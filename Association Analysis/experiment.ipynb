# %%
import pandas as pd # 读取数据表并进行基于DataFrame结构的操作
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
import re
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore') # 不显示warning信息
pd.options.display.width = 900 # Dataframe 显示宽度设置

# %% [markdown]
# 首先我们从文件中读取数据。可以看到，共有9835条数据，每个数据两个属性，ID和items。

# %%
df = pd.read_csv("Datas.csv")
print(df.shape)
df.head(7)
# Out:
# (9835, 2)
#    ID                                              items
# 0   1  {citrus fruit,semi-finished bread,margarine,re...
# 1   2                     {tropical fruit,yogurt,coffee}
# 2   3                                       {whole milk}
# 3   4      {pip fruit,yogurt,cream cheese ,meat spreads}
# 4   5  {other vegetables,whole milk,condensed milk,lo...
# 5   6   {whole milk,butter,yogurt,rice,abrasive cleaner}
# 6   7                                       {rolls/buns}

# %% [markdown]
# 接下来我们需要进行数据预处理，将数据转化为我们能够操作的形式。
#
# 原始数据存在于DataFrame中，首先我们将数据提取出来作为一个字典

# %%
data={}
for index,items in df.groupby('ID')['items']:
    data[index] = frozenset(items.values)
data
# Out:
# {1: frozenset({'{citrus fruit,semi-finished bread,margarine,ready soups}'}),
#  2: frozenset({'{tropical fruit,yogurt,coffee}'}),
#  3: frozenset({'{whole milk}'}),
#  4: frozenset({'{pip fruit,yogurt,cream cheese ,meat spreads}'}),
#  5: frozenset({'{other vegetables,whole milk,condensed milk,long life bakery product}'}),
#  6: frozenset({'{whole milk,butter,yogurt,rice,abrasive cleaner}'}),
#  7: frozenset({'{rolls/buns}'}),
#  8: frozenset({'{other vegetables,UHT-milk,rolls/buns,bottled beer,liquor (appetizer)}'}),
#  9: frozenset({'{pot plants}'}),
#  10: frozenset({'{whole milk,cereals}'}),
#  11: frozenset({'{tropical fruit,other vegetables,white bread,bottled water,chocolate}'}),
#  12: frozenset({'{citrus fruit,tropical fruit,whole milk,butter,curd,yogurt,flour,bottled water,dishes}'}),
#  13: frozenset({'{beef}'}),
#  14: frozenset({'{frankfurter,rolls/buns,soda}'}),
#  15: frozenset({'{chicken,tropical fruit}'}),
#  16: frozenset({'{butter,sugar,fruit/vegetable juice,newspapers}'}),
#  17: frozenset({'{fruit/vegetable juice}'}),
#  18: frozenset({'{packaged fruit/vegetables}'}),
#  19: frozenset({'{chocolate}'}),
#  20: frozenset({'{specialty bar}'}),
#  21: frozenset({'{other vegetables}'}),
#  22: frozenset({'{butter milk,pastry}'}),
#  23: frozenset({'{whole milk}'}),
#  24: frozenset({'{tropical fruit,cream cheese ,processed cheese,detergent,newspapers}'}),
#  25: frozenset({'{tropical fruit,root vegetables,other vegetables,frozen dessert,rolls/buns,flour,sweet spreads,salty snack,waffles,candy,bathroom cleaner}'}),
#  26: frozenset({'{bottled water,canned beer}'}),
#  27: frozenset({'{yogurt}'}),
#  28: frozenset({'{sausage,rolls/buns,soda,chocolate}'}),
#  29: frozenset({'{other vegetables}'}),
#  30: frozenset({'{brown bread,soda,fruit/vegetable juice,canned beer,newspapers,shopping bags}'}),
#  31: frozenset({'{yogurt,beverages,bottled water,specialty bar}'}),
#  32: frozenset({'{hamburger meat,other vegetables,rolls/buns,spices,bottled water,hygiene articles,napkins}'}),
#  33: frozenset({'{root vegetables,other vegetables,whole milk,beverages,sugar}'}),
#  34: frozenset({'{pork,berries,other vegetables,whole milk,whipped/sour cream,artif. sweetener,soda,abrasive cleaner}'}),
#  35: frozenset({'{beef,grapes,detergent}'}),
#  36: frozenset({'{pastry,soda}'}),
#  37: frozenset({'{fruit/vegetable juice}'}),
#  38: frozenset({'{canned beer}'}),
#  39: frozenset({'{root vegetables,other vegetables,whole milk,dessert}'}),
#  40: frozenset({'{citrus fruit,zwieback,newspapers}'}),
#  41: frozenset({'{sausage,rolls/buns,soda,canned beer,specialty bar,shopping bags}'}),
#  42: frozenset({'{tropical fruit,root vegetables,whole milk,yogurt,domestic eggs,brown bread,pastry,sugar,cereals,coffee,soda,waffles,candy}'}),
#  43: frozenset({'{berries,yogurt}'}),
#  44: frozenset({'{canned beer}'}),
#  45: frozenset({'{butter milk,yogurt,cream cheese ,spread cheese,rolls/buns,bottled water,soda,newspapers}'}),
#  46: frozenset({'{coffee}'}),
#  47: frozenset({'{pastry,bottled water}'}),
#  48: frozenset({'{rolls/buns}'}),
#  49: frozenset({'{misc. beverages}'}),
#  50: frozenset({'{root vegetables,other vegetables,butter,curd,whipped/sour cream,UHT-milk,hard cheese,rolls/buns,bottled water,long life bakery product}'}),
#  51: frozenset({'{sausage,rolls/buns,cat food,newspapers}'}),
#  52: frozenset({'{canned beer}'}),
#  53: frozenset({'{ham,grapes,other vegetables,whole milk}'}),
#  54: frozenset({'{turkey,tropical fruit,other vegetables,curd,domestic eggs,brown bread,semi-finished bread,margarine,baking powder,fruit/vegetable juice}'}),
#  55: frozenset({'{whole milk,yogurt,processed cheese,pickled vegetables,soda}'}),
#  56: frozenset({'{whole milk,curd,yogurt,pastry}'}),
#  57: frozenset({'{packaged fruit/vegetables,brown bread,canned beer}'}),
#  58: frozenset({'{rolls/buns,oil,bottled water,chewing gum,chocolate marshmallow,hygiene articles,napkins}'}),
#  59: frozenset({'{ham,beef,whipped/sour cream,ice cream,rolls/buns,cat food}'}),
#  60: frozenset({'{rolls/buns,pastry,sugar}'}),
#  61: frozenset({'{other vegetables,whole milk,frozen vegetables,canned fish,salty snack,seasonal products,detergent}'}),
#  62: frozenset({'{sausage,pastry}'}),
#  63: frozenset({'{sausage,beef,whole milk}'}),
#  64: frozenset({'{frankfurter,tropical fruit,rolls/buns,brown bread,sugar}'}),
#  65: frozenset({'{rolls/buns,pastry,soda}'}),
#  66: frozenset({'{whole milk}'}),
#  67: frozenset({'{curd cheese,coffee}'}),
#  68: frozenset({'{red/blush wine,newspapers}'}),
#  69: frozenset({'{sausage,whole milk,curd}'}),
#  70: frozenset({'{tropical fruit,pip fruit,berries,whole milk,frozen potato products,rolls/buns,pickled vegetables,chocolate}'}),
#  71: frozenset({'{red/blush wine}'}),
#  72: frozenset({'{whole milk,butter,margarine,specialty fat,specialty chocolate,candles,flower (seeds)}'}),
#  73: frozenset({'{frankfurter,citrus fruit,whole milk,domestic eggs,oil,sparkling wine,specialty chocolate,newspapers}'}),
#  74: frozenset({'{whole milk,meat spreads,soda}'}),
#  75: frozenset({'{frozen potato products}'}),
#  76: frozenset({'{other vegetables,whole milk,rolls/buns,sugar}'}),
#  77: frozenset({'{citrus fruit,whole milk,curd,butter milk,pastry}'}),
#  78: frozenset({'{flour,salt,bottled water,fruit/vegetable juice,bottled beer}'}),
#  79: frozenset({'{sugar,bottled water,soda,bottled beer}'}),
#  80: frozenset({'{frozen meals,coffee}'}),
#  81: frozenset({'{chocolate}'}),
#  82: frozenset({'{root vegetables,whole milk,frozen vegetables,domestic eggs,rolls/buns,oil,margarine,canned vegetables,fruit/vegetable juice,bathroom cleaner}'}),
#  83: frozenset({'{root vegetables,onions,hard cheese,frozen vegetables}'}),
#  84: frozenset({'{herbs,condensed milk,frozen vegetables,salt,oil,white wine,candles}'}),
#  85: frozenset({'{bottled water}'}),
#  86: frozenset({'{sausage,root vegetables,onions,yogurt,rolls/buns,brandy,detergent}'}),
#  87: frozenset({'{coffee,newspapers}'}),
#  88: frozenset({'{pork,other vegetables,whipped/sour cream}'}),
#  89: frozenset({'{berries,yogurt}'}),
#  90: frozenset({'{soda}'}),
#  91: frozenset({'{berries}'}),
#  92: frozenset({'{fruit/vegetable juice,salty snack,candles}'}),
#  93: frozenset({'{citrus fruit,butter milk,yogurt,cream cheese }'}),
#  94: frozenset({'{pork,hamburger meat,citrus fruit,berries,onions,whipped/sour cream,rice,coffee,chocolate}'}),
#  95: frozenset({'{detergent}'}),
#  96: frozenset({'{grapes,photo/film}'}),
#  97: frozenset({'{sausage,sliced cheese,rolls/buns,brown bread,fruit/vegetable juice,canned beer,red/blush wine,waffles,shopping bags}'}),
#  98: frozenset({'{chicken,hamburger meat,citrus fruit,tropical fruit,root vegetables,other vegetables,butter,pasta,oil,detergent}'}),
#  99: frozenset({'{whole milk,yogurt,brown bread}'}),
#  100: frozenset({'{citrus fruit,tropical fruit}'}),
#  101: frozenset({'{soda,misc. beverages}'}),
#  102: frozenset({'{sausage,pork,grapes,whole milk,rolls/buns,pastry,soda,specialty bar,bathroom cleaner}'}),
#  103: frozenset({'{frankfurter,rolls/buns,bottled water}'}),
#  104: frozenset({'{sausage,whole milk,yogurt,coffee,fruit/vegetable juice,bottled beer,softener,napkins,photo/film,shopping bags}'}),
#  105: frozenset({'{soda}'}),
#  106: frozenset({'{rolls/buns,fruit/vegetable juice}'}),
#  107: frozenset({'{beef,citrus fruit,berries,root vegetables,brown bread,detergent}'}),
#  108: frozenset({'{whole milk,whipped/sour cream,rolls/buns,soda,waffles,candy,cling film/bags}'}),
#  109: frozenset({'{processed cheese}'}),
#  110: frozenset({'{tropical fruit,pip fruit}'}),
#  111: frozenset({'{frankfurter,sausage,root vegetables,other vegetables,rolls/buns,oil,pickled vegetables,bottled beer,chewing gum,dishes}'}),
#  112: frozenset({'{packaged fruit/vegetables,bottled water}'}),
#  113: frozenset({'{whole milk,dessert,frozen vegetables,rolls/buns,margarine,bottled water,red/blush wine,newspapers}'}),
#  114: frozenset({'{berries,whipped/sour cream}'}),
#  115: frozenset({'{citrus fruit,berries,UHT-milk,processed cheese}'}),
#  116: frozenset({'{tropical fruit,whole milk,yogurt}'}),
#  117: frozenset({'{hamburger meat,whole milk,frozen vegetables,rolls/buns,bottled beer,sparkling wine}'}),
#  118: frozenset({'{hamburger meat,other vegetables,whole milk,frozen vegetables,domestic eggs,soda,dishes}'}),
#  119: frozenset({'{whole milk,cream cheese ,soda}'}),
#  120: frozenset({'{fish,other vegetables,pastry,margarine,coffee,long life bakery product,male cosmetics,shopping bags}'}),
#  121: frozenset({'{frankfurter,sausage,long life bakery product,waffles}'}),
#  122: frozenset({'{packaged fruit/vegetables,dessert,semi-finished bread,canned beer}'}),
#  123: frozenset({'{pastry,soda}'}),
#  124: frozenset({'{other vegetables,red/blush wine}'}),
#  125: frozenset({'{misc. beverages}'}),
#  126: frozenset({'{frankfurter,sausage,citrus fruit,tropical fruit,pip fruit,whole milk,hard cheese,cream cheese ,domestic eggs,rice,sugar,canned fruit,misc. beverages,fruit/vegetable juice,hygiene articles}'}),
#  127: frozenset({'{sparkling wine}'}),
#  128: frozenset({'{specialty bar}'}),
#  129: frozenset({'{sausage,butter milk,rolls/buns}'}),
#  130: frozenset({'{curd cheese}'}),
#  131: frozenset({'{frankfurter,dessert}'}),
#  132: frozenset({'{whole milk,yogurt,beverages,brown bread,shopping bags}'}),
#  133: frozenset({'{newspapers}'}),
#  134: frozenset({'{berries,soda}'}),
#  135: frozenset({'{curd,flour,liquor (appetizer)}'}),
#  136: frozenset({'{tropical fruit,other vegetables,coffee}'}),
#  137: frozenset({'{soda}'}),
#  138: frozenset({'{rolls/buns,Instant food products}'}),
#  139: frozenset({'{canned beer}'}),
#  140: frozenset({'{canned beer}'}),
#  141: frozenset({'{frankfurter,sausage,whole milk,rolls/buns,margarine}'}),
#  142: frozenset({'{other vegetables,misc. beverages,canned beer}'}),
#  143: frozenset({'{whole milk,frozen vegetables}'}),
#  144: frozenset({'{whole milk}'}),
#  145: frozenset({'{citrus fruit,butter,cream cheese ,white bread,oil,margarine,newspapers}'}),
#  146: frozenset({'{frankfurter,rolls/buns}'}),
#  147: frozenset({'{frankfurter,ham,pip fruit,other vegetables,whole milk,soft cheese,frozen vegetables,rolls/buns,sugar,baking powder}'}),
#  148: frozenset({'{butter milk,yogurt,honey,soda,detergent}'}),
#  149: frozenset({'{hamburger meat,citrus fruit,onions,rolls/buns,bottled water,dental care}'}),
#  150: frozenset({'{pasta,popcorn}'}),
#  151: frozenset({'{other vegetables,whole milk,meat spreads,cake bar,chocolate,shopping bags}'}),
#  152: frozenset({'{sausage,pork,citrus fruit,dessert,white bread,dishes,candles}'}),
#  153: frozenset({'{rolls/buns}'}),
#  154: frozenset({'{grapes,other vegetables,curd,dessert,yogurt,napkins}'}),
#  155: frozenset({'{root vegetables,other vegetables,whole milk,yogurt,beverages,soft cheese,frozen vegetables,fruit/vegetable juice,bottled beer}'}),
#  156: frozenset({'{coffee,shopping bags}'}),
#  157: frozenset({'{popcorn}'}),
#  158: frozenset({'{whole milk,rolls/buns,sugar,bottled water,soda}'}),
#  159: frozenset({'{tropical fruit,other vegetables,packaged fruit/vegetables,whole milk,snack products}'}),
#  160: frozenset({'{beef,herbs,flour,cling film/bags,flower soil/fertilizer}'}),
#  161: frozenset({'{whole milk,butter,dessert,rolls/buns}'}),
#  162: frozenset({'{frankfurter,soda,chewing gum}'}),
#  163: frozenset({'{tropical fruit,specialty cheese,bottled water}'}),
#  164: frozenset({'{canned beer}'}),
#  165: frozenset({'{finished products,other vegetables,frozen vegetables,bottled beer}'}),
#  166: frozenset({'{beverages,soda}'}),
#  167: frozenset({'{hamburger meat,root vegetables,whole milk}'}),
#  168: frozenset({'{whole milk,pastry,long life bakery product}'}),
#  169: frozenset({'{finished products,white wine,shopping bags}'}),
#  170: frozenset({'{other vegetables}'}),
#  171: frozenset({'{ham,tropical fruit,other vegetables,whole milk,white bread,brown bread,fruit/vegetable juice,bottled beer}'}),
#  172: frozenset({'{other vegetables}'}),
#  173: frozenset({'{curd,butter milk,cocoa drinks,salty snack,popcorn}'}),
#  174: frozenset({'{bottled beer}'}),
#  175: frozenset({'{curd,dessert,soda,salty snack,waffles,cake bar,chocolate,shopping bags}'}),
#  176: frozenset({'{whole milk,cream cheese ,cereals,dog food}'}),
#  177: frozenset({'{whole milk,salt}'}),
#  178: frozenset({'{dessert,ice cream}'}),
#  179: frozenset({'{sausage,soft cheese,coffee}'}),
#  180: frozenset({'{other vegetables,bottled water,waffles,dishes,shopping bags}'}),
#  181: frozenset({'{ham,whole milk,rolls/buns}'}),
#  182: frozenset({'{other vegetables,ice cream}'}),
#  183: frozenset({'{other vegetables,bottled water}'}),
#  184: frozenset({'{soda,bottled beer,white wine,prosecco}'}),
#  185: frozenset({'{herbs,candy}'}),
#  186: frozenset({'{frankfurter,ham,tropical fruit,pip fruit,root vegetables,other vegetables,whole milk,butter,curd,yogurt,whipped/sour cream,soft cheese,sliced cheese,cream cheese ,frozen meals,frozen fish,domestic eggs,white bread,sugar,cereals,fruit/vegetable juice,bottled beer,waffles}'}),
#  187: frozenset({'{rolls/buns,canned beer}'}),
#  188: frozenset({'{curd,cream cheese ,semi-finished bread,zwieback,cake bar,specialty bar,shopping bags}'}),
#  189: frozenset({'{frankfurter,tropical fruit,whole milk,spread cheese,margarine,shopping bags}'}),
#  190: frozenset({'{other vegetables}'}),
#  191: frozenset({'{dog food}'}),
#  192: frozenset({'{specialty bar}'}),
#  193: frozenset({'{curd,salt,liquor (appetizer),detergent,shopping bags}'}),
#  194: frozenset({'{frankfurter,rolls/buns}'}),
#  195: frozenset({'{soda}'}),
#  196: frozenset({'{beef,berries,root vegetables,whole milk,dessert,spread cheese,brown bread}'}),
#  197: frozenset({'{canned beer}'}),
#  198: frozenset({'{pork,beef,pip fruit,herbs,spices}'}),
#  199: frozenset({'{frankfurter,citrus fruit,UHT-milk,margarine,sugar}'}),
#  200: frozenset({'{sausage,bottled beer,liquor (appetizer)}'}),
#  201: frozenset({'{canned beer}'}),
#  202: frozenset({'{specialty chocolate}'}),
#  203: frozenset({'{curd,rolls/buns}'}),
#  204: frozenset({'{canned beer}'}),
#  205: frozenset({'{whole milk,bottled water,newspapers}'}),
#  206: frozenset({'{rolls/buns,chewing gum}'}),
#  207: frozenset({'{pork,root vegetables,other vegetables,whole milk,dishes}'}),
#  208: frozenset({'{citrus fruit,pastry}'}),
#  209: frozenset({'{pot plants}'}),
#  210: frozenset({'{rolls/buns,pastry,soda}'}),
#  211: frozenset({'{butter,yogurt,bottled water,soda,make up remover,hygiene articles}'}),
#  212: frozenset({'{condensed milk,sugar,coffee,shopping bags}'}),
#  213: frozenset({'{sausage,other vegetables,yogurt,soda,shopping bags}'}),
#  214: frozenset({'{whole milk,beverages,UHT-milk,soda}'}),
#  215: frozenset({'{sausage,pork,beef,whole milk,rolls/buns,margarine}'}),
#  216: frozenset({'{beverages}'}),
#  217: frozenset({'{beverages,specialty bar}'}),
#  218: frozenset({'{bottled water,fruit/vegetable juice}'}),
#  219: frozenset({'{newspapers}'}),
#  220: frozenset({'{cleaner,female sanitary products}'}),
#  221: frozenset({'{sausage,soda,newspapers,shopping bags}'}),
#  222: frozenset({'{newspapers}'}),
#  223: frozenset({'{sausage,beef,citrus fruit,other vegetables,whole milk,butter milk,whipped/sour cream,beverages,hard cheese,rolls/buns,dish cleaner,cookware}'}),
#  224: frozenset({'{misc. beverages,newspapers}'}),
#  225: frozenset({'{white wine}'}),
#  226: frozenset({'{sausage,sliced cheese,rolls/buns,soda,canned beer,shopping bags}'}),
#  227: frozenset({'{meat,curd,bottled beer,cake bar}'}),
#  228: frozenset({'{frankfurter,meat,tropical fruit,onions,oil,baking powder,tea,cling film/bags}'}),
#  229: frozenset({'{ice cream,rolls/buns,canned beer}'}),
#  230: frozenset({'{canned beer}'}),
#  231: frozenset({'{tropical fruit,berries,root vegetables,other vegetables,bottled water,shopping bags}'}),
#  232: frozenset({'{meat,citrus fruit,other vegetables,curd,dessert,butter milk,beverages,cream cheese ,rolls/buns,brown bread,tea,bottled water}'}),
#  233: frozenset({'{whole milk,mustard,bottled water}'}),
#  234: frozenset({'{sausage,beef,beverages,sliced cheese,rolls/buns,spices,house keeping products,flower (seeds)}'}),
#  235: frozenset({'{frankfurter,sausage,root vegetables,butter,curd,sliced cheese,rolls/buns,salty snack,long life bakery product}'}),
#  236: frozenset({'{meat,other vegetables,butter,rolls/buns}'}),
#  237: frozenset({'{root vegetables,beverages,Instant food products,pickled vegetables,detergent}'}),
#  238: frozenset({'{root vegetables,herbs,other vegetables,whole milk,sliced cheese,rolls/buns}'}),
#  239: frozenset({'{whole milk,whipped/sour cream,semi-finished bread,margarine}'}),
#  240: frozenset({'{citrus fruit,whole milk,curd,dessert,yogurt,whipped/sour cream,frozen dessert,rolls/buns,salt,sugar,cereals,canned vegetables,canned fish,skin care,hygiene articles,napkins}'}),
#  241: frozenset({'{citrus fruit,curd,pastry,margarine,sugar,candy,newspapers}'}),
#  242: frozenset({'{other vegetables,whole milk,bottled water,soda,misc. beverages,bottled beer,red/blush wine,napkins}'}),
#  243: frozenset({'{citrus fruit,whole milk,rolls/buns}'}),
#  244: frozenset({'{sausage,oil,hygiene articles,napkins}'}),
#  245: frozenset({'{frankfurter,beef,hamburger meat,grapes,root vegetables,whole milk,butter,frozen dessert,potato products,bottled water,bottled beer}'}),
#  246: frozenset({'{hard cheese,rolls/buns,bottled water,newspapers}'}),
#  247: frozenset({'{cream cheese ,rolls/buns,soda,chocolate}'}),
#  248: frozenset({'{turkey,beef,frozen vegetables,dishes,photo/film}'}),
#  249: frozenset({'{pork,other vegetables,whipped/sour cream,rolls/buns,soda,shopping bags}'}),
#  250: frozenset({'{whole milk,beverages}'}),
#  251: frozenset({'{rolls/buns,soda}'}),
#  252: frozenset({'{sausage,pip fruit,whole milk,curd,yogurt,sliced cheese,rolls/buns,bottled water,hygiene articles}'}),
#  253: frozenset({'{ice cream}'}),
#  254: frozenset({'{liquor}'}),
#  255: frozenset({'{pip fruit,other vegetables,fruit/vegetable juice}'}),
#  256: frozenset({'{root vegetables,other vegetables,yogurt}'}),
#  257: frozenset({'{soda}'}),
#  258: frozenset({'{soda}'}),
#  259: frozenset({'{sausage,citrus fruit,tropical fruit,other vegetables,whole milk,yogurt,rolls/buns,bottled water,soda,chocolate,newspapers}'}),
#  260: frozenset({'{root vegetables,whole milk,pet care,detergent}'}),
#  261: frozenset({'{pork,berries,root vegetables,other vegetables,pastry,specialty bar}'}),
#  262: frozenset({'{pork}'}),
#  263: frozenset({'{chocolate}'}),
#  264: frozenset({'{fruit/vegetable juice}'}),
#  265: frozenset({'{pickled vegetables,coffee}'}),
#  266: frozenset({'{bottled water}'}),
#  267: frozenset({'{frankfurter,sausage,butter,whipped/sour cream,rolls/buns,margarine,spices}'}),
#  268: frozenset({'{tropical fruit,pip fruit,onions,other vegetables,whole milk,domestic eggs,sugar,soups,tea,soda,hygiene articles,napkins}'}),
#  269: frozenset({'{canned beer}'}),
#  270: frozenset({'{root vegetables}'}),
#  271: frozenset({'{meat,citrus fruit,berries,root vegetables,whole milk,soda}'}),
#  272: frozenset({'{frankfurter,rolls/buns,bottled water,fruit/vegetable juice,hygiene articles}'}),
#  273: frozenset({'{tropical fruit,margarine,rum}'}),
#  274: frozenset({'{tropical fruit,root vegetables,herbs,whole milk,butter milk,whipped/sour cream,flour,hygiene articles}'}),
#  275: frozenset({'{citrus fruit,pip fruit,root vegetables,other vegetables,whole milk,cream cheese ,domestic eggs,brown bread,margarine,baking powder,waffles}'}),
#  276: frozenset({'{hamburger meat,other vegetables,whole milk,curd,yogurt,rolls/buns,pastry,semi-finished bread,margarine,bottled water,fruit/vegetable juice}'}),
#  277: frozenset({'{chicken,pip fruit,other vegetables,whole milk,dessert,yogurt,whipped/sour cream,rolls/buns,pasta,soda,waffles}'}),
#  278: frozenset({'{chicken,citrus fruit,tropical fruit,root vegetables,whole milk,frozen fish,rolls/buns}'}),
#  279: frozenset({'{frankfurter,citrus fruit,onions,other vegetables,whole milk,rolls/buns,sugar,soda}'}),
#  280: frozenset({'{canned beer}'}),
#  281: frozenset({'{turkey,pip fruit,salad dressing,pastry}'}),
#  282: frozenset({'{packaged fruit/vegetables,whole milk,curd,yogurt,domestic eggs,brown bread,mustard,pickled vegetables,bottled water,misc. beverages}'}),
#  283: frozenset({'{pasta}'}),
#  284: frozenset({'{citrus fruit,tropical fruit}'}),
#  285: frozenset({'{sausage,whole milk,yogurt,rolls/buns,brown bread,pot plants}'}),
#  286: frozenset({'{whole milk,frozen meals,pastry,fruit/vegetable juice,waffles}'}),
#  287: frozenset({'{canned beer}'}),
#  288: frozenset({'{citrus fruit,sugar,sauces}'}),
#  289: frozenset({'{liquor (appetizer)}'}),
#  290: frozenset({'{citrus fruit,other vegetables,rolls/buns,salty snack,shopping bags}'}),
#  291: frozenset({'{sausage}'}),
#  292: frozenset({'{chicken,other vegetables,whole milk,vinegar,oil,bottled water,canned beer,napkins,newspapers}'}),
#  293: frozenset({'{hamburger meat,root vegetables,other vegetables,whole milk,yogurt,whipped/sour cream,specialty cheese,flour,margarine}'}),
#  294: frozenset({'{sausage,pork,other vegetables,dessert,yogurt,oil,soda}'}),
#  295: frozenset({'{beef,berries,root vegetables,whole milk,whipped/sour cream,abrasive cleaner}'}),
#  296: frozenset({'{citrus fruit,packaged fruit/vegetables,yogurt,bottled water}'}),
#  297: frozenset({'{UHT-milk,coffee}'}),
#  298: frozenset({'{candy}'}),
#  299: frozenset({'{newspapers}'}),
#  300: frozenset({'{beef,citrus fruit,other vegetables,yogurt}'}),
#  301: frozenset({'{sausage,rolls/buns}'}),
#  302: frozenset({'{frankfurter,beef,root vegetables,curd,dessert,yogurt,soft cheese,rolls/buns,mustard,pickled vegetables,canned beer,hygiene articles,napkins}'}),
#  303: frozenset({'{canned beer}'}),
#  304: frozenset({'{bottled beer}'}),
#  305: frozenset({'{onions,soda,chewing gum,chocolate,newspapers}'}),
#  306: frozenset({'{tropical fruit,packaged fruit/vegetables,cream cheese ,white bread,candy}'}),
#  307: frozenset({'{bottled water,white wine}'}),
#  308: frozenset({'{beef,white bread,pastry,pasta,soap}'}),
#  309: frozenset({'{sausage,chicken,tropical fruit,root vegetables,whole milk,yogurt,candy,abrasive cleaner,cleaner}'}),
#  310: frozenset({'{hair spray}'}),
#  311: frozenset({'{chicken,whole milk,spices,long life bakery product,shopping bags}'}),
#  312: frozenset({'{pork,citrus fruit,brown bread,pastry,sugar,cat food}'}),
#  313: frozenset({'{ice cream}'}),
#  314: frozenset({'{meat,hard cheese,bottled beer}'}),
#  315: frozenset({'{other vegetables,yogurt,brown bread,instant coffee}'}),
#  316: frozenset({'{bottled water,cake bar}'}),
#  317: frozenset({'{tropical fruit,soda,salty snack}'}),
#  318: frozenset({'{photo/film}'}),
#  319: frozenset({'{sausage,citrus fruit,yogurt,coffee,soda,canned beer,dishes}'}),
#  320: frozenset({'{grapes,root vegetables}'}),
#  321: frozenset({'{domestic eggs,brown bread,photo/film}'}),
#  322: frozenset({'{rolls/buns,canned fish,canned beer}'}),
#  323: frozenset({'{tropical fruit,whole milk}'}),
#  324: frozenset({'{chicken}'}),
#  325: frozenset({'{frankfurter,other vegetables,yogurt,brown bread,bottled water}'}),
#  326: frozenset({'{berries,root vegetables,other vegetables,curd,butter milk,cream cheese ,roll products ,margarine,misc. beverages,specialty chocolate,detergent}'}),
#  327: frozenset({'{margarine,hygiene articles}'}),
#  328: frozenset({'{tropical fruit,yogurt,rolls/buns,soda,shopping bags}'}),
#  329: frozenset({'{ham,other vegetables,whipped/sour cream,hard cheese,rolls/buns,soda,misc. beverages,chocolate,candy}'}),
#  330: frozenset({'{hamburger meat,white bread,salty snack}'}),
#  331: frozenset({'{yogurt,mayonnaise,rolls/buns,soda,napkins}'}),
#  332: frozenset({'{soda,specialty chocolate}'}),
#  333: frozenset({'{yogurt}'}),
#  334: frozenset({'{soda}'}),
#  335: frozenset({'{bottled water}'}),
#  336: frozenset({'{sausage,meat,hamburger meat,rubbing alcohol}'}),
#  337: frozenset({'{citrus fruit,pip fruit,beverages,hard cheese,pet care,soda,fruit/vegetable juice,waffles}'}),
#  338: frozenset({'{shopping bags}'}),
#  339: frozenset({'{newspapers}'}),
#  340: frozenset({'{frankfurter,other vegetables,whole milk,curd,frozen potato products,zwieback,specialty bar,dish cleaner}'}),
#  341: frozenset({'{sausage,citrus fruit,whole milk,canned beer}'}),
#  342: frozenset({'{frankfurter,rolls/buns}'}),
#  343: frozenset({'{salt,salty snack,cookware}'}),
#  344: frozenset({'{oil}'}),
#  345: frozenset({'{curd,beverages,cream cheese ,rolls/buns,pastry,soda,cake bar,chewing gum}'}),
#  346: frozenset({'{other vegetables,butter,specialty chocolate}'}),
#  347: frozenset({'{citrus fruit}'}),
#  348: frozenset({'{frankfurter,whole milk,butter milk}'}),
#  349: frozenset({'{root vegetables,whole milk,butter,processed cheese,mayonnaise,salty snack}'}),
#  350: frozenset({'{tropical fruit,whole milk,frozen meals,bottled beer}'}),
#  351: frozenset({'{beef,hamburger meat,pip fruit}'}),
#  352: frozenset({'{berries,whipped/sour cream,cereals,waffles,shopping bags}'}),
#  353: frozenset({'{canned beer}'}),
#  354: frozenset({'{whipped/sour cream,canned beer,red/blush wine}'}),
#  355: frozenset({'{root vegetables,domestic eggs,margarine,chocolate marshmallow,candy}'}),
#  356: frozenset({'{whole milk,soda}'}),
#  357: frozenset({'{beef}'}),
#  358: frozenset({'{frozen vegetables}'}),
#  359: frozenset({'{rolls/buns,bottled beer}'}),
#  360: frozenset({'{whole milk,hygiene articles}'}),
#  361: frozenset({'{whole milk}'}),
#  362: frozenset({'{citrus fruit,whole milk,curd,soft cheese}'}),
#  363: frozenset({'{pastry,fruit/vegetable juice}'}),
#  364: frozenset({'{frankfurter,sausage,pork,pip fruit,butter,processed cheese,white bread,brown bread}'}),
#  365: frozenset({'{tropical fruit,root vegetables,whole milk,whipped/sour cream,domestic eggs}'}),
#  366: frozenset({'{frankfurter,sausage,root vegetables,yogurt,whipped/sour cream,pastry,napkins}'}),
#  367: frozenset({'{berries,root vegetables,other vegetables,packaged fruit/vegetables,whole milk,curd,curd cheese,cat food,specialty bar,detergent}'}),
#  368: frozenset({'{rolls/buns,brown bread,pastry,coffee,bottled beer}'}),
#  369: frozenset({'{root vegetables,packaged fruit/vegetables,curd,dessert,frozen vegetables,specialty fat,coffee}'}),
#  370: frozenset({'{yogurt}'}),
#  371: frozenset({'{other vegetables,bottled water}'}),
#  372: frozenset({'{berries,white bread}'}),
#  373: frozenset({'{berries,coffee}'}),
#  374: frozenset({'{other vegetables,butter milk,frozen meals,bottled water}'}),
#  375: frozenset({'{rolls/buns,newspapers}'}),
#  376: frozenset({'{ham,citrus fruit,whole milk,whipped/sour cream,rolls/buns,pastry,waffles,hygiene articles}'}),
#  377: frozenset({'{whole milk,frozen dessert,salty snack,napkins}'}),
#  378: frozenset({'{tropical fruit,butter milk,rolls/buns,bottled water}'}),
#  379: frozenset({'{bottled water}'}),
#  380: frozenset({'{butter milk,yogurt}'}),
#  381: frozenset({'{newspapers}'}),
#  382: frozenset({'{coffee}'}),
#  383: frozenset({'{bottled beer,liquor}'}),
#  384: frozenset({'{onions,butter,whipped/sour cream,hard cheese,frozen vegetables,pasta,specialty fat,syrup,candy,napkins,cling film/bags}'}),
#  385: frozenset({'{hamburger meat,hard cheese,frozen meals,pasta,dog food,salty snack,shopping bags}'}),
#  386: frozenset({'{sausage,liver loaf,other vegetables,cream cheese ,pastry,soap,shopping bags}'}),
#  387: frozenset({'{hard cheese,pastry,napkins}'}),
#  388: frozenset({'{sausage,tropical fruit,condensed milk,rolls/buns}'}),
#  389: frozenset({'{hamburger meat}'}),
#  390: frozenset({'{onions,whole milk,beverages,frozen dessert}'}),
#  391: frozenset({'{coffee}'}),
#  392: frozenset({'{shopping bags}'}),
#  393: frozenset({'{yogurt,rolls/buns,pastry,bottled water,soda,shopping bags}'}),
#  394: frozenset({'{soda}'}),
#  395: frozenset({'{sliced cheese}'}),
#  396: frozenset({'{sausage,whole milk,coffee}'}),
#  397: frozenset({'{yogurt,chocolate}'}),
#  398: frozenset({'{domestic eggs,rolls/buns,dish cleaner,hygiene articles}'}),
#  399: frozenset({'{whole milk}'}),
#  400: frozenset({'{meat,other vegetables,whole milk,whipped/sour cream}'}),
#  401: frozenset({'{dish cleaner,bathroom cleaner,hygiene articles,napkins}'}),
#  402: frozenset({'{other vegetables,red/blush wine}'}),
#  403: frozenset({'{whole milk,butter milk,yogurt,sliced cheese,rolls/buns,sweet spreads,coffee,fruit/vegetable juice,long life bakery product,shopping bags}'}),
#  404: frozenset({'{other vegetables,whole milk,rolls/buns,Instant food products}'}),
#  405: frozenset({'{tropical fruit,other vegetables}'}),
#  406: frozenset({'{baking powder,bottled water,salty snack,chewing gum}'}),
#  407: frozenset({'{specialty bar}'}),
#  408: frozenset({'{ice cream}'}),
#  409: frozenset({'{frankfurter,yogurt}'}),
#  410: frozenset({'{canned beer}'}),
#  411: frozenset({'{bottled water}'}),
#  412: frozenset({'{other vegetables,whole milk,rolls/buns,margarine,bottled water,bottled beer}'}),
#  413: frozenset({'{citrus fruit,tropical fruit,onions,other vegetables,shopping bags}'}),
#  414: frozenset({'{sausage,ham,hamburger meat,whole milk,soda,softener,newspapers}'}),
#  415: frozenset({'{domestic eggs,rolls/buns,specialty bar,napkins}'}),
#  416: frozenset({'{pork,citrus fruit,tropical fruit,root vegetables,other vegetables,curd,hygiene articles}'}),
#  417: frozenset({'{specialty cheese,frozen vegetables,coffee,soda,fruit/vegetable juice,salty snack}'}),
#  418: frozenset({'{pork,citrus fruit,pip fruit,yogurt,fruit/vegetable juice,sparkling wine}'}),
#  419: frozenset({'{beef,berries,whipped/sour cream,domestic eggs,rolls/buns}'}),
#  420: frozenset({'{other vegetables,pet care}'}),
#  421: frozenset({'{chicken,yogurt,sliced cheese,rolls/buns,chewing gum,dishes}'}),
#  422: frozenset({'{soda,chewing gum}'}),
#  423: frozenset({'{whole milk}'}),
#  424: frozenset({'{rolls/buns}'}),
#  425: frozenset({'{bottled beer}'}),
#  426: frozenset({'{root vegetables,pastry,bottled water,male cosmetics}'}),
#  427: frozenset({'{pastry}'}),
#  428: frozenset({'{berries,pet care,cake bar,shopping bags}'}),
#  429: frozenset({'{citrus fruit,tropical fruit,root vegetables,yogurt,canned vegetables,bottled water,soda,softener}'}),
#  430: frozenset({'{whole milk,oil,canned fruit,fruit/vegetable juice}'}),
#  431: frozenset({'{soda,misc. beverages}'}),
#  432: frozenset({'{bottled water,soda}'}),
#  433: frozenset({'{tropical fruit,other vegetables,rolls/buns}'}),
#  434: frozenset({'{salty snack}'}),
#  435: frozenset({'{bottled water,canned beer}'}),
#  436: frozenset({'{chocolate}'}),
#  437: frozenset({'{citrus fruit,UHT-milk,cream cheese ,frozen vegetables}'}),
#  438: frozenset({'{bottled water,canned beer,male cosmetics}'}),
#  439: frozenset({'{onions,other vegetables,pastry,bottled water,soda,napkins}'}),
#  440: frozenset({'{dessert,oil,cat food,soda}'}),
#  441: frozenset({'{beef,other vegetables,whole milk,frozen potato products,rolls/buns,oil,margarine,coffee,dental care,hygiene articles,newspapers}'}),
#  442: frozenset({'{rolls/buns,zwieback,bottled water,misc. beverages,bottled beer,canned beer,brandy}'}),
#  443: frozenset({'{beef,tropical fruit,root vegetables,onions,other vegetables,instant coffee,soda}'}),
#  444: frozenset({'{soda}'}),
#  445: frozenset({'{coffee,hygiene articles}'}),
#  446: frozenset({'{rolls/buns,brown bread,bottled water}'}),
#  447: frozenset({'{pork,beef,hamburger meat,other vegetables,whole milk,frozen vegetables,rolls/buns,margarine,shopping bags}'}),
#  448: frozenset({'{soda,canned beer,liquor (appetizer),hygiene articles,napkins,newspapers}'}),
#  449: frozenset({'{sausage,ham,other vegetables,ice cream,white bread}'}),
#  450: frozenset({'{beef,root vegetables,other vegetables,rolls/buns,sugar}'}),
#  451: frozenset({'{whole milk,butter,bottled water,bottled beer}'}),
#  452: frozenset({'{pork,ice cream,hygiene articles,house keeping products}'}),
#  453: frozenset({'{berries,packaged fruit/vegetables,whole milk,ice cream,fruit/vegetable juice,salty snack,specialty bar}'}),
#  454: frozenset({'{sausage,other vegetables,curd,yogurt,whipped/sour cream,frozen vegetables,rolls/buns,roll products }'}),
#  455: frozenset({'{bottled water,misc. beverages,cling film/bags}'}),
#  456: frozenset({'{tropical fruit,other vegetables,packaged fruit/vegetables,whole milk,hard cheese,frozen dessert,rice,bottled water}'}),
#  457: frozenset({'{herbs,bottled water}'}),
#  458: frozenset({'{yogurt,rolls/buns}'}),
#  459: frozenset({'{Instant food products}'}),
#  460: frozenset({'{specialty chocolate}'}),
#  461: frozenset({'{coffee}'}),
#  462: frozenset({'{bottled beer,liquor}'}),
#  463: frozenset({'{beef,root vegetables}'}),
#  464: frozenset({'{whole milk,honey,waffles}'}),
#  465: frozenset({'{frankfurter,rolls/buns,pastry,snack products,specialty bar}'}),
#  466: frozenset({'{frankfurter,sausage,liver loaf,root vegetables,curd,frozen vegetables,rolls/buns,semi-finished bread,hygiene articles,photo/film}'}),
#  467: frozenset({'{other vegetables,whole milk,cream cheese }'}),
#  468: frozenset({'{frankfurter,root vegetables,pickled vegetables,soda,seasonal products}'}),
#  469: frozenset({'{whole milk,rolls/buns,newspapers}'}),
#  470: frozenset({'{frankfurter,margarine,dental care}'}),
#  471: frozenset({'{other vegetables,salty snack}'}),
#  472: frozenset({'{bottled water,shopping bags}'}),
#  473: frozenset({'{pork,onions,whole milk,butter,rolls/buns,pastry,rum,hygiene articles}'}),
#  474: frozenset({'{bottled water}'}),
#  475: frozenset({'{other vegetables,whipped/sour cream,specialty cheese,domestic eggs}'}),
#  476: frozenset({'{hamburger meat,whole milk,curd,pasta,canned beer}'}),
#  477: frozenset({'{hamburger meat,citrus fruit,other vegetables}'}),
#  478: frozenset({'{shopping bags}'}),
#  479: frozenset({'{whole milk,cream cheese ,soda,fruit/vegetable juice}'}),
#  480: frozenset({'{ice cream}'}),
#  481: frozenset({'{pastry,bottled water}'}),
#  482: frozenset({'{ham,pip fruit,whole milk,curd,dessert,butter milk,whipped/sour cream,sliced cheese,cream cheese ,white bread,coffee,long life bakery product,chocolate,baby cosmetics}'}),
#  483: frozenset({'{frankfurter,soda}'}),
#  484: frozenset({'{sausage,turkey,beef,root vegetables,domestic eggs,rolls/buns,flour,rice,organic products,misc. beverages,napkins}'}),
#  485: frozenset({'{bottled beer}'}),
#  486: frozenset({'{bottled water,bottled beer,napkins}'}),
#  487: frozenset({'{meat,other vegetables,hard cheese,frozen meals,bottled water,soda}'}),
#  488: frozenset({'{dessert,candy}'}),
#  489: frozenset({'{other vegetables,packaged fruit/vegetables,UHT-milk,bottled water}'}),
#  490: frozenset({'{beverages,rolls/buns,soda}'}),
#  491: frozenset({'{ham,mustard,canned fish}'}),
#  492: frozenset({'{specialty bar}'}),
#  493: frozenset({'{brown bread,soda,salty snack,shopping bags}'}),
#  494: frozenset({'{whole milk,cream cheese ,coffee}'}),
#  495: frozenset({'{rolls/buns,pastry,red/blush wine}'}),
#  496: frozenset({'{bottled beer,nut snack}'}),
#  497: frozenset({'{pet care,bottled beer}'}),
#  498: frozenset({'{citrus fruit,other vegetables,soda}'}),
#  499: frozenset({'{pork,other vegetables,frozen vegetables,hygiene articles}'}),
#  500: frozenset({'{other vegetables,shopping bags}'}),
#  501: frozenset({'{white wine,detergent}'}),
#  502: frozenset({'{whole milk,dessert,bottled water}'}),
#  503: frozenset({'{pip fruit,white wine,shopping bags}'}),
#  504: frozenset({'{sugar,soda,bottled beer}'}),
#  505: frozenset({'{tropical fruit,pip fruit,rolls/buns,coffee,fruit/vegetable juice,candy}'}),
#  506: frozenset({'{root vegetables,cream cheese ,spread cheese,frozen dessert,white bread,bottled water,soda,misc. beverages,fruit/vegetable juice,bottled beer}'}),
#  507: frozenset({'{soda,misc. beverages}'}),
#  508: frozenset({'{whole milk,curd}'}),
#  509: frozenset({'{tropical fruit,other vegetables,yogurt,bottled water,male cosmetics}'}),
#  510: frozenset({'{white bread,brown bread}'}),
#  511: frozenset({'{brown bread,sugar,hygiene articles}'}),
#  512: frozenset({'{tropical fruit,root vegetables,coffee,bottled water,red/blush wine,candy,house keeping products,shopping bags}'}),
#  513: frozenset({'{domestic eggs}'}),
#  514: frozenset({'{coffee,detergent,hygiene articles,photo/film}'}),
#  515: frozenset({'{soda}'}),
#  516: frozenset({'{whole milk}'}),
#  517: frozenset({'{bottled beer}'}),
#  518: frozenset({'{pork,beef,berries,packaged fruit/vegetables,whole milk,mayonnaise,frozen fish,frozen potato products,oil,mustard,cat food,coffee,soda,chocolate,dish cleaner,napkins,newspapers}'}),
#  519: frozenset({'{other vegetables,yogurt}'}),
#  520: frozenset({'{yogurt,bottled water,dishes}'}),
#  521: frozenset({'{sparkling wine}'}),
#  522: frozenset({'{bottled water,candy}'}),
#  523: frozenset({'{citrus fruit,berries,other vegetables,butter milk,sugar,fruit/vegetable juice,hygiene articles}'}),
#  524: frozenset({'{hamburger meat,root vegetables,other vegetables,whole milk,rolls/buns}'}),
#  525: frozenset({'{packaged fruit/vegetables,seasonal products}'}),
#  526: frozenset({'{other vegetables,margarine}'}),
#  527: frozenset({'{soda}'}),
#  528: frozenset({'{whole milk,yogurt,frozen potato products,margarine,bottled water,fruit/vegetable juice,salty snack}'}),
#  529: frozenset({'{herbs,yogurt}'}),
#  530: frozenset({'{citrus fruit,spread cheese,rolls/buns,soda}'}),
#  531: frozenset({'{misc. beverages}'}),
#  532: frozenset({'{female sanitary products}'}),
#  533: frozenset({'{soda}'}),
#  534: frozenset({'{tropical fruit,whole milk,beverages,white bread,pasta,shopping bags}'}),
#  535: frozenset({'{soda,female sanitary products}'}),
#  536: frozenset({'{white bread,bottled water,soda,waffles}'}),
#  537: frozenset({'{coffee,chewing gum,chocolate marshmallow}'}),
#  538: frozenset({'{tropical fruit,root vegetables,whole milk,frozen vegetables,honey,baking powder,coffee,red/blush wine,chocolate marshmallow}'}),
#  539: frozenset({'{pork,pip fruit,whole milk,butter milk}'}),
#  540: frozenset({'{citrus fruit,bottled water}'}),
#  541: frozenset({'{frankfurter}'}),
#  542: frozenset({'{frankfurter,rolls/buns}'}),
#  543: frozenset({'{frankfurter,tropical fruit,pip fruit,curd,UHT-milk,hard cheese,domestic eggs,rolls/buns,hygiene articles,napkins,shopping bags}'}),
#  544: frozenset({'{other vegetables}'}),
#  545: frozenset({'{yogurt,fruit/vegetable juice,newspapers}'}),
#  546: frozenset({'{sausage,whole milk,yogurt,brown bread,cereals,bottled water,soda}'}),
#  547: frozenset({'{whole milk}'}),
#  548: frozenset({'{pip fruit,whole milk,curd,pastry,bottled water}'}),
#  549: frozenset({'{whole milk}'}),
#  550: frozenset({'{root vegetables,other vegetables}'}),
#  551: frozenset({'{onions,fruit/vegetable juice}'}),
#  552: frozenset({'{specialty chocolate}'}),
#  553: frozenset({'{hamburger meat,domestic eggs}'}),
#  554: frozenset({'{photo/film}'}),
#  555: frozenset({'{rolls/buns,soda,snack products,newspapers}'}),
#  556: frozenset({'{canned beer}'}),
#  557: frozenset({'{canned beer}'}),
#  558: frozenset({'{other vegetables,curd,frozen meals,frozen potato products,soda,bottled beer,kitchen towels,candles}'}),
#  559: frozenset({'{canned beer}'}),
#  560: frozenset({'{curd,whipped/sour cream,rolls/buns,zwieback,spices}'}),
#  561: frozenset({'{butter,fruit/vegetable juice,newspapers}'}),
#  562: frozenset({'{other vegetables,whole milk,yogurt,domestic eggs,bottled water,soda}'}),
#  563: frozenset({'{whole milk}'}),
#  564: frozenset({'{beef,tropical fruit,herbs,whole milk,curd,yogurt,whipped/sour cream,sliced cheese}'}),
#  565: frozenset({'{sausage,rolls/buns}'}),
#  566: frozenset({'{soda}'}),
#  567: frozenset({'{fruit/vegetable juice,long life bakery product}'}),
#  568: frozenset({'{rolls/buns,coffee,long life bakery product,detergent,shopping bags}'}),
#  569: frozenset({'{pip fruit,whole milk,bottled water,candy}'}),
#  570: frozenset({'{frozen vegetables,bottled beer,liquor (appetizer),chewing gum,napkins,newspapers}'}),
#  571: frozenset({'{beverages}'}),
#  572: frozenset({'{hamburger meat,root vegetables,other vegetables,domestic eggs,roll products ,oil,margarine,hygiene articles}'}),
#  573: frozenset({'{root vegetables,other vegetables,whole milk,yogurt,fruit/vegetable juice,white wine}'}),
#  574: frozenset({'{canned beer}'}),
#  575: frozenset({'{frozen vegetables,bottled beer}'}),
#  576: frozenset({'{canned beer}'}),
#  577: frozenset({'{newspapers}'}),
#  578: frozenset({'{rolls/buns}'}),
#  579: frozenset({'{hamburger meat,UHT-milk,salty snack}'}),
#  580: frozenset({'{pip fruit,whole milk,curd,rum}'}),
#  581: frozenset({'{canned beer}'}),
#  582: frozenset({'{grapes,root vegetables,frozen vegetables,domestic eggs,white wine}'}),
#  583: frozenset({'{root vegetables,packaged fruit/vegetables,butter,whipped/sour cream,rolls/buns}'}),
#  584: frozenset({'{citrus fruit,frozen vegetables,rolls/buns,canned beer,salty snack}'}),
#  585: frozenset({'{cling film/bags,pot plants}'}),
#  586: frozenset({'{frankfurter,whole milk,rolls/buns,margarine,baking powder,bottled beer}'}),
#  587: frozenset({'{whole milk,red/blush wine}'}),
#  588: frozenset({'{pork,tropical fruit,whole milk,curd,yogurt,hard cheese,frozen meals,frozen dessert,domestic eggs,cereals,baking powder,fruit/vegetable juice,soap}'}),
#  589: frozenset({'{chicken,pastry}'}),
#  590: frozenset({'{sausage,dish cleaner,dishes}'}),
#  591: frozenset({'{specialty bar}'}),
#  592: frozenset({'{whipped/sour cream,pastry,specialty bar}'}),
#  593: frozenset({'{root vegetables,brown bread}'}),
#  594: frozenset({'{rolls/buns,soda}'}),
#  595: frozenset({'{other vegetables,bottled beer,red/blush wine}'}),
#  596: frozenset({'{citrus fruit,tropical fruit,berries,root vegetables,other vegetables,whole milk,butter,bottled water,rubbing alcohol,hygiene articles,napkins}'}),
#  597: frozenset({'{whole milk,processed cheese,brown bread,pastry,soda}'}),
#  598: frozenset({'{frankfurter,sausage,tropical fruit,root vegetables,whole milk,yogurt,rolls/buns,pastry,candy}'}),
#  599: frozenset({'{coffee,long life bakery product}'}),
#  600: frozenset({'{ham,rolls/buns,white wine}'}),
#  601: frozenset({'{canned beer}'}),
#  602: frozenset({'{canned beer}'}),
#  603: frozenset({'{canned beer}'}),
#  604: frozenset({'{pip fruit,whole milk,canned fish}'}),
#  605: frozenset({'{pork,pip fruit,other vegetables,whole milk,curd,white bread,sugar,bottled water,soda}'}),
#  606: frozenset({'{soap}'}),
#  607: frozenset({'{pip fruit,butter,frozen meals,pasta,bottled water}'}),
#  608: frozenset({'{beef,hamburger meat,citrus fruit,whole milk,mustard,soap}'}),
#  609: frozenset({'{sausage,meat,other vegetables,whole milk,yogurt,rolls/buns,soda,bottled beer,chocolate,newspapers}'}),
#  610: frozenset({'{frozen chicken}'}),
#  611: frozenset({'{soda}'}),
#  612: frozenset({'{tropical fruit,curd,yogurt,rolls/buns,brown bread,bottled water,bottled beer,seasonal products}'}),
#  613: frozenset({'{other vegetables}'}),
#  614: frozenset({'{beef,citrus fruit,curd,rolls/buns,oil,margarine,specialty bar,detergent,newspapers}'}),
#  615: frozenset({'{meat,pork,beef,citrus fruit,root vegetables,other vegetables,whole milk,pickled vegetables}'}),
#  616: frozenset({'{meat,hamburger meat,root vegetables,packaged fruit/vegetables,whole milk,butter,newspapers}'}),
#  617: frozenset({'{bottled water,soda,red/blush wine,long life bakery product,newspapers}'}),
#  618: frozenset({'{rolls/buns}'}),
#  619: frozenset({'{pastry,canned beer}'}),
#  620: frozenset({'{pork,whole milk,pastry,sauces}'}),
#  621: frozenset({'{pip fruit,sliced cheese,pastry,white wine,light bulbs,newspapers}'}),
#  622: frozenset({'{beef,citrus fruit,tropical fruit,yogurt,UHT-milk,frozen vegetables,rolls/buns,bottled water,skin care}'}),
#  623: frozenset({'{beef,citrus fruit,berries,brown bread,sugar,coffee,kitchen towels}'}),
#  624: frozenset({'{rolls/buns,spices}'}),
#  625: frozenset({'{citrus fruit,tropical fruit,herbs,whole milk,butter,curd,whipped/sour cream,frozen vegetables,canned vegetables,misc. beverages}'}),
#  626: frozenset({'{meat,beef,herbs,whole milk,frozen dessert,rolls/buns,semi-finished bread,flour,oil,coffee,pot plants}'}),
#  627: frozenset({'{beverages,pastry,bottled water}'}),
#  628: frozenset({'{beef,citrus fruit,other vegetables,rolls/buns}'}),
#  629: frozenset({'{ham,whole milk,white bread,margarine,hair spray}'}),
#  630: frozenset({'{hamburger meat,whole milk,oil,ketchup,soups,Instant food products,canned fish,coffee,bottled beer,hygiene articles,newspapers}'}),
#  631: frozenset({'{beef,citrus fruit,other vegetables,butter milk,sliced cheese,processed cheese,rolls/buns,margarine,bottled water,fruit/vegetable juice}'}),
#  632: frozenset({'{beef,citrus fruit,whole milk,domestic eggs,rolls/buns,pastry,roll products ,tea,fruit/vegetable juice}'}),
#  633: frozenset({'{root vegetables,whole milk,detergent}'}),
#  634: frozenset({'{citrus fruit,tropical fruit,grapes,other vegetables,frozen vegetables,pickled vegetables,fruit/vegetable juice,liquor,rum,liquor (appetizer),candy,cling film/bags}'}),
#  635: frozenset({'{yogurt,bottled water}'}),
#  636: frozenset({'{tropical fruit,root vegetables,other vegetables,whipped/sour cream,brown bread,canned fish,long life bakery product}'}),
#  637: frozenset({'{frankfurter,root vegetables,newspapers}'}),
#  638: frozenset({'{beef,other vegetables,whole milk,brown bread,pastry,salty snack,abrasive cleaner,shopping bags}'}),
#  639: frozenset({'{shopping bags}'}),
#  640: frozenset({'{canned beer}'}),
#  641: frozenset({'{rolls/buns,canned beer}'}),
#  642: frozenset({'{other vegetables,rolls/buns,meat spreads,bottled water,soda,misc. beverages,waffles,chocolate,candy}'}),
#  643: frozenset({'{hamburger meat,other vegetables,yogurt,rolls/buns,bottled water}'}),
#  644: frozenset({'{hamburger meat,citrus fruit,root vegetables,rolls/buns,Instant food products,canned fish,bottled water,soda,fruit/vegetable juice,napkins}'}),
#  645: frozenset({'{frankfurter,sausage,domestic eggs,soda,chewing gum,shopping bags}'}),
#  646: frozenset({'{bottled beer}'}),
#  647: frozenset({'{tropical fruit,domestic eggs,rolls/buns,pastry}'}),
#  648: frozenset({'{soda}'}),
#  649: frozenset({'{frankfurter,root vegetables,onions,other vegetables,white bread,canned beer}'}),
#  650: frozenset({'{chicken,hamburger meat,herbs,whipped/sour cream,soups,soda,canned beer,dish cleaner,napkins,cling film/bags}'}),
#  651: frozenset({'{coffee,soda}'}),
#  652: frozenset({'{whole milk}'}),
#  653: frozenset({'{margarine}'}),
#  654: frozenset({'{tropical fruit,other vegetables}'}),
#  655: frozenset({'{meat,other vegetables}'}),
#  656: frozenset({'{cream cheese ,bottled water,canned beer}'}),
#  657: frozenset({'{newspapers}'}),
#  658: frozenset({'{rolls/buns,pastry,newspapers}'}),
#  659: frozenset({'{citrus fruit,other vegetables,whole milk,curd,yogurt,potato products,fruit/vegetable juice,long life bakery product}'}),
#  660: frozenset({'{whole milk,rolls/buns,detergent}'}),
#  661: frozenset({'{frankfurter,citrus fruit,butter milk,UHT-milk,rolls/buns,female sanitary products,shopping bags}'}),
#  662: frozenset({'{ham,other vegetables,butter,whipped/sour cream,sugar,soda}'}),
#  663: frozenset({'{frankfurter,citrus fruit,bottled beer,salty snack}'}),
#  664: frozenset({'{sausage,onions,curd,yogurt,domestic eggs,coffee}'}),
#  665: frozenset({'{domestic eggs}'}),
#  666: frozenset({'{whole milk,domestic eggs,rolls/buns,soda}'}),
#  667: frozenset({'{rolls/buns,bottled beer,newspapers}'}),
#  668: frozenset({'{whole milk,hard cheese,chocolate marshmallow}'}),
#  669: frozenset({'{sausage,root vegetables,other vegetables,rolls/buns,soda}'}),
#  670: frozenset({'{curd,butter milk,yogurt,beverages}'}),
#  671: frozenset({'{bottled water}'}),
#  672: frozenset({'{beef}'}),
#  673: frozenset({'{frankfurter,hamburger meat,whole milk,rolls/buns,potato products,mustard,coffee,waffles,chocolate marshmallow,soap,newspapers}'}),
#  674: frozenset({'{chicken,butter,newspapers}'}),
#  675: frozenset({'{sausage,meat,tropical fruit,pip fruit,pastry,sugar,coffee,candles,pot plants}'}),
#  676: frozenset({'{pork,whole milk,whipped/sour cream,beverages}'}),
#  677: frozenset({'{yogurt,pastry,coffee}'}),
#  678: frozenset({'{whole milk,sliced cheese,margarine,cat food,detergent,dishes,shopping bags}'}),
#  679: frozenset({'{frankfurter,ham,whole milk,yogurt,rolls/buns,pastry,vinegar,sugar,soda,fruit/vegetable juice,napkins}'}),
#  680: frozenset({'{beef,whole milk,brown bread,specialty chocolate,newspapers}'}),
#  681: frozenset({'{pip fruit,other vegetables,butter milk,cream cheese ,rolls/buns}'}),
#  682: frozenset({'{sausage,whole milk,rolls/buns,coffee,chocolate}'}),
#  683: frozenset({'{pastry,coffee}'}),
#  684: frozenset({'{chicken,beef,specialty chocolate}'}),
#  685: frozenset({'{root vegetables,other vegetables,whole milk,sliced cheese,frozen vegetables,frozen fish,frozen dessert,chocolate}'}),
#  686: frozenset({'{whole milk,frozen meals,rolls/buns}'}),
#  687: frozenset({'{detergent}'}),
#  688: frozenset({'{rolls/buns,canned fish}'}),
#  689: frozenset({'{house keeping products}'}),
#  690: frozenset({'{yogurt,salt,jam,sparkling wine,cleaner}'}),
# ...
#  815: frozenset({'{root vegetables,pot plants}'}),
#  816: frozenset({'{canned beer}'}),
#  817: frozenset({'{citrus fruit,root vegetables,whole milk,butter,whipped/sour cream,oil,mustard,bottled water,bottled beer}'}),
#  818: frozenset({'{pip fruit,herbs,other vegetables,whole milk,coffee,female sanitary products,hygiene articles,shopping bags}'}),
#  819: frozenset({'{root vegetables,dessert,yogurt,cream cheese ,rice}'}),
#  820: frozenset({'{tropical fruit,curd,rolls/buns,organic products,newspapers}'}),
#  821: frozenset({'{beef,root vegetables,other vegetables,whole milk,butter,soft cheese,hard cheese,domestic eggs,pasta,coffee,candles}'}),
#  822: frozenset({'{chicken,pork,whole milk,butter,white bread}'}),
#  823: frozenset({'{citrus fruit,grapes,whole milk,rolls/buns,pastry,oil,margarine,candles,newspapers}'}),
#  824: frozenset({'{meat,beef,tropical fruit,pip fruit,other vegetables,whipped/sour cream,soft cheese,frozen meals,margarine,coffee,fruit/vegetable juice,pot plants}'}),
#  825: frozenset({'{cream cheese ,spread cheese,rolls/buns}'}),
#  826: frozenset({'{citrus fruit,herbs,whole milk,bottled water,bottled beer,pot plants}'}),
#  827: frozenset({'{specialty bar}'}),
#  828: frozenset({'{meat,other vegetables,whole milk,beverages,rolls/buns,margarine,chocolate,napkins,newspapers}'}),
#  829: frozenset({'{citrus fruit,tropical fruit,pip fruit}'}),
#  830: frozenset({'{frankfurter,beef,tropical fruit,root vegetables,packaged fruit/vegetables,whole milk,frozen vegetables}'}),
#  831: frozenset({'{citrus fruit,whole milk}'}),
#  832: frozenset({'{turkey,root vegetables,other vegetables,curd,bottled beer,specialty chocolate}'}),
#  833: frozenset({'{citrus fruit,onions,whole milk,curd,yogurt,rolls/buns,pasta,mustard,dog food,canned beer}'}),
#  834: frozenset({'{sausage,domestic eggs}'}),
#  835: frozenset({'{newspapers}'}),
#  836: frozenset({'{whole milk,yogurt}'}),
#  837: frozenset({'{yogurt}'}),
#  838: frozenset({'{yogurt}'}),
#  839: frozenset({'{bottled water}'}),
#  840: frozenset({'{berries,whole milk,whipped/sour cream,domestic eggs}'}),
#  841: frozenset({'{packaged fruit/vegetables,whole milk,rolls/buns,pastry}'}),
#  842: frozenset({'{frankfurter,soda}'}),
#  843: frozenset({'{nuts/prunes,whole milk,semi-finished bread,jam,soda,pot plants,shopping bags}'}),
#  844: frozenset({'{citrus fruit,other vegetables,packaged fruit/vegetables,whole milk,butter,whipped/sour cream,flour,sugar,coffee,soda,sparkling wine,dishes}'}),
#  845: frozenset({'{beef,citrus fruit,root vegetables,onions,curd,hard cheese,rolls/buns,fruit/vegetable juice}'}),
#  846: frozenset({'{whole milk,yogurt,frozen vegetables,coffee,canned beer,napkins}'}),
#  847: frozenset({'{other vegetables,whipped/sour cream}'}),
#  848: frozenset({'{beef,other vegetables}'}),
#  849: frozenset({'{fish,berries,other vegetables,whole milk,dessert,yogurt,spread cheese,coffee,white wine,red/blush wine}'}),
#  850: frozenset({'{other vegetables,whole milk,curd,frozen vegetables,domestic eggs,sugar,instant coffee,newspapers}'}),
#  851: frozenset({'{tropical fruit,berries,root vegetables,whole milk,butter,yogurt,whipped/sour cream,sliced cheese,hard cheese,specialty chocolate,napkins}'}),
#  852: frozenset({'{coffee}'}),
#  853: frozenset({'{sausage,pork,other vegetables,frozen fish,rolls/buns,semi-finished bread,artif. sweetener,ready soups,bottled water,hygiene articles,newspapers}'}),
#  854: frozenset({'{meat,root vegetables,whipped/sour cream,beverages,cream cheese ,waffles,dishes}'}),
#  855: frozenset({'{chicken,tropical fruit,pip fruit,root vegetables,other vegetables,packaged fruit/vegetables,butter,rolls/buns,margarine,sugar,rum,long life bakery product,abrasive cleaner}'}),
#  856: frozenset({'{berries,whole milk,whipped/sour cream,margarine,organic products,fruit/vegetable juice,shopping bags}'}),
#  857: frozenset({'{frozen meals,misc. beverages}'}),
#  858: frozenset({'{whipped/sour cream}'}),
#  859: frozenset({'{beef,root vegetables,bottled beer,chocolate,shopping bags}'}),
#  860: frozenset({'{chicken,pork,other vegetables,whole milk,whipped/sour cream,UHT-milk,domestic eggs,rolls/buns,bottled water,soda,fruit/vegetable juice,bottled beer}'}),
#  861: frozenset({'{chicken,pork,hamburger meat,pip fruit,nuts/prunes,root vegetables,other vegetables,whole milk,spread cheese,frozen potato products,brown bread,Instant food products,soda,fruit/vegetable juice,shopping bags}'}),
#  862: frozenset({'{beef,tropical fruit,root vegetables,herbs,other vegetables,whole milk,yogurt,hard cheese,rolls/buns,brown bread,bottled water,bottled beer,salty snack,shopping bags}'}),
#  863: frozenset({'{packaged fruit/vegetables,pickled vegetables}'}),
#  864: frozenset({'{sugar}'}),
#  865: frozenset({'{frankfurter,sausage,beef,root vegetables,packaged fruit/vegetables,whole milk,dessert,yogurt,sliced cheese,ice cream,rolls/buns,soda}'}),
#  866: frozenset({'{berries,frozen vegetables,pet care,instant coffee}'}),
#  867: frozenset({'{bottled water,soda,chewing gum,napkins}'}),
#  868: frozenset({'{sausage,chicken,citrus fruit,berries,root vegetables,curd,beverages,abrasive cleaner}'}),
#  869: frozenset({'{whole milk,UHT-milk,domestic eggs,soda,fruit/vegetable juice,dishes,newspapers}'}),
#  870: frozenset({'{ice cream,rolls/buns}'}),
#  871: frozenset({'{frankfurter,citrus fruit,tropical fruit,rolls/buns}'}),
#  872: frozenset({'{root vegetables,whole milk,white bread,brown bread,sweet spreads,dog food,brandy,shopping bags}'}),
#  873: frozenset({'{sausage,rolls/buns,specialty chocolate}'}),
#  874: frozenset({'{sausage,ham,citrus fruit,tropical fruit,berries,packaged fruit/vegetables,whole milk,whipped/sour cream,sliced cheese,pastry,sugar,baking powder}'}),
#  875: frozenset({'{beef,root vegetables,whole milk,cream cheese }'}),
#  876: frozenset({'{fruit/vegetable juice}'}),
#  877: frozenset({'{sugar,hygiene articles}'}),
#  878: frozenset({'{berries,whipped/sour cream}'}),
#  879: frozenset({'{yogurt,beverages,coffee}'}),
#  880: frozenset({'{pork,beef}'}),
#  881: frozenset({'{bottled beer,shopping bags}'}),
#  882: frozenset({'{curd,butter milk,yogurt,sliced cheese,coffee}'}),
#  883: frozenset({'{beef,Instant food products,canned beer}'}),
#  884: frozenset({'{pork,berries,whipped/sour cream,beverages,flour,oil,soda,chocolate,newspapers}'}),
#  885: frozenset({'{white bread}'}),
#  886: frozenset({'{grapes,whole milk,processed cheese,rolls/buns,white bread,fruit/vegetable juice}'}),
#  887: frozenset({'{potato products,flower (seeds)}'}),
#  888: frozenset({'{root vegetables,onions,yogurt,rolls/buns,coffee,bottled water,dishes}'}),
#  889: frozenset({'{chicken,hamburger meat,UHT-milk,soda,canned beer,bathroom cleaner,newspapers}'}),
#  890: frozenset({'{chicken,other vegetables,salt}'}),
#  891: frozenset({'{fish,cream cheese ,coffee}'}),
#  892: frozenset({'{canned beer}'}),
#  893: frozenset({'{other vegetables,whole milk,frozen meals,rolls/buns,brown bread,napkins}'}),
#  894: frozenset({'{chicken,pork,whole milk,frozen vegetables,brown bread,vinegar,bottled beer,red/blush wine,newspapers}'}),
#  895: frozenset({'{other vegetables,misc. beverages}'}),
#  896: frozenset({'{tropical fruit,whole milk}'}),
#  897: frozenset({'{whole milk,cake bar,newspapers}'}),
#  898: frozenset({'{beef,hamburger meat,berries,pastry,hygiene articles}'}),
#  899: frozenset({'{sausage,grapes,rolls/buns,soda,salty snack}'}),
#  900: frozenset({'{whole milk,rolls/buns,chocolate}'}),
#  901: frozenset({'{rolls/buns,soda}'}),
#  902: frozenset({'{citrus fruit,tropical fruit,pip fruit,other vegetables}'}),
#  903: frozenset({'{whole milk,sliced cheese,domestic eggs,artif. sweetener,bottled water,soda,shopping bags}'}),
#  904: frozenset({'{pastry,soda,bottled beer}'}),
#  905: frozenset({'{tropical fruit,other vegetables,whole milk,yogurt,soft cheese,hard cheese,spread cheese,curd cheese,frozen vegetables,ice cream,pastry,coffee,fruit/vegetable juice,hygiene articles}'}),
#  906: frozenset({'{sliced cheese,pastry,newspapers}'}),
#  907: frozenset({'{soda}'}),
#  908: frozenset({'{ham,citrus fruit,whole milk,dessert,frozen meals,coffee,popcorn,shopping bags}'}),
#  909: frozenset({'{salty snack}'}),
#  910: frozenset({'{whole milk,curd,cream cheese ,flour,coffee,bottled water,misc. beverages,newspapers}'}),
#  911: frozenset({'{root vegetables,whipped/sour cream}'}),
#  912: frozenset({'{soda,canned beer,shopping bags}'}),
#  913: frozenset({'{curd,roll products ,margarine,bottled water,canned beer,white wine,dish cleaner}'}),
#  914: frozenset({'{bottled water,soda,fruit/vegetable juice,bottled beer,napkins}'}),
#  915: frozenset({'{packaged fruit/vegetables,pot plants}'}),
#  916: frozenset({'{tropical fruit,root vegetables,frozen vegetables,ice cream,bottled water,cling film/bags}'}),
#  917: frozenset({'{ham,beef,grapes,yogurt,whipped/sour cream,domestic eggs,white bread,pastry,bottled water,fruit/vegetable juice,white wine,salty snack,chocolate,newspapers,shopping bags}'}),
#  918: frozenset({'{pork,citrus fruit,UHT-milk,brown bread,soda,bottled beer,canned beer,long life bakery product}'}),
#  919: frozenset({'{beverages,rolls/buns,soda,misc. beverages,liqueur,cake bar}'}),
#  920: frozenset({'{sausage,rolls/buns,soda}'}),
#  921: frozenset({'{sausage,citrus fruit,whole milk,yogurt,rolls/buns,bottled water,soda,napkins}'}),
#  922: frozenset({'{root vegetables,whole milk,butter,yogurt,cream cheese ,frozen fish,shopping bags}'}),
#  923: frozenset({'{whole milk,cream cheese }'}),
#  924: frozenset({'{frankfurter,turkey,root vegetables,other vegetables,yogurt,rolls/buns,pastry,ready soups}'}),
#  925: frozenset({'{soda,shopping bags}'}),
#  926: frozenset({'{soda,bottled beer}'}),
#  927: frozenset({'{frankfurter,popcorn}'}),
#  928: frozenset({'{berries,whole milk,whipped/sour cream,pickled vegetables,detergent,newspapers}'}),
#  929: frozenset({'{canned beer}'}),
#  930: frozenset({'{frankfurter,pork,white bread,canned vegetables,soda}'}),
#  931: frozenset({'{frankfurter,hamburger meat,whole milk,butter,curd,flour,rice,oil,sugar,mustard,salty snack,chocolate,chocolate marshmallow,dish cleaner,dental care}'}),
#  932: frozenset({'{berries,root vegetables,whole milk,beverages,sugar,soups,coffee,shopping bags}'}),
#  933: frozenset({'{frankfurter,rolls/buns}'}),
#  934: frozenset({'{newspapers}'}),
#  935: frozenset({'{frozen fish,newspapers}'}),
#  936: frozenset({'{tropical fruit,newspapers}'}),
#  937: frozenset({'{beef,grapes,berries,whole milk,yogurt,rolls/buns,newspapers,pot plants}'}),
#  938: frozenset({'{rolls/buns,coffee,instant coffee,salty snack,specialty chocolate}'}),
#  939: frozenset({'{specialty chocolate,pot plants}'}),
#  940: frozenset({'{sparkling wine,dish cleaner}'}),
#  941: frozenset({'{citrus fruit,napkins,shopping bags}'}),
#  942: frozenset({'{onions,herbs,bottled beer}'}),
#  943: frozenset({'{whole milk,pastry,detergent,candles}'}),
#  944: frozenset({'{photo/film}'}),
#  945: frozenset({'{hamburger meat}'}),
#  946: frozenset({'{other vegetables,whole milk,white bread,chewing gum}'}),
#  947: frozenset({'{whole milk,rolls/buns,shopping bags}'}),
#  948: frozenset({'{pork,tropical fruit,grapes,hard cheese,soda,napkins,shopping bags}'}),
#  949: frozenset({'{tropical fruit,grapes,berries,other vegetables,whole milk,butter,dessert,yogurt,whipped/sour cream,ice cream,pastry,salt,baking powder,bottled water,misc. beverages,fruit/vegetable juice,canned beer,specialty chocolate,pot plants}'}),
#  950: frozenset({'{chicken,pork,citrus fruit,other vegetables,whipped/sour cream,white bread,chewing gum,pot plants}'}),
#  951: frozenset({'{other vegetables,chewing gum}'}),
#  952: frozenset({'{sausage,bottled water,red/blush wine}'}),
#  953: frozenset({'{whole milk,whipped/sour cream,baking powder}'}),
#  954: frozenset({'{rolls/buns,coffee}'}),
#  955: frozenset({'{hygiene articles}'}),
#  956: frozenset({'{ice cream,newspapers}'}),
#  957: frozenset({'{curd,whipped/sour cream,domestic eggs,flour,misc. beverages,newspapers}'}),
#  958: frozenset({'{whole milk,frozen meals,newspapers}'}),
#  959: frozenset({'{onions,whole milk,dessert,domestic eggs,rolls/buns,white bread,coffee,bottled water}'}),
#  960: frozenset({'{finished products,organic sausage,sliced cheese,white bread,fruit/vegetable juice}'}),
#  961: frozenset({'{salt,dog food,long life bakery product}'}),
#  962: frozenset({'{tropical fruit,root vegetables,other vegetables,domestic eggs,white bread,brown bread,canned vegetables,soda,fruit/vegetable juice,rum}'}),
#  963: frozenset({'{other vegetables,whole milk,yogurt}'}),
#  964: frozenset({'{chocolate}'}),
#  965: frozenset({'{ice cream}'}),
#  966: frozenset({'{tropical fruit,oil,cat food}'}),
#  967: frozenset({'{frankfurter,citrus fruit,whole milk,yogurt,sliced cheese,specialty cheese,pastry,fruit/vegetable juice}'}),
#  968: frozenset({'{butter,pasta,canned fish,softener,flower (seeds)}'}),
#  969: frozenset({'{other vegetables,butter milk,frozen fish,salty snack}'}),
#  970: frozenset({'{tropical fruit,pastry,canned beer,chocolate}'}),
#  971: frozenset({'{citrus fruit,root vegetables,packaged fruit/vegetables,yogurt,sliced cheese,rolls/buns,white bread,brown bread,zwieback}'}),
#  972: frozenset({'{UHT-milk,salt,soda,specialty chocolate,shopping bags}'}),
#  973: frozenset({'{beef}'}),
#  974: frozenset({'{curd,yogurt,spread cheese,sugar,canned vegetables}'}),
#  975: frozenset({'{citrus fruit,other vegetables,whole milk,dessert,yogurt,frozen vegetables,fruit/vegetable juice,bottled beer,salty snack}'}),
#  976: frozenset({'{yogurt,brown bread,bottled beer,white wine}'}),
#  977: frozenset({'{bottled beer,liquor,red/blush wine}'}),
#  978: frozenset({'{grapes}'}),
#  979: frozenset({'{pork,other vegetables,soda}'}),
#  980: frozenset({'{sausage,citrus fruit,berries,other vegetables,whole milk,yogurt,whipped/sour cream,cream cheese ,frozen vegetables,domestic eggs,pastry,margarine,soups,canned fish,chocolate,candy,napkins}'}),
#  981: frozenset({'{frankfurter,chicken,pork,tropical fruit,root vegetables,other vegetables,yogurt,UHT-milk,mayonnaise,brown bread,pastry,flour,mustard,coffee,cocoa drinks,fruit/vegetable juice,salty snack,long life bakery product,chocolate,seasonal products}'}),
#  982: frozenset({'{artif. sweetener,soda,photo/film}'}),
#  983: frozenset({'{frankfurter,onions,butter,processed cheese,rolls/buns,coffee,bottled beer}'}),
#  984: frozenset({'{pip fruit,root vegetables,dessert,yogurt,domestic eggs,shopping bags}'}),
#  985: frozenset({'{frankfurter,whole milk,coffee,detergent}'}),
#  986: frozenset({'{whole milk,newspapers}'}),
#  987: frozenset({'{domestic eggs,hygiene articles,photo/film,flower soil/fertilizer}'}),
#  988: frozenset({'{packaged fruit/vegetables,dessert,mayonnaise,oil,soda,waffles,chocolate,flower (seeds),shopping bags}'}),
#  989: frozenset({'{chicken,other vegetables,whipped/sour cream,frozen vegetables,bottled water,long life bakery product}'}),
#  990: frozenset({'{pork,whole milk,curd,yogurt,whipped/sour cream,cream cheese ,domestic eggs,white bread,sugar,baking powder,coffee,cocoa drinks,salty snack,waffles,candy,napkins}'}),
#  991: frozenset({'{citrus fruit,other vegetables,whole milk,curd,yogurt,whipped/sour cream,cream cheese ,pastry,vinegar,oil,coffee,long life bakery product,detergent,cleaner,napkins,newspapers}'}),
#  992: frozenset({'{light bulbs}'}),
#  993: frozenset({'{cream cheese ,margarine,tea}'}),
#  994: frozenset({'{sausage,curd,frozen meals,domestic eggs,cake bar,seasonal products,detergent,cleaner,house keeping products,pot plants,shopping bags}'}),
#  995: frozenset({'{citrus fruit,onions}'}),
#  996: frozenset({'{other vegetables,whipped/sour cream,roll products }'}),
#  997: frozenset({'{chicken,tropical fruit,pip fruit,root vegetables,other vegetables,whole milk,butter,yogurt,whipped/sour cream,hard cheese,frozen vegetables,frozen fish,domestic eggs,white bread,rice,specialty fat,dog food,bottled water,fruit/vegetable juice,long life bakery product,softener,napkins,cling film/bags}'}),
#  998: frozenset({'{ice cream}'}),
#  999: frozenset({'{pork,beef,ice cream,rolls/buns,newspapers}'}),
#  1000: frozenset({'{pork,tropical fruit,other vegetables,yogurt,semi-finished bread,flour,margarine,artif. sweetener,organic products,chocolate marshmallow}'}),
#  ...}

# %% [markdown]
# 原始数据提取出之后发现字典的值是字符串格式，多个项合成了一个字符串。我们无法直接对一个字符串进行操作，因此继续对字典的值进行字符串切割，提取出其中的项。
#
# 考虑到后面我们需要对项数进行统计，这里使用了不可变集合数据结构，每一个元素在添加后是确定的，可以生成一个对应的哈希值作为字典的关键字，便于我们后续处理。

# %%
Data={}
# tmp=set()
for item in data:
    for record in data[item]:
        for x in re.split(r'[{}]',record):
            if x == '':
                continue
            else:
#                 print(re.split(r'[,]',x))
                Data[item]= frozenset(re.split(r'[,]',x))                 
Data
# Out:
# {1: frozenset({'citrus fruit',
#             'margarine',
#             'ready soups',
#             'semi-finished bread'}),
#  2: frozenset({'coffee', 'tropical fruit', 'yogurt'}),
#  3: frozenset({'whole milk'}),
#  4: frozenset({'cream cheese ', 'meat spreads', 'pip fruit', 'yogurt'}),
#  5: frozenset({'condensed milk',
#             'long life bakery product',
#             'other vegetables',
#             'whole milk'}),
#  6: frozenset({'abrasive cleaner', 'butter', 'rice', 'whole milk', 'yogurt'}),
#  7: frozenset({'rolls/buns'}),
#  8: frozenset({'UHT-milk',
#             'bottled beer',
#             'liquor (appetizer)',
#             'other vegetables',
#             'rolls/buns'}),
#  9: frozenset({'pot plants'}),
#  10: frozenset({'cereals', 'whole milk'}),
#  11: frozenset({'bottled water',
#             'chocolate',
#             'other vegetables',
#             'tropical fruit',
#             'white bread'}),
#  12: frozenset({'bottled water',
#             'butter',
#             'citrus fruit',
#             'curd',
#             'dishes',
#             'flour',
#             'tropical fruit',
#             'whole milk',
#             'yogurt'}),
#  13: frozenset({'beef'}),
#  14: frozenset({'frankfurter', 'rolls/buns', 'soda'}),
#  15: frozenset({'chicken', 'tropical fruit'}),
#  16: frozenset({'butter', 'fruit/vegetable juice', 'newspapers', 'sugar'}),
#  17: frozenset({'fruit/vegetable juice'}),
#  18: frozenset({'packaged fruit/vegetables'}),
#  19: frozenset({'chocolate'}),
#  20: frozenset({'specialty bar'}),
#  21: frozenset({'other vegetables'}),
#  22: frozenset({'butter milk', 'pastry'}),
#  23: frozenset({'whole milk'}),
#  24: frozenset({'cream cheese ',
#             'detergent',
#             'newspapers',
#             'processed cheese',
#             'tropical fruit'}),
#  25: frozenset({'bathroom cleaner',
#             'candy',
#             'flour',
#             'frozen dessert',
#             'other vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'salty snack',
#             'sweet spreads',
#             'tropical fruit',
#             'waffles'}),
#  26: frozenset({'bottled water', 'canned beer'}),
#  27: frozenset({'yogurt'}),
#  28: frozenset({'chocolate', 'rolls/buns', 'sausage', 'soda'}),
#  29: frozenset({'other vegetables'}),
#  30: frozenset({'brown bread',
#             'canned beer',
#             'fruit/vegetable juice',
#             'newspapers',
#             'shopping bags',
#             'soda'}),
#  31: frozenset({'beverages', 'bottled water', 'specialty bar', 'yogurt'}),
#  32: frozenset({'bottled water',
#             'hamburger meat',
#             'hygiene articles',
#             'napkins',
#             'other vegetables',
#             'rolls/buns',
#             'spices'}),
#  33: frozenset({'beverages',
#             'other vegetables',
#             'root vegetables',
#             'sugar',
#             'whole milk'}),
#  34: frozenset({'abrasive cleaner',
#             'artif. sweetener',
#             'berries',
#             'other vegetables',
#             'pork',
#             'soda',
#             'whipped/sour cream',
#             'whole milk'}),
#  35: frozenset({'beef', 'detergent', 'grapes'}),
#  36: frozenset({'pastry', 'soda'}),
#  37: frozenset({'fruit/vegetable juice'}),
#  38: frozenset({'canned beer'}),
#  39: frozenset({'dessert',
#             'other vegetables',
#             'root vegetables',
#             'whole milk'}),
#  40: frozenset({'citrus fruit', 'newspapers', 'zwieback'}),
#  41: frozenset({'canned beer',
#             'rolls/buns',
#             'sausage',
#             'shopping bags',
#             'soda',
#             'specialty bar'}),
#  42: frozenset({'brown bread',
#             'candy',
#             'cereals',
#             'coffee',
#             'domestic eggs',
#             'pastry',
#             'root vegetables',
#             'soda',
#             'sugar',
#             'tropical fruit',
#             'waffles',
#             'whole milk',
#             'yogurt'}),
#  43: frozenset({'berries', 'yogurt'}),
#  44: frozenset({'canned beer'}),
#  45: frozenset({'bottled water',
#             'butter milk',
#             'cream cheese ',
#             'newspapers',
#             'rolls/buns',
#             'soda',
#             'spread cheese',
#             'yogurt'}),
#  46: frozenset({'coffee'}),
#  47: frozenset({'bottled water', 'pastry'}),
#  48: frozenset({'rolls/buns'}),
#  49: frozenset({'misc. beverages'}),
#  50: frozenset({'UHT-milk',
#             'bottled water',
#             'butter',
#             'curd',
#             'hard cheese',
#             'long life bakery product',
#             'other vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'whipped/sour cream'}),
#  51: frozenset({'cat food', 'newspapers', 'rolls/buns', 'sausage'}),
#  52: frozenset({'canned beer'}),
#  53: frozenset({'grapes', 'ham', 'other vegetables', 'whole milk'}),
#  54: frozenset({'baking powder',
#             'brown bread',
#             'curd',
#             'domestic eggs',
#             'fruit/vegetable juice',
#             'margarine',
#             'other vegetables',
#             'semi-finished bread',
#             'tropical fruit',
#             'turkey'}),
#  55: frozenset({'pickled vegetables',
#             'processed cheese',
#             'soda',
#             'whole milk',
#             'yogurt'}),
#  56: frozenset({'curd', 'pastry', 'whole milk', 'yogurt'}),
#  57: frozenset({'brown bread', 'canned beer', 'packaged fruit/vegetables'}),
#  58: frozenset({'bottled water',
#             'chewing gum',
#             'chocolate marshmallow',
#             'hygiene articles',
#             'napkins',
#             'oil',
#             'rolls/buns'}),
#  59: frozenset({'beef',
#             'cat food',
#             'ham',
#             'ice cream',
#             'rolls/buns',
#             'whipped/sour cream'}),
#  60: frozenset({'pastry', 'rolls/buns', 'sugar'}),
#  61: frozenset({'canned fish',
#             'detergent',
#             'frozen vegetables',
#             'other vegetables',
#             'salty snack',
#             'seasonal products',
#             'whole milk'}),
#  62: frozenset({'pastry', 'sausage'}),
#  63: frozenset({'beef', 'sausage', 'whole milk'}),
#  64: frozenset({'brown bread',
#             'frankfurter',
#             'rolls/buns',
#             'sugar',
#             'tropical fruit'}),
#  65: frozenset({'pastry', 'rolls/buns', 'soda'}),
#  66: frozenset({'whole milk'}),
#  67: frozenset({'coffee', 'curd cheese'}),
#  68: frozenset({'newspapers', 'red/blush wine'}),
#  69: frozenset({'curd', 'sausage', 'whole milk'}),
#  70: frozenset({'berries',
#             'chocolate',
#             'frozen potato products',
#             'pickled vegetables',
#             'pip fruit',
#             'rolls/buns',
#             'tropical fruit',
#             'whole milk'}),
#  71: frozenset({'red/blush wine'}),
#  72: frozenset({'butter',
#             'candles',
#             'flower (seeds)',
#             'margarine',
#             'specialty chocolate',
#             'specialty fat',
#             'whole milk'}),
#  73: frozenset({'citrus fruit',
#             'domestic eggs',
#             'frankfurter',
#             'newspapers',
#             'oil',
#             'sparkling wine',
#             'specialty chocolate',
#             'whole milk'}),
#  74: frozenset({'meat spreads', 'soda', 'whole milk'}),
#  75: frozenset({'frozen potato products'}),
#  76: frozenset({'other vegetables', 'rolls/buns', 'sugar', 'whole milk'}),
#  77: frozenset({'butter milk',
#             'citrus fruit',
#             'curd',
#             'pastry',
#             'whole milk'}),
#  78: frozenset({'bottled beer',
#             'bottled water',
#             'flour',
#             'fruit/vegetable juice',
#             'salt'}),
#  79: frozenset({'bottled beer', 'bottled water', 'soda', 'sugar'}),
#  80: frozenset({'coffee', 'frozen meals'}),
#  81: frozenset({'chocolate'}),
#  82: frozenset({'bathroom cleaner',
#             'canned vegetables',
#             'domestic eggs',
#             'frozen vegetables',
#             'fruit/vegetable juice',
#             'margarine',
#             'oil',
#             'rolls/buns',
#             'root vegetables',
#             'whole milk'}),
#  83: frozenset({'frozen vegetables',
#             'hard cheese',
#             'onions',
#             'root vegetables'}),
#  84: frozenset({'candles',
#             'condensed milk',
#             'frozen vegetables',
#             'herbs',
#             'oil',
#             'salt',
#             'white wine'}),
#  85: frozenset({'bottled water'}),
#  86: frozenset({'brandy',
#             'detergent',
#             'onions',
#             'rolls/buns',
#             'root vegetables',
#             'sausage',
#             'yogurt'}),
#  87: frozenset({'coffee', 'newspapers'}),
#  88: frozenset({'other vegetables', 'pork', 'whipped/sour cream'}),
#  89: frozenset({'berries', 'yogurt'}),
#  90: frozenset({'soda'}),
#  91: frozenset({'berries'}),
#  92: frozenset({'candles', 'fruit/vegetable juice', 'salty snack'}),
#  93: frozenset({'butter milk', 'citrus fruit', 'cream cheese ', 'yogurt'}),
#  94: frozenset({'berries',
#             'chocolate',
#             'citrus fruit',
#             'coffee',
#             'hamburger meat',
#             'onions',
#             'pork',
#             'rice',
#             'whipped/sour cream'}),
#  95: frozenset({'detergent'}),
#  96: frozenset({'grapes', 'photo/film'}),
#  97: frozenset({'brown bread',
#             'canned beer',
#             'fruit/vegetable juice',
#             'red/blush wine',
#             'rolls/buns',
#             'sausage',
#             'shopping bags',
#             'sliced cheese',
#             'waffles'}),
#  98: frozenset({'butter',
#             'chicken',
#             'citrus fruit',
#             'detergent',
#             'hamburger meat',
#             'oil',
#             'other vegetables',
#             'pasta',
#             'root vegetables',
#             'tropical fruit'}),
#  99: frozenset({'brown bread', 'whole milk', 'yogurt'}),
#  100: frozenset({'citrus fruit', 'tropical fruit'}),
#  101: frozenset({'misc. beverages', 'soda'}),
#  102: frozenset({'bathroom cleaner',
#             'grapes',
#             'pastry',
#             'pork',
#             'rolls/buns',
#             'sausage',
#             'soda',
#             'specialty bar',
#             'whole milk'}),
#  103: frozenset({'bottled water', 'frankfurter', 'rolls/buns'}),
#  104: frozenset({'bottled beer',
#             'coffee',
#             'fruit/vegetable juice',
#             'napkins',
#             'photo/film',
#             'sausage',
#             'shopping bags',
#             'softener',
#             'whole milk',
#             'yogurt'}),
#  105: frozenset({'soda'}),
#  106: frozenset({'fruit/vegetable juice', 'rolls/buns'}),
#  107: frozenset({'beef',
#             'berries',
#             'brown bread',
#             'citrus fruit',
#             'detergent',
#             'root vegetables'}),
#  108: frozenset({'candy',
#             'cling film/bags',
#             'rolls/buns',
#             'soda',
#             'waffles',
#             'whipped/sour cream',
#             'whole milk'}),
#  109: frozenset({'processed cheese'}),
#  110: frozenset({'pip fruit', 'tropical fruit'}),
#  111: frozenset({'bottled beer',
#             'chewing gum',
#             'dishes',
#             'frankfurter',
#             'oil',
#             'other vegetables',
#             'pickled vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'sausage'}),
#  112: frozenset({'bottled water', 'packaged fruit/vegetables'}),
#  113: frozenset({'bottled water',
#             'dessert',
#             'frozen vegetables',
#             'margarine',
#             'newspapers',
#             'red/blush wine',
#             'rolls/buns',
#             'whole milk'}),
#  114: frozenset({'berries', 'whipped/sour cream'}),
#  115: frozenset({'UHT-milk', 'berries', 'citrus fruit', 'processed cheese'}),
#  116: frozenset({'tropical fruit', 'whole milk', 'yogurt'}),
#  117: frozenset({'bottled beer',
#             'frozen vegetables',
#             'hamburger meat',
#             'rolls/buns',
#             'sparkling wine',
#             'whole milk'}),
#  118: frozenset({'dishes',
#             'domestic eggs',
#             'frozen vegetables',
#             'hamburger meat',
#             'other vegetables',
#             'soda',
#             'whole milk'}),
#  119: frozenset({'cream cheese ', 'soda', 'whole milk'}),
#  120: frozenset({'coffee',
#             'fish',
#             'long life bakery product',
#             'male cosmetics',
#             'margarine',
#             'other vegetables',
#             'pastry',
#             'shopping bags'}),
#  121: frozenset({'frankfurter',
#             'long life bakery product',
#             'sausage',
#             'waffles'}),
#  122: frozenset({'canned beer',
#             'dessert',
#             'packaged fruit/vegetables',
#             'semi-finished bread'}),
#  123: frozenset({'pastry', 'soda'}),
#  124: frozenset({'other vegetables', 'red/blush wine'}),
#  125: frozenset({'misc. beverages'}),
#  126: frozenset({'canned fruit',
#             'citrus fruit',
#             'cream cheese ',
#             'domestic eggs',
#             'frankfurter',
#             'fruit/vegetable juice',
#             'hard cheese',
#             'hygiene articles',
#             'misc. beverages',
#             'pip fruit',
#             'rice',
#             'sausage',
#             'sugar',
#             'tropical fruit',
#             'whole milk'}),
#  127: frozenset({'sparkling wine'}),
#  128: frozenset({'specialty bar'}),
#  129: frozenset({'butter milk', 'rolls/buns', 'sausage'}),
#  130: frozenset({'curd cheese'}),
#  131: frozenset({'dessert', 'frankfurter'}),
#  132: frozenset({'beverages',
#             'brown bread',
#             'shopping bags',
#             'whole milk',
#             'yogurt'}),
#  133: frozenset({'newspapers'}),
#  134: frozenset({'berries', 'soda'}),
#  135: frozenset({'curd', 'flour', 'liquor (appetizer)'}),
#  136: frozenset({'coffee', 'other vegetables', 'tropical fruit'}),
#  137: frozenset({'soda'}),
#  138: frozenset({'Instant food products', 'rolls/buns'}),
#  139: frozenset({'canned beer'}),
#  140: frozenset({'canned beer'}),
#  141: frozenset({'frankfurter',
#             'margarine',
#             'rolls/buns',
#             'sausage',
#             'whole milk'}),
#  142: frozenset({'canned beer', 'misc. beverages', 'other vegetables'}),
#  143: frozenset({'frozen vegetables', 'whole milk'}),
#  144: frozenset({'whole milk'}),
#  145: frozenset({'butter',
#             'citrus fruit',
#             'cream cheese ',
#             'margarine',
#             'newspapers',
#             'oil',
#             'white bread'}),
#  146: frozenset({'frankfurter', 'rolls/buns'}),
#  147: frozenset({'baking powder',
#             'frankfurter',
#             'frozen vegetables',
#             'ham',
#             'other vegetables',
#             'pip fruit',
#             'rolls/buns',
#             'soft cheese',
#             'sugar',
#             'whole milk'}),
#  148: frozenset({'butter milk', 'detergent', 'honey', 'soda', 'yogurt'}),
#  149: frozenset({'bottled water',
#             'citrus fruit',
#             'dental care',
#             'hamburger meat',
#             'onions',
#             'rolls/buns'}),
#  150: frozenset({'pasta', 'popcorn'}),
#  151: frozenset({'cake bar',
#             'chocolate',
#             'meat spreads',
#             'other vegetables',
#             'shopping bags',
#             'whole milk'}),
#  152: frozenset({'candles',
#             'citrus fruit',
#             'dessert',
#             'dishes',
#             'pork',
#             'sausage',
#             'white bread'}),
#  153: frozenset({'rolls/buns'}),
#  154: frozenset({'curd',
#             'dessert',
#             'grapes',
#             'napkins',
#             'other vegetables',
#             'yogurt'}),
#  155: frozenset({'beverages',
#             'bottled beer',
#             'frozen vegetables',
#             'fruit/vegetable juice',
#             'other vegetables',
#             'root vegetables',
#             'soft cheese',
#             'whole milk',
#             'yogurt'}),
#  156: frozenset({'coffee', 'shopping bags'}),
#  157: frozenset({'popcorn'}),
#  158: frozenset({'bottled water',
#             'rolls/buns',
#             'soda',
#             'sugar',
#             'whole milk'}),
#  159: frozenset({'other vegetables',
#             'packaged fruit/vegetables',
#             'snack products',
#             'tropical fruit',
#             'whole milk'}),
#  160: frozenset({'beef',
#             'cling film/bags',
#             'flour',
#             'flower soil/fertilizer',
#             'herbs'}),
#  161: frozenset({'butter', 'dessert', 'rolls/buns', 'whole milk'}),
#  162: frozenset({'chewing gum', 'frankfurter', 'soda'}),
#  163: frozenset({'bottled water', 'specialty cheese', 'tropical fruit'}),
#  164: frozenset({'canned beer'}),
#  165: frozenset({'bottled beer',
#             'finished products',
#             'frozen vegetables',
#             'other vegetables'}),
#  166: frozenset({'beverages', 'soda'}),
#  167: frozenset({'hamburger meat', 'root vegetables', 'whole milk'}),
#  168: frozenset({'long life bakery product', 'pastry', 'whole milk'}),
#  169: frozenset({'finished products', 'shopping bags', 'white wine'}),
#  170: frozenset({'other vegetables'}),
#  171: frozenset({'bottled beer',
#             'brown bread',
#             'fruit/vegetable juice',
#             'ham',
#             'other vegetables',
#             'tropical fruit',
#             'white bread',
#             'whole milk'}),
#  172: frozenset({'other vegetables'}),
#  173: frozenset({'butter milk',
#             'cocoa drinks',
#             'curd',
#             'popcorn',
#             'salty snack'}),
#  174: frozenset({'bottled beer'}),
#  175: frozenset({'cake bar',
#             'chocolate',
#             'curd',
#             'dessert',
#             'salty snack',
#             'shopping bags',
#             'soda',
#             'waffles'}),
#  176: frozenset({'cereals', 'cream cheese ', 'dog food', 'whole milk'}),
#  177: frozenset({'salt', 'whole milk'}),
#  178: frozenset({'dessert', 'ice cream'}),
#  179: frozenset({'coffee', 'sausage', 'soft cheese'}),
#  180: frozenset({'bottled water',
#             'dishes',
#             'other vegetables',
#             'shopping bags',
#             'waffles'}),
#  181: frozenset({'ham', 'rolls/buns', 'whole milk'}),
#  182: frozenset({'ice cream', 'other vegetables'}),
#  183: frozenset({'bottled water', 'other vegetables'}),
#  184: frozenset({'bottled beer', 'prosecco', 'soda', 'white wine'}),
#  185: frozenset({'candy', 'herbs'}),
#  186: frozenset({'bottled beer',
#             'butter',
#             'cereals',
#             'cream cheese ',
#             'curd',
#             'domestic eggs',
#             'frankfurter',
#             'frozen fish',
#             'frozen meals',
#             'fruit/vegetable juice',
#             'ham',
#             'other vegetables',
#             'pip fruit',
#             'root vegetables',
#             'sliced cheese',
#             'soft cheese',
#             'sugar',
#             'tropical fruit',
#             'waffles',
#             'whipped/sour cream',
#             'white bread',
#             'whole milk',
#             'yogurt'}),
#  187: frozenset({'canned beer', 'rolls/buns'}),
#  188: frozenset({'cake bar',
#             'cream cheese ',
#             'curd',
#             'semi-finished bread',
#             'shopping bags',
#             'specialty bar',
#             'zwieback'}),
#  189: frozenset({'frankfurter',
#             'margarine',
#             'shopping bags',
#             'spread cheese',
#             'tropical fruit',
#             'whole milk'}),
#  190: frozenset({'other vegetables'}),
#  191: frozenset({'dog food'}),
#  192: frozenset({'specialty bar'}),
#  193: frozenset({'curd',
#             'detergent',
#             'liquor (appetizer)',
#             'salt',
#             'shopping bags'}),
#  194: frozenset({'frankfurter', 'rolls/buns'}),
#  195: frozenset({'soda'}),
#  196: frozenset({'beef',
#             'berries',
#             'brown bread',
#             'dessert',
#             'root vegetables',
#             'spread cheese',
#             'whole milk'}),
#  197: frozenset({'canned beer'}),
#  198: frozenset({'beef', 'herbs', 'pip fruit', 'pork', 'spices'}),
#  199: frozenset({'UHT-milk',
#             'citrus fruit',
#             'frankfurter',
#             'margarine',
#             'sugar'}),
#  200: frozenset({'bottled beer', 'liquor (appetizer)', 'sausage'}),
#  201: frozenset({'canned beer'}),
#  202: frozenset({'specialty chocolate'}),
#  203: frozenset({'curd', 'rolls/buns'}),
#  204: frozenset({'canned beer'}),
#  205: frozenset({'bottled water', 'newspapers', 'whole milk'}),
#  206: frozenset({'chewing gum', 'rolls/buns'}),
#  207: frozenset({'dishes',
#             'other vegetables',
#             'pork',
#             'root vegetables',
#             'whole milk'}),
#  208: frozenset({'citrus fruit', 'pastry'}),
#  209: frozenset({'pot plants'}),
#  210: frozenset({'pastry', 'rolls/buns', 'soda'}),
#  211: frozenset({'bottled water',
#             'butter',
#             'hygiene articles',
#             'make up remover',
#             'soda',
#             'yogurt'}),
#  212: frozenset({'coffee', 'condensed milk', 'shopping bags', 'sugar'}),
#  213: frozenset({'other vegetables',
#             'sausage',
#             'shopping bags',
#             'soda',
#             'yogurt'}),
#  214: frozenset({'UHT-milk', 'beverages', 'soda', 'whole milk'}),
#  215: frozenset({'beef',
#             'margarine',
#             'pork',
#             'rolls/buns',
#             'sausage',
#             'whole milk'}),
#  216: frozenset({'beverages'}),
#  217: frozenset({'beverages', 'specialty bar'}),
#  218: frozenset({'bottled water', 'fruit/vegetable juice'}),
#  219: frozenset({'newspapers'}),
#  220: frozenset({'cleaner', 'female sanitary products'}),
#  221: frozenset({'newspapers', 'sausage', 'shopping bags', 'soda'}),
#  222: frozenset({'newspapers'}),
#  223: frozenset({'beef',
#             'beverages',
#             'butter milk',
#             'citrus fruit',
#             'cookware',
#             'dish cleaner',
#             'hard cheese',
#             'other vegetables',
#             'rolls/buns',
#             'sausage',
#             'whipped/sour cream',
#             'whole milk'}),
#  224: frozenset({'misc. beverages', 'newspapers'}),
#  225: frozenset({'white wine'}),
#  226: frozenset({'canned beer',
#             'rolls/buns',
#             'sausage',
#             'shopping bags',
#             'sliced cheese',
#             'soda'}),
#  227: frozenset({'bottled beer', 'cake bar', 'curd', 'meat'}),
#  228: frozenset({'baking powder',
#             'cling film/bags',
#             'frankfurter',
#             'meat',
#             'oil',
#             'onions',
#             'tea',
#             'tropical fruit'}),
#  229: frozenset({'canned beer', 'ice cream', 'rolls/buns'}),
#  230: frozenset({'canned beer'}),
#  231: frozenset({'berries',
#             'bottled water',
#             'other vegetables',
#             'root vegetables',
#             'shopping bags',
#             'tropical fruit'}),
#  232: frozenset({'beverages',
#             'bottled water',
#             'brown bread',
#             'butter milk',
#             'citrus fruit',
#             'cream cheese ',
#             'curd',
#             'dessert',
#             'meat',
#             'other vegetables',
#             'rolls/buns',
#             'tea'}),
#  233: frozenset({'bottled water', 'mustard', 'whole milk'}),
#  234: frozenset({'beef',
#             'beverages',
#             'flower (seeds)',
#             'house keeping products',
#             'rolls/buns',
#             'sausage',
#             'sliced cheese',
#             'spices'}),
#  235: frozenset({'butter',
#             'curd',
#             'frankfurter',
#             'long life bakery product',
#             'rolls/buns',
#             'root vegetables',
#             'salty snack',
#             'sausage',
#             'sliced cheese'}),
#  236: frozenset({'butter', 'meat', 'other vegetables', 'rolls/buns'}),
#  237: frozenset({'Instant food products',
#             'beverages',
#             'detergent',
#             'pickled vegetables',
#             'root vegetables'}),
#  238: frozenset({'herbs',
#             'other vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'sliced cheese',
#             'whole milk'}),
#  239: frozenset({'margarine',
#             'semi-finished bread',
#             'whipped/sour cream',
#             'whole milk'}),
#  240: frozenset({'canned fish',
#             'canned vegetables',
#             'cereals',
#             'citrus fruit',
#             'curd',
#             'dessert',
#             'frozen dessert',
#             'hygiene articles',
#             'napkins',
#             'rolls/buns',
#             'salt',
#             'skin care',
#             'sugar',
#             'whipped/sour cream',
#             'whole milk',
#             'yogurt'}),
#  241: frozenset({'candy',
#             'citrus fruit',
#             'curd',
#             'margarine',
#             'newspapers',
#             'pastry',
#             'sugar'}),
#  242: frozenset({'bottled beer',
#             'bottled water',
#             'misc. beverages',
#             'napkins',
#             'other vegetables',
#             'red/blush wine',
#             'soda',
#             'whole milk'}),
#  243: frozenset({'citrus fruit', 'rolls/buns', 'whole milk'}),
#  244: frozenset({'hygiene articles', 'napkins', 'oil', 'sausage'}),
#  245: frozenset({'beef',
#             'bottled beer',
#             'bottled water',
#             'butter',
#             'frankfurter',
#             'frozen dessert',
#             'grapes',
#             'hamburger meat',
#             'potato products',
#             'root vegetables',
#             'whole milk'}),
#  246: frozenset({'bottled water', 'hard cheese', 'newspapers', 'rolls/buns'}),
#  247: frozenset({'chocolate', 'cream cheese ', 'rolls/buns', 'soda'}),
#  248: frozenset({'beef',
#             'dishes',
#             'frozen vegetables',
#             'photo/film',
#             'turkey'}),
#  249: frozenset({'other vegetables',
#             'pork',
#             'rolls/buns',
#             'shopping bags',
#             'soda',
#             'whipped/sour cream'}),
#  250: frozenset({'beverages', 'whole milk'}),
#  251: frozenset({'rolls/buns', 'soda'}),
#  252: frozenset({'bottled water',
#             'curd',
#             'hygiene articles',
#             'pip fruit',
#             'rolls/buns',
#             'sausage',
#             'sliced cheese',
#             'whole milk',
#             'yogurt'}),
#  253: frozenset({'ice cream'}),
#  254: frozenset({'liquor'}),
#  255: frozenset({'fruit/vegetable juice', 'other vegetables', 'pip fruit'}),
#  256: frozenset({'other vegetables', 'root vegetables', 'yogurt'}),
#  257: frozenset({'soda'}),
#  258: frozenset({'soda'}),
#  259: frozenset({'bottled water',
#             'chocolate',
#             'citrus fruit',
#             'newspapers',
#             'other vegetables',
#             'rolls/buns',
#             'sausage',
#             'soda',
#             'tropical fruit',
#             'whole milk',
#             'yogurt'}),
#  260: frozenset({'detergent', 'pet care', 'root vegetables', 'whole milk'}),
#  261: frozenset({'berries',
#             'other vegetables',
#             'pastry',
#             'pork',
#             'root vegetables',
#             'specialty bar'}),
#  262: frozenset({'pork'}),
#  263: frozenset({'chocolate'}),
#  264: frozenset({'fruit/vegetable juice'}),
#  265: frozenset({'coffee', 'pickled vegetables'}),
#  266: frozenset({'bottled water'}),
#  267: frozenset({'butter',
#             'frankfurter',
#             'margarine',
#             'rolls/buns',
#             'sausage',
#             'spices',
#             'whipped/sour cream'}),
#  268: frozenset({'domestic eggs',
#             'hygiene articles',
#             'napkins',
#             'onions',
#             'other vegetables',
#             'pip fruit',
#             'soda',
#             'soups',
#             'sugar',
#             'tea',
#             'tropical fruit',
#             'whole milk'}),
#  269: frozenset({'canned beer'}),
#  270: frozenset({'root vegetables'}),
#  271: frozenset({'berries',
#             'citrus fruit',
#             'meat',
#             'root vegetables',
#             'soda',
#             'whole milk'}),
#  272: frozenset({'bottled water',
#             'frankfurter',
#             'fruit/vegetable juice',
#             'hygiene articles',
#             'rolls/buns'}),
#  273: frozenset({'margarine', 'rum', 'tropical fruit'}),
#  274: frozenset({'butter milk',
#             'flour',
#             'herbs',
#             'hygiene articles',
#             'root vegetables',
#             'tropical fruit',
#             'whipped/sour cream',
#             'whole milk'}),
#  275: frozenset({'baking powder',
#             'brown bread',
#             'citrus fruit',
#             'cream cheese ',
#             'domestic eggs',
#             'margarine',
#             'other vegetables',
#             'pip fruit',
#             'root vegetables',
#             'waffles',
#             'whole milk'}),
#  276: frozenset({'bottled water',
#             'curd',
#             'fruit/vegetable juice',
#             'hamburger meat',
#             'margarine',
#             'other vegetables',
#             'pastry',
#             'rolls/buns',
#             'semi-finished bread',
#             'whole milk',
#             'yogurt'}),
#  277: frozenset({'chicken',
#             'dessert',
#             'other vegetables',
#             'pasta',
#             'pip fruit',
#             'rolls/buns',
#             'soda',
#             'waffles',
#             'whipped/sour cream',
#             'whole milk',
#             'yogurt'}),
#  278: frozenset({'chicken',
#             'citrus fruit',
#             'frozen fish',
#             'rolls/buns',
#             'root vegetables',
#             'tropical fruit',
#             'whole milk'}),
#  279: frozenset({'citrus fruit',
#             'frankfurter',
#             'onions',
#             'other vegetables',
#             'rolls/buns',
#             'soda',
#             'sugar',
#             'whole milk'}),
#  280: frozenset({'canned beer'}),
#  281: frozenset({'pastry', 'pip fruit', 'salad dressing', 'turkey'}),
#  282: frozenset({'bottled water',
#             'brown bread',
#             'curd',
#             'domestic eggs',
#             'misc. beverages',
#             'mustard',
#             'packaged fruit/vegetables',
#             'pickled vegetables',
#             'whole milk',
#             'yogurt'}),
#  283: frozenset({'pasta'}),
#  284: frozenset({'citrus fruit', 'tropical fruit'}),
#  285: frozenset({'brown bread',
#             'pot plants',
#             'rolls/buns',
#             'sausage',
#             'whole milk',
#             'yogurt'}),
#  286: frozenset({'frozen meals',
#             'fruit/vegetable juice',
#             'pastry',
#             'waffles',
#             'whole milk'}),
#  287: frozenset({'canned beer'}),
#  288: frozenset({'citrus fruit', 'sauces', 'sugar'}),
#  289: frozenset({'liquor (appetizer)'}),
#  290: frozenset({'citrus fruit',
#             'other vegetables',
#             'rolls/buns',
#             'salty snack',
#             'shopping bags'}),
#  291: frozenset({'sausage'}),
#  292: frozenset({'bottled water',
#             'canned beer',
#             'chicken',
#             'napkins',
#             'newspapers',
#             'oil',
#             'other vegetables',
#             'vinegar',
#             'whole milk'}),
#  293: frozenset({'flour',
#             'hamburger meat',
#             'margarine',
#             'other vegetables',
#             'root vegetables',
#             'specialty cheese',
#             'whipped/sour cream',
#             'whole milk',
#             'yogurt'}),
#  294: frozenset({'dessert',
#             'oil',
#             'other vegetables',
#             'pork',
#             'sausage',
#             'soda',
#             'yogurt'}),
#  295: frozenset({'abrasive cleaner',
#             'beef',
#             'berries',
#             'root vegetables',
#             'whipped/sour cream',
#             'whole milk'}),
#  296: frozenset({'bottled water',
#             'citrus fruit',
#             'packaged fruit/vegetables',
#             'yogurt'}),
#  297: frozenset({'UHT-milk', 'coffee'}),
#  298: frozenset({'candy'}),
#  299: frozenset({'newspapers'}),
#  300: frozenset({'beef', 'citrus fruit', 'other vegetables', 'yogurt'}),
#  301: frozenset({'rolls/buns', 'sausage'}),
#  302: frozenset({'beef',
#             'canned beer',
#             'curd',
#             'dessert',
#             'frankfurter',
#             'hygiene articles',
#             'mustard',
#             'napkins',
#             'pickled vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'soft cheese',
#             'yogurt'}),
#  303: frozenset({'canned beer'}),
#  304: frozenset({'bottled beer'}),
#  305: frozenset({'chewing gum', 'chocolate', 'newspapers', 'onions', 'soda'}),
#  306: frozenset({'candy',
#             'cream cheese ',
#             'packaged fruit/vegetables',
#             'tropical fruit',
#             'white bread'}),
#  307: frozenset({'bottled water', 'white wine'}),
#  308: frozenset({'beef', 'pasta', 'pastry', 'soap', 'white bread'}),
#  309: frozenset({'abrasive cleaner',
#             'candy',
#             'chicken',
#             'cleaner',
#             'root vegetables',
#             'sausage',
#             'tropical fruit',
#             'whole milk',
#             'yogurt'}),
#  310: frozenset({'hair spray'}),
#  311: frozenset({'chicken',
#             'long life bakery product',
#             'shopping bags',
#             'spices',
#             'whole milk'}),
#  312: frozenset({'brown bread',
#             'cat food',
#             'citrus fruit',
#             'pastry',
#             'pork',
#             'sugar'}),
#  313: frozenset({'ice cream'}),
#  314: frozenset({'bottled beer', 'hard cheese', 'meat'}),
#  315: frozenset({'brown bread',
#             'instant coffee',
#             'other vegetables',
#             'yogurt'}),
#  316: frozenset({'bottled water', 'cake bar'}),
#  317: frozenset({'salty snack', 'soda', 'tropical fruit'}),
#  318: frozenset({'photo/film'}),
#  319: frozenset({'canned beer',
#             'citrus fruit',
#             'coffee',
#             'dishes',
#             'sausage',
#             'soda',
#             'yogurt'}),
#  320: frozenset({'grapes', 'root vegetables'}),
#  321: frozenset({'brown bread', 'domestic eggs', 'photo/film'}),
#  322: frozenset({'canned beer', 'canned fish', 'rolls/buns'}),
#  323: frozenset({'tropical fruit', 'whole milk'}),
#  324: frozenset({'chicken'}),
#  325: frozenset({'bottled water',
#             'brown bread',
#             'frankfurter',
#             'other vegetables',
#             'yogurt'}),
#  326: frozenset({'berries',
#             'butter milk',
#             'cream cheese ',
#             'curd',
#             'detergent',
#             'margarine',
#             'misc. beverages',
#             'other vegetables',
#             'roll products ',
#             'root vegetables',
#             'specialty chocolate'}),
#  327: frozenset({'hygiene articles', 'margarine'}),
#  328: frozenset({'rolls/buns',
#             'shopping bags',
#             'soda',
#             'tropical fruit',
#             'yogurt'}),
#  329: frozenset({'candy',
#             'chocolate',
#             'ham',
#             'hard cheese',
#             'misc. beverages',
#             'other vegetables',
#             'rolls/buns',
#             'soda',
#             'whipped/sour cream'}),
#  330: frozenset({'hamburger meat', 'salty snack', 'white bread'}),
#  331: frozenset({'mayonnaise', 'napkins', 'rolls/buns', 'soda', 'yogurt'}),
#  332: frozenset({'soda', 'specialty chocolate'}),
#  333: frozenset({'yogurt'}),
#  334: frozenset({'soda'}),
#  335: frozenset({'bottled water'}),
#  336: frozenset({'hamburger meat', 'meat', 'rubbing alcohol', 'sausage'}),
#  337: frozenset({'beverages',
#             'citrus fruit',
#             'fruit/vegetable juice',
#             'hard cheese',
#             'pet care',
#             'pip fruit',
#             'soda',
#             'waffles'}),
#  338: frozenset({'shopping bags'}),
#  339: frozenset({'newspapers'}),
#  340: frozenset({'curd',
#             'dish cleaner',
#             'frankfurter',
#             'frozen potato products',
#             'other vegetables',
#             'specialty bar',
#             'whole milk',
#             'zwieback'}),
#  341: frozenset({'canned beer', 'citrus fruit', 'sausage', 'whole milk'}),
#  342: frozenset({'frankfurter', 'rolls/buns'}),
#  343: frozenset({'cookware', 'salt', 'salty snack'}),
#  344: frozenset({'oil'}),
#  345: frozenset({'beverages',
#             'cake bar',
#             'chewing gum',
#             'cream cheese ',
#             'curd',
#             'pastry',
#             'rolls/buns',
#             'soda'}),
#  346: frozenset({'butter', 'other vegetables', 'specialty chocolate'}),
#  347: frozenset({'citrus fruit'}),
#  348: frozenset({'butter milk', 'frankfurter', 'whole milk'}),
#  349: frozenset({'butter',
#             'mayonnaise',
#             'processed cheese',
#             'root vegetables',
#             'salty snack',
#             'whole milk'}),
#  350: frozenset({'bottled beer',
#             'frozen meals',
#             'tropical fruit',
#             'whole milk'}),
#  351: frozenset({'beef', 'hamburger meat', 'pip fruit'}),
#  352: frozenset({'berries',
#             'cereals',
#             'shopping bags',
#             'waffles',
#             'whipped/sour cream'}),
#  353: frozenset({'canned beer'}),
#  354: frozenset({'canned beer', 'red/blush wine', 'whipped/sour cream'}),
#  355: frozenset({'candy',
#             'chocolate marshmallow',
#             'domestic eggs',
#             'margarine',
#             'root vegetables'}),
#  356: frozenset({'soda', 'whole milk'}),
#  357: frozenset({'beef'}),
#  358: frozenset({'frozen vegetables'}),
#  359: frozenset({'bottled beer', 'rolls/buns'}),
#  360: frozenset({'hygiene articles', 'whole milk'}),
#  361: frozenset({'whole milk'}),
#  362: frozenset({'citrus fruit', 'curd', 'soft cheese', 'whole milk'}),
#  363: frozenset({'fruit/vegetable juice', 'pastry'}),
#  364: frozenset({'brown bread',
#             'butter',
#             'frankfurter',
#             'pip fruit',
#             'pork',
#             'processed cheese',
#             'sausage',
#             'white bread'}),
#  365: frozenset({'domestic eggs',
#             'root vegetables',
#             'tropical fruit',
#             'whipped/sour cream',
#             'whole milk'}),
#  366: frozenset({'frankfurter',
#             'napkins',
#             'pastry',
#             'root vegetables',
#             'sausage',
#             'whipped/sour cream',
#             'yogurt'}),
#  367: frozenset({'berries',
#             'cat food',
#             'curd',
#             'curd cheese',
#             'detergent',
#             'other vegetables',
#             'packaged fruit/vegetables',
#             'root vegetables',
#             'specialty bar',
#             'whole milk'}),
#  368: frozenset({'bottled beer',
#             'brown bread',
#             'coffee',
#             'pastry',
#             'rolls/buns'}),
#  369: frozenset({'coffee',
#             'curd',
#             'dessert',
#             'frozen vegetables',
#             'packaged fruit/vegetables',
#             'root vegetables',
#             'specialty fat'}),
#  370: frozenset({'yogurt'}),
#  371: frozenset({'bottled water', 'other vegetables'}),
#  372: frozenset({'berries', 'white bread'}),
#  373: frozenset({'berries', 'coffee'}),
#  374: frozenset({'bottled water',
#             'butter milk',
#             'frozen meals',
#             'other vegetables'}),
#  375: frozenset({'newspapers', 'rolls/buns'}),
#  376: frozenset({'citrus fruit',
#             'ham',
#             'hygiene articles',
#             'pastry',
#             'rolls/buns',
#             'waffles',
#             'whipped/sour cream',
#             'whole milk'}),
#  377: frozenset({'frozen dessert', 'napkins', 'salty snack', 'whole milk'}),
#  378: frozenset({'bottled water',
#             'butter milk',
#             'rolls/buns',
#             'tropical fruit'}),
#  379: frozenset({'bottled water'}),
#  380: frozenset({'butter milk', 'yogurt'}),
#  381: frozenset({'newspapers'}),
#  382: frozenset({'coffee'}),
#  383: frozenset({'bottled beer', 'liquor'}),
#  384: frozenset({'butter',
#             'candy',
#             'cling film/bags',
#             'frozen vegetables',
#             'hard cheese',
#             'napkins',
#             'onions',
#             'pasta',
#             'specialty fat',
#             'syrup',
#             'whipped/sour cream'}),
#  385: frozenset({'dog food',
#             'frozen meals',
#             'hamburger meat',
#             'hard cheese',
#             'pasta',
#             'salty snack',
#             'shopping bags'}),
#  386: frozenset({'cream cheese ',
#             'liver loaf',
#             'other vegetables',
#             'pastry',
#             'sausage',
#             'shopping bags',
#             'soap'}),
#  387: frozenset({'hard cheese', 'napkins', 'pastry'}),
#  388: frozenset({'condensed milk', 'rolls/buns', 'sausage', 'tropical fruit'}),
#  389: frozenset({'hamburger meat'}),
#  390: frozenset({'beverages', 'frozen dessert', 'onions', 'whole milk'}),
#  391: frozenset({'coffee'}),
#  392: frozenset({'shopping bags'}),
#  393: frozenset({'bottled water',
#             'pastry',
#             'rolls/buns',
#             'shopping bags',
#             'soda',
#             'yogurt'}),
#  394: frozenset({'soda'}),
#  395: frozenset({'sliced cheese'}),
#  396: frozenset({'coffee', 'sausage', 'whole milk'}),
#  397: frozenset({'chocolate', 'yogurt'}),
#  398: frozenset({'dish cleaner',
#             'domestic eggs',
#             'hygiene articles',
#             'rolls/buns'}),
#  399: frozenset({'whole milk'}),
#  400: frozenset({'meat',
#             'other vegetables',
#             'whipped/sour cream',
#             'whole milk'}),
#  401: frozenset({'bathroom cleaner',
#             'dish cleaner',
#             'hygiene articles',
#             'napkins'}),
#  402: frozenset({'other vegetables', 'red/blush wine'}),
#  403: frozenset({'butter milk',
#             'coffee',
#             'fruit/vegetable juice',
#             'long life bakery product',
#             'rolls/buns',
#             'shopping bags',
#             'sliced cheese',
#             'sweet spreads',
#             'whole milk',
#             'yogurt'}),
#  404: frozenset({'Instant food products',
#             'other vegetables',
#             'rolls/buns',
#             'whole milk'}),
#  405: frozenset({'other vegetables', 'tropical fruit'}),
#  406: frozenset({'baking powder',
#             'bottled water',
#             'chewing gum',
#             'salty snack'}),
#  407: frozenset({'specialty bar'}),
#  408: frozenset({'ice cream'}),
#  409: frozenset({'frankfurter', 'yogurt'}),
#  410: frozenset({'canned beer'}),
#  411: frozenset({'bottled water'}),
#  412: frozenset({'bottled beer',
#             'bottled water',
#             'margarine',
#             'other vegetables',
#             'rolls/buns',
#             'whole milk'}),
#  413: frozenset({'citrus fruit',
#             'onions',
#             'other vegetables',
#             'shopping bags',
#             'tropical fruit'}),
#  414: frozenset({'ham',
#             'hamburger meat',
#             'newspapers',
#             'sausage',
#             'soda',
#             'softener',
#             'whole milk'}),
#  415: frozenset({'domestic eggs', 'napkins', 'rolls/buns', 'specialty bar'}),
#  416: frozenset({'citrus fruit',
#             'curd',
#             'hygiene articles',
#             'other vegetables',
#             'pork',
#             'root vegetables',
#             'tropical fruit'}),
#  417: frozenset({'coffee',
#             'frozen vegetables',
#             'fruit/vegetable juice',
#             'salty snack',
#             'soda',
#             'specialty cheese'}),
#  418: frozenset({'citrus fruit',
#             'fruit/vegetable juice',
#             'pip fruit',
#             'pork',
#             'sparkling wine',
#             'yogurt'}),
#  419: frozenset({'beef',
#             'berries',
#             'domestic eggs',
#             'rolls/buns',
#             'whipped/sour cream'}),
#  420: frozenset({'other vegetables', 'pet care'}),
#  421: frozenset({'chewing gum',
#             'chicken',
#             'dishes',
#             'rolls/buns',
#             'sliced cheese',
#             'yogurt'}),
#  422: frozenset({'chewing gum', 'soda'}),
#  423: frozenset({'whole milk'}),
#  424: frozenset({'rolls/buns'}),
#  425: frozenset({'bottled beer'}),
#  426: frozenset({'bottled water',
#             'male cosmetics',
#             'pastry',
#             'root vegetables'}),
#  427: frozenset({'pastry'}),
#  428: frozenset({'berries', 'cake bar', 'pet care', 'shopping bags'}),
#  429: frozenset({'bottled water',
#             'canned vegetables',
#             'citrus fruit',
#             'root vegetables',
#             'soda',
#             'softener',
#             'tropical fruit',
#             'yogurt'}),
#  430: frozenset({'canned fruit',
#             'fruit/vegetable juice',
#             'oil',
#             'whole milk'}),
#  431: frozenset({'misc. beverages', 'soda'}),
#  432: frozenset({'bottled water', 'soda'}),
#  433: frozenset({'other vegetables', 'rolls/buns', 'tropical fruit'}),
#  434: frozenset({'salty snack'}),
#  435: frozenset({'bottled water', 'canned beer'}),
#  436: frozenset({'chocolate'}),
#  437: frozenset({'UHT-milk',
#             'citrus fruit',
#             'cream cheese ',
#             'frozen vegetables'}),
#  438: frozenset({'bottled water', 'canned beer', 'male cosmetics'}),
#  439: frozenset({'bottled water',
#             'napkins',
#             'onions',
#             'other vegetables',
#             'pastry',
#             'soda'}),
#  440: frozenset({'cat food', 'dessert', 'oil', 'soda'}),
#  441: frozenset({'beef',
#             'coffee',
#             'dental care',
#             'frozen potato products',
#             'hygiene articles',
#             'margarine',
#             'newspapers',
#             'oil',
#             'other vegetables',
#             'rolls/buns',
#             'whole milk'}),
#  442: frozenset({'bottled beer',
#             'bottled water',
#             'brandy',
#             'canned beer',
#             'misc. beverages',
#             'rolls/buns',
#             'zwieback'}),
#  443: frozenset({'beef',
#             'instant coffee',
#             'onions',
#             'other vegetables',
#             'root vegetables',
#             'soda',
#             'tropical fruit'}),
#  444: frozenset({'soda'}),
#  445: frozenset({'coffee', 'hygiene articles'}),
#  446: frozenset({'bottled water', 'brown bread', 'rolls/buns'}),
#  447: frozenset({'beef',
#             'frozen vegetables',
#             'hamburger meat',
#             'margarine',
#             'other vegetables',
#             'pork',
#             'rolls/buns',
#             'shopping bags',
#             'whole milk'}),
#  448: frozenset({'canned beer',
#             'hygiene articles',
#             'liquor (appetizer)',
#             'napkins',
#             'newspapers',
#             'soda'}),
#  449: frozenset({'ham',
#             'ice cream',
#             'other vegetables',
#             'sausage',
#             'white bread'}),
#  450: frozenset({'beef',
#             'other vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'sugar'}),
#  451: frozenset({'bottled beer', 'bottled water', 'butter', 'whole milk'}),
#  452: frozenset({'house keeping products',
#             'hygiene articles',
#             'ice cream',
#             'pork'}),
#  453: frozenset({'berries',
#             'fruit/vegetable juice',
#             'ice cream',
#             'packaged fruit/vegetables',
#             'salty snack',
#             'specialty bar',
#             'whole milk'}),
#  454: frozenset({'curd',
#             'frozen vegetables',
#             'other vegetables',
#             'roll products ',
#             'rolls/buns',
#             'sausage',
#             'whipped/sour cream',
#             'yogurt'}),
#  455: frozenset({'bottled water', 'cling film/bags', 'misc. beverages'}),
#  456: frozenset({'bottled water',
#             'frozen dessert',
#             'hard cheese',
#             'other vegetables',
#             'packaged fruit/vegetables',
#             'rice',
#             'tropical fruit',
#             'whole milk'}),
#  457: frozenset({'bottled water', 'herbs'}),
#  458: frozenset({'rolls/buns', 'yogurt'}),
#  459: frozenset({'Instant food products'}),
#  460: frozenset({'specialty chocolate'}),
#  461: frozenset({'coffee'}),
#  462: frozenset({'bottled beer', 'liquor'}),
#  463: frozenset({'beef', 'root vegetables'}),
#  464: frozenset({'honey', 'waffles', 'whole milk'}),
#  465: frozenset({'frankfurter',
#             'pastry',
#             'rolls/buns',
#             'snack products',
#             'specialty bar'}),
#  466: frozenset({'curd',
#             'frankfurter',
#             'frozen vegetables',
#             'hygiene articles',
#             'liver loaf',
#             'photo/film',
#             'rolls/buns',
#             'root vegetables',
#             'sausage',
#             'semi-finished bread'}),
# ...
#             'chocolate',
#             'flour',
#             'newspapers',
#             'oil',
#             'pork',
#             'soda',
#             'whipped/sour cream'}),
#  885: frozenset({'white bread'}),
#  886: frozenset({'fruit/vegetable juice',
#             'grapes',
#             'processed cheese',
#             'rolls/buns',
#             'white bread',
#             'whole milk'}),
#  887: frozenset({'flower (seeds)', 'potato products'}),
#  888: frozenset({'bottled water',
#             'coffee',
#             'dishes',
#             'onions',
#             'rolls/buns',
#             'root vegetables',
#             'yogurt'}),
#  889: frozenset({'UHT-milk',
#             'bathroom cleaner',
#             'canned beer',
#             'chicken',
#             'hamburger meat',
#             'newspapers',
#             'soda'}),
#  890: frozenset({'chicken', 'other vegetables', 'salt'}),
#  891: frozenset({'coffee', 'cream cheese ', 'fish'}),
#  892: frozenset({'canned beer'}),
#  893: frozenset({'brown bread',
#             'frozen meals',
#             'napkins',
#             'other vegetables',
#             'rolls/buns',
#             'whole milk'}),
#  894: frozenset({'bottled beer',
#             'brown bread',
#             'chicken',
#             'frozen vegetables',
#             'newspapers',
#             'pork',
#             'red/blush wine',
#             'vinegar',
#             'whole milk'}),
#  895: frozenset({'misc. beverages', 'other vegetables'}),
#  896: frozenset({'tropical fruit', 'whole milk'}),
#  897: frozenset({'cake bar', 'newspapers', 'whole milk'}),
#  898: frozenset({'beef',
#             'berries',
#             'hamburger meat',
#             'hygiene articles',
#             'pastry'}),
#  899: frozenset({'grapes', 'rolls/buns', 'salty snack', 'sausage', 'soda'}),
#  900: frozenset({'chocolate', 'rolls/buns', 'whole milk'}),
#  901: frozenset({'rolls/buns', 'soda'}),
#  902: frozenset({'citrus fruit',
#             'other vegetables',
#             'pip fruit',
#             'tropical fruit'}),
#  903: frozenset({'artif. sweetener',
#             'bottled water',
#             'domestic eggs',
#             'shopping bags',
#             'sliced cheese',
#             'soda',
#             'whole milk'}),
#  904: frozenset({'bottled beer', 'pastry', 'soda'}),
#  905: frozenset({'coffee',
#             'curd cheese',
#             'frozen vegetables',
#             'fruit/vegetable juice',
#             'hard cheese',
#             'hygiene articles',
#             'ice cream',
#             'other vegetables',
#             'pastry',
#             'soft cheese',
#             'spread cheese',
#             'tropical fruit',
#             'whole milk',
#             'yogurt'}),
#  906: frozenset({'newspapers', 'pastry', 'sliced cheese'}),
#  907: frozenset({'soda'}),
#  908: frozenset({'citrus fruit',
#             'coffee',
#             'dessert',
#             'frozen meals',
#             'ham',
#             'popcorn',
#             'shopping bags',
#             'whole milk'}),
#  909: frozenset({'salty snack'}),
#  910: frozenset({'bottled water',
#             'coffee',
#             'cream cheese ',
#             'curd',
#             'flour',
#             'misc. beverages',
#             'newspapers',
#             'whole milk'}),
#  911: frozenset({'root vegetables', 'whipped/sour cream'}),
#  912: frozenset({'canned beer', 'shopping bags', 'soda'}),
#  913: frozenset({'bottled water',
#             'canned beer',
#             'curd',
#             'dish cleaner',
#             'margarine',
#             'roll products ',
#             'white wine'}),
#  914: frozenset({'bottled beer',
#             'bottled water',
#             'fruit/vegetable juice',
#             'napkins',
#             'soda'}),
#  915: frozenset({'packaged fruit/vegetables', 'pot plants'}),
#  916: frozenset({'bottled water',
#             'cling film/bags',
#             'frozen vegetables',
#             'ice cream',
#             'root vegetables',
#             'tropical fruit'}),
#  917: frozenset({'beef',
#             'bottled water',
#             'chocolate',
#             'domestic eggs',
#             'fruit/vegetable juice',
#             'grapes',
#             'ham',
#             'newspapers',
#             'pastry',
#             'salty snack',
#             'shopping bags',
#             'whipped/sour cream',
#             'white bread',
#             'white wine',
#             'yogurt'}),
#  918: frozenset({'UHT-milk',
#             'bottled beer',
#             'brown bread',
#             'canned beer',
#             'citrus fruit',
#             'long life bakery product',
#             'pork',
#             'soda'}),
#  919: frozenset({'beverages',
#             'cake bar',
#             'liqueur',
#             'misc. beverages',
#             'rolls/buns',
#             'soda'}),
#  920: frozenset({'rolls/buns', 'sausage', 'soda'}),
#  921: frozenset({'bottled water',
#             'citrus fruit',
#             'napkins',
#             'rolls/buns',
#             'sausage',
#             'soda',
#             'whole milk',
#             'yogurt'}),
#  922: frozenset({'butter',
#             'cream cheese ',
#             'frozen fish',
#             'root vegetables',
#             'shopping bags',
#             'whole milk',
#             'yogurt'}),
#  923: frozenset({'cream cheese ', 'whole milk'}),
#  924: frozenset({'frankfurter',
#             'other vegetables',
#             'pastry',
#             'ready soups',
#             'rolls/buns',
#             'root vegetables',
#             'turkey',
#             'yogurt'}),
#  925: frozenset({'shopping bags', 'soda'}),
#  926: frozenset({'bottled beer', 'soda'}),
#  927: frozenset({'frankfurter', 'popcorn'}),
#  928: frozenset({'berries',
#             'detergent',
#             'newspapers',
#             'pickled vegetables',
#             'whipped/sour cream',
#             'whole milk'}),
#  929: frozenset({'canned beer'}),
#  930: frozenset({'canned vegetables',
#             'frankfurter',
#             'pork',
#             'soda',
#             'white bread'}),
#  931: frozenset({'butter',
#             'chocolate',
#             'chocolate marshmallow',
#             'curd',
#             'dental care',
#             'dish cleaner',
#             'flour',
#             'frankfurter',
#             'hamburger meat',
#             'mustard',
#             'oil',
#             'rice',
#             'salty snack',
#             'sugar',
#             'whole milk'}),
#  932: frozenset({'berries',
#             'beverages',
#             'coffee',
#             'root vegetables',
#             'shopping bags',
#             'soups',
#             'sugar',
#             'whole milk'}),
#  933: frozenset({'frankfurter', 'rolls/buns'}),
#  934: frozenset({'newspapers'}),
#  935: frozenset({'frozen fish', 'newspapers'}),
#  936: frozenset({'newspapers', 'tropical fruit'}),
#  937: frozenset({'beef',
#             'berries',
#             'grapes',
#             'newspapers',
#             'pot plants',
#             'rolls/buns',
#             'whole milk',
#             'yogurt'}),
#  938: frozenset({'coffee',
#             'instant coffee',
#             'rolls/buns',
#             'salty snack',
#             'specialty chocolate'}),
#  939: frozenset({'pot plants', 'specialty chocolate'}),
#  940: frozenset({'dish cleaner', 'sparkling wine'}),
#  941: frozenset({'citrus fruit', 'napkins', 'shopping bags'}),
#  942: frozenset({'bottled beer', 'herbs', 'onions'}),
#  943: frozenset({'candles', 'detergent', 'pastry', 'whole milk'}),
#  944: frozenset({'photo/film'}),
#  945: frozenset({'hamburger meat'}),
#  946: frozenset({'chewing gum',
#             'other vegetables',
#             'white bread',
#             'whole milk'}),
#  947: frozenset({'rolls/buns', 'shopping bags', 'whole milk'}),
#  948: frozenset({'grapes',
#             'hard cheese',
#             'napkins',
#             'pork',
#             'shopping bags',
#             'soda',
#             'tropical fruit'}),
#  949: frozenset({'baking powder',
#             'berries',
#             'bottled water',
#             'butter',
#             'canned beer',
#             'dessert',
#             'fruit/vegetable juice',
#             'grapes',
#             'ice cream',
#             'misc. beverages',
#             'other vegetables',
#             'pastry',
#             'pot plants',
#             'salt',
#             'specialty chocolate',
#             'tropical fruit',
#             'whipped/sour cream',
#             'whole milk',
#             'yogurt'}),
#  950: frozenset({'chewing gum',
#             'chicken',
#             'citrus fruit',
#             'other vegetables',
#             'pork',
#             'pot plants',
#             'whipped/sour cream',
#             'white bread'}),
#  951: frozenset({'chewing gum', 'other vegetables'}),
#  952: frozenset({'bottled water', 'red/blush wine', 'sausage'}),
#  953: frozenset({'baking powder', 'whipped/sour cream', 'whole milk'}),
#  954: frozenset({'coffee', 'rolls/buns'}),
#  955: frozenset({'hygiene articles'}),
#  956: frozenset({'ice cream', 'newspapers'}),
#  957: frozenset({'curd',
#             'domestic eggs',
#             'flour',
#             'misc. beverages',
#             'newspapers',
#             'whipped/sour cream'}),
#  958: frozenset({'frozen meals', 'newspapers', 'whole milk'}),
#  959: frozenset({'bottled water',
#             'coffee',
#             'dessert',
#             'domestic eggs',
#             'onions',
#             'rolls/buns',
#             'white bread',
#             'whole milk'}),
#  960: frozenset({'finished products',
#             'fruit/vegetable juice',
#             'organic sausage',
#             'sliced cheese',
#             'white bread'}),
#  961: frozenset({'dog food', 'long life bakery product', 'salt'}),
#  962: frozenset({'brown bread',
#             'canned vegetables',
#             'domestic eggs',
#             'fruit/vegetable juice',
#             'other vegetables',
#             'root vegetables',
#             'rum',
#             'soda',
#             'tropical fruit',
#             'white bread'}),
#  963: frozenset({'other vegetables', 'whole milk', 'yogurt'}),
#  964: frozenset({'chocolate'}),
#  965: frozenset({'ice cream'}),
#  966: frozenset({'cat food', 'oil', 'tropical fruit'}),
#  967: frozenset({'citrus fruit',
#             'frankfurter',
#             'fruit/vegetable juice',
#             'pastry',
#             'sliced cheese',
#             'specialty cheese',
#             'whole milk',
#             'yogurt'}),
#  968: frozenset({'butter',
#             'canned fish',
#             'flower (seeds)',
#             'pasta',
#             'softener'}),
#  969: frozenset({'butter milk',
#             'frozen fish',
#             'other vegetables',
#             'salty snack'}),
#  970: frozenset({'canned beer', 'chocolate', 'pastry', 'tropical fruit'}),
#  971: frozenset({'brown bread',
#             'citrus fruit',
#             'packaged fruit/vegetables',
#             'rolls/buns',
#             'root vegetables',
#             'sliced cheese',
#             'white bread',
#             'yogurt',
#             'zwieback'}),
#  972: frozenset({'UHT-milk',
#             'salt',
#             'shopping bags',
#             'soda',
#             'specialty chocolate'}),
#  973: frozenset({'beef'}),
#  974: frozenset({'canned vegetables',
#             'curd',
#             'spread cheese',
#             'sugar',
#             'yogurt'}),
#  975: frozenset({'bottled beer',
#             'citrus fruit',
#             'dessert',
#             'frozen vegetables',
#             'fruit/vegetable juice',
#             'other vegetables',
#             'salty snack',
#             'whole milk',
#             'yogurt'}),
#  976: frozenset({'bottled beer', 'brown bread', 'white wine', 'yogurt'}),
#  977: frozenset({'bottled beer', 'liquor', 'red/blush wine'}),
#  978: frozenset({'grapes'}),
#  979: frozenset({'other vegetables', 'pork', 'soda'}),
#  980: frozenset({'berries',
#             'candy',
#             'canned fish',
#             'chocolate',
#             'citrus fruit',
#             'cream cheese ',
#             'domestic eggs',
#             'frozen vegetables',
#             'margarine',
#             'napkins',
#             'other vegetables',
#             'pastry',
#             'sausage',
#             'soups',
#             'whipped/sour cream',
#             'whole milk',
#             'yogurt'}),
#  981: frozenset({'UHT-milk',
#             'brown bread',
#             'chicken',
#             'chocolate',
#             'cocoa drinks',
#             'coffee',
#             'flour',
#             'frankfurter',
#             'fruit/vegetable juice',
#             'long life bakery product',
#             'mayonnaise',
#             'mustard',
#             'other vegetables',
#             'pastry',
#             'pork',
#             'root vegetables',
#             'salty snack',
#             'seasonal products',
#             'tropical fruit',
#             'yogurt'}),
#  982: frozenset({'artif. sweetener', 'photo/film', 'soda'}),
#  983: frozenset({'bottled beer',
#             'butter',
#             'coffee',
#             'frankfurter',
#             'onions',
#             'processed cheese',
#             'rolls/buns'}),
#  984: frozenset({'dessert',
#             'domestic eggs',
#             'pip fruit',
#             'root vegetables',
#             'shopping bags',
#             'yogurt'}),
#  985: frozenset({'coffee', 'detergent', 'frankfurter', 'whole milk'}),
#  986: frozenset({'newspapers', 'whole milk'}),
#  987: frozenset({'domestic eggs',
#             'flower soil/fertilizer',
#             'hygiene articles',
#             'photo/film'}),
#  988: frozenset({'chocolate',
#             'dessert',
#             'flower (seeds)',
#             'mayonnaise',
#             'oil',
#             'packaged fruit/vegetables',
#             'shopping bags',
#             'soda',
#             'waffles'}),
#  989: frozenset({'bottled water',
#             'chicken',
#             'frozen vegetables',
#             'long life bakery product',
#             'other vegetables',
#             'whipped/sour cream'}),
#  990: frozenset({'baking powder',
#             'candy',
#             'cocoa drinks',
#             'coffee',
#             'cream cheese ',
#             'curd',
#             'domestic eggs',
#             'napkins',
#             'pork',
#             'salty snack',
#             'sugar',
#             'waffles',
#             'whipped/sour cream',
#             'white bread',
#             'whole milk',
#             'yogurt'}),
#  991: frozenset({'citrus fruit',
#             'cleaner',
#             'coffee',
#             'cream cheese ',
#             'curd',
#             'detergent',
#             'long life bakery product',
#             'napkins',
#             'newspapers',
#             'oil',
#             'other vegetables',
#             'pastry',
#             'vinegar',
#             'whipped/sour cream',
#             'whole milk',
#             'yogurt'}),
#  992: frozenset({'light bulbs'}),
#  993: frozenset({'cream cheese ', 'margarine', 'tea'}),
#  994: frozenset({'cake bar',
#             'cleaner',
#             'curd',
#             'detergent',
#             'domestic eggs',
#             'frozen meals',
#             'house keeping products',
#             'pot plants',
#             'sausage',
#             'seasonal products',
#             'shopping bags'}),
#  995: frozenset({'citrus fruit', 'onions'}),
#  996: frozenset({'other vegetables', 'roll products ', 'whipped/sour cream'}),
#  997: frozenset({'bottled water',
#             'butter',
#             'chicken',
#             'cling film/bags',
#             'dog food',
#             'domestic eggs',
#             'frozen fish',
#             'frozen vegetables',
#             'fruit/vegetable juice',
#             'hard cheese',
#             'long life bakery product',
#             'napkins',
#             'other vegetables',
#             'pip fruit',
#             'rice',
#             'root vegetables',
#             'softener',
#             'specialty fat',
#             'tropical fruit',
#             'whipped/sour cream',
#             'white bread',
#             'whole milk',
#             'yogurt'}),
#  998: frozenset({'ice cream'}),
#  999: frozenset({'beef', 'ice cream', 'newspapers', 'pork', 'rolls/buns'}),
#  1000: frozenset({'artif. sweetener',
#             'chocolate marshmallow',
#             'flour',
#             'margarine',
#             'organic products',
#             'other vegetables',
#             'pork',
#             'semi-finished bread',
#             'tropical fruit',
#             'yogurt'}),
#  ...}

# %%
freq_1={}
for item in Data:
    for record in Data[item]:
        if frozenset([record]) in freq_1:
            freq_1[frozenset([record])] += 1
        else:
            freq_1[frozenset([record])]  = 1

# %% [markdown]
# 第一频繁项集的候选集大小为169

# %%
len(freq_1)
# Out:
# 169

# %% [markdown]
# 设置支持度为400，提取出第一频繁项集

# %%
min_supp=400
freq_1_supp={v:freq_1[v] for v in freq_1 if freq_1[v]>=min_supp}
freq_1_supp
# Out:
# {frozenset({'margarine'}): 576,
#  frozenset({'citrus fruit'}): 814,
#  frozenset({'coffee'}): 571,
#  frozenset({'yogurt'}): 1372,
#  frozenset({'tropical fruit'}): 1032,
#  frozenset({'whole milk'}): 2513,
#  frozenset({'pip fruit'}): 744,
#  frozenset({'other vegetables'}): 1903,
#  frozenset({'butter'}): 545,
#  frozenset({'rolls/buns'}): 1809,
#  frozenset({'bottled beer'}): 792,
#  frozenset({'white bread'}): 414,
#  frozenset({'chocolate'}): 488,
#  frozenset({'bottled water'}): 1087,
#  frozenset({'curd'}): 524,
#  frozenset({'beef'}): 516,
#  frozenset({'soda'}): 1715,
#  frozenset({'frankfurter'}): 580,
#  frozenset({'chicken'}): 422,
#  frozenset({'newspapers'}): 785,
#  frozenset({'fruit/vegetable juice'}): 711,
#  frozenset({'pastry'}): 875,
#  frozenset({'root vegetables'}): 1072,
#  frozenset({'canned beer'}): 764,
#  frozenset({'sausage'}): 924,
#  frozenset({'brown bread'}): 638,
#  frozenset({'shopping bags'}): 969,
#  frozenset({'napkins'}): 515,
#  frozenset({'pork'}): 567,
#  frozenset({'whipped/sour cream'}): 705,
#  frozenset({'domestic eggs'}): 624,
#  frozenset({'frozen vegetables'}): 473}

# %%
def getSubset(item, k):
    
    import itertools as its
    return [frozenset(item) for item in its.combinations(item, k)]

def getAllSubsets(item):
    
    subsets = []
    
    for i in range(len(item) - 1):
    
        subsets.extend(getSubset(item, i + 1))
                       
    return subsets

# %%
def get_frequent_item_list_with_spuu(frequent_k,min_supp,k,item_list):
    items = frequent_k.keys()
    condidate_items=[]
    current_k={}
    candidate_items=[m.union(n) for m in items for n in items if m!=n and len(m.union(n))==k] # 合并集合,连接，生成候选项集
    for record in item_list.items():
          for item in candidate_items:
            if item.issubset(record[1]):
                if item in current_k:
                    current_k[item]+=1
                else:
                    current_k[item]=1
    return {v:current_k[v] for v in current_k if current_k[v]>=min_supp}

# %%
k = 2
final_itemsets = []
final_itemsets.append(freq_1_supp)
min_conf=0.6
frequent_k_minus_one = freq_1_supp
while k<=6:
    print(len(frequent_k_minus_one))
    print(frequent_k_minus_one)
    print("")
    frequent_k=get_frequent_item_list_with_spuu(frequent_k_minus_one,min_supp,k,Data)
    final_itemsets.append(frequent_k)
    frequent_k_minus_one=frequent_k
    k+=1
# Out:
# 32
# {frozenset({'margarine'}): 576, frozenset({'citrus fruit'}): 814, frozenset({'coffee'}): 571, frozenset({'yogurt'}): 1372, frozenset({'tropical fruit'}): 1032, frozenset({'whole milk'}): 2513, frozenset({'pip fruit'}): 744, frozenset({'other vegetables'}): 1903, frozenset({'butter'}): 545, frozenset({'rolls/buns'}): 1809, frozenset({'bottled beer'}): 792, frozenset({'white bread'}): 414, frozenset({'chocolate'}): 488, frozenset({'bottled water'}): 1087, frozenset({'curd'}): 524, frozenset({'beef'}): 516, frozenset({'soda'}): 1715, frozenset({'frankfurter'}): 580, frozenset({'chicken'}): 422, frozenset({'newspapers'}): 785, frozenset({'fruit/vegetable juice'}): 711, frozenset({'pastry'}): 875, frozenset({'root vegetables'}): 1072, frozenset({'canned beer'}): 764, frozenset({'sausage'}): 924, frozenset({'brown bread'}): 638, frozenset({'shopping bags'}): 969, frozenset({'napkins'}): 515, frozenset({'pork'}): 567, frozenset({'whipped/sour cream'}): 705, frozenset({'domestic eggs'}): 624, frozenset({'frozen vegetables'}): 473}
#
# 60
# {frozenset({'yogurt', 'tropical fruit'}): 576, frozenset({'whole milk', 'other vegetables'}): 1472, frozenset({'yogurt', 'whole milk'}): 1102, frozenset({'butter', 'whole milk'}): 542, frozenset({'rolls/buns', 'other vegetables'}): 838, frozenset({'other vegetables', 'tropical fruit'}): 706, frozenset({'bottled water', 'other vegetables'}): 488, frozenset({'yogurt', 'citrus fruit'}): 426, frozenset({'citrus fruit', 'whole milk'}): 600, frozenset({'yogurt', 'bottled water'}): 452, frozenset({'whole milk', 'tropical fruit'}): 832, frozenset({'bottled water', 'whole milk'}): 676, frozenset({'curd', 'whole milk'}): 514, frozenset({'rolls/buns', 'soda'}): 754, frozenset({'rolls/buns', 'tropical fruit'}): 484, frozenset({'root vegetables', 'tropical fruit'}): 414, frozenset({'other vegetables', 'root vegetables'}): 932, frozenset({'rolls/buns', 'root vegetables'}): 478, frozenset({'rolls/buns', 'sausage'}): 602, frozenset({'soda', 'sausage'}): 478, frozenset({'shopping bags', 'soda'}): 484, frozenset({'rolls/buns', 'bottled water'}): 476, frozenset({'whole milk', 'root vegetables'}): 962, frozenset({'soda', 'whole milk'}): 788, frozenset({'pork', 'whole milk'}): 436, frozenset({'whole milk', 'whipped/sour cream'}): 634, frozenset({'soda', 'other vegetables'}): 644, frozenset({'pork', 'other vegetables'}): 426, frozenset({'other vegetables', 'whipped/sour cream'}): 568, frozenset({'soda', 'pastry'}): 414, frozenset({'yogurt', 'soda'}): 538, frozenset({'yogurt', 'root vegetables'}): 508, frozenset({'soda', 'tropical fruit'}): 410, frozenset({'whole milk', 'pastry'}): 654, frozenset({'brown bread', 'whole milk'}): 496, frozenset({'domestic eggs', 'whole milk'}): 590, frozenset({'rolls/buns', 'yogurt'}): 676, frozenset({'soda', 'bottled water'}): 570, frozenset({'other vegetables', 'fruit/vegetable juice'}): 414, frozenset({'domestic eggs', 'other vegetables'}): 438, frozenset({'rolls/buns', 'pastry'}): 412, frozenset({'frozen vegetables', 'whole milk'}): 402, frozenset({'beef', 'whole milk'}): 418, frozenset({'whole milk', 'sausage'}): 588, frozenset({'tropical fruit', 'pip fruit'}): 402, frozenset({'whole milk', 'pip fruit'}): 592, frozenset({'rolls/buns', 'whole milk'}): 1114, frozenset({'margarine', 'whole milk'}): 476, frozenset({'frankfurter', 'whole milk'}): 404, frozenset({'newspapers', 'whole milk'}): 538, frozenset({'whole milk', 'fruit/vegetable juice'}): 524, frozenset({'citrus fruit', 'other vegetables'}): 568, frozenset({'bottled beer', 'whole milk'}): 402, frozenset({'shopping bags', 'whole milk'}): 482, frozenset({'other vegetables', 'sausage'}): 530, frozenset({'other vegetables', 'pastry'}): 444, frozenset({'shopping bags', 'other vegetables'}): 456, frozenset({'other vegetables', 'pip fruit'}): 514, frozenset({'yogurt', 'other vegetables'}): 854, frozenset({'yogurt', 'whipped/sour cream'}): 408}
#
# 58
# {frozenset({'yogurt', 'whole milk', 'tropical fruit'}): 894, frozenset({'yogurt', 'citrus fruit', 'whole milk'}): 606, frozenset({'yogurt', 'bottled water', 'whole milk'}): 570, frozenset({'rolls/buns', 'other vegetables', 'tropical fruit'}): 462, frozenset({'rolls/buns', 'other vegetables', 'root vegetables'}): 720, frozenset({'root vegetables', 'other vegetables', 'tropical fruit'}): 726, frozenset({'rolls/buns', 'soda', 'sausage'}): 570, frozenset({'rolls/buns', 'bottled water', 'other vegetables'}): 432, frozenset({'whole milk', 'other vegetables', 'root vegetables'}): 1368, frozenset({'soda', 'whole milk', 'other vegetables'}): 822, frozenset({'pork', 'whole milk', 'other vegetables'}): 600, frozenset({'whole milk', 'other vegetables', 'whipped/sour cream'}): 864, frozenset({'yogurt', 'root vegetables', 'tropical fruit'}): 480, frozenset({'yogurt', 'whole milk', 'root vegetables'}): 858, frozenset({'yogurt', 'whole milk', 'soda'}): 618, frozenset({'whole milk', 'tropical fruit', 'root vegetables'}): 708, frozenset({'soda', 'whole milk', 'tropical fruit'}): 462, frozenset({'soda', 'whole milk', 'pastry'}): 486, frozenset({'rolls/buns', 'yogurt', 'bottled water'}): 420, frozenset({'yogurt', 'bottled water', 'soda'}): 438, frozenset({'rolls/buns', 'soda', 'bottled water'}): 402, frozenset({'rolls/buns', 'soda', 'yogurt'}): 510, frozenset({'rolls/buns', 'whole milk', 'tropical fruit'}): 648, frozenset({'whole milk', 'tropical fruit', 'pip fruit'}): 498, frozenset({'rolls/buns', 'whole milk', 'other vegetables'}): 1056, frozenset({'rolls/buns', 'whole milk', 'root vegetables'}): 750, frozenset({'rolls/buns', 'yogurt', 'root vegetables'}): 426, frozenset({'rolls/buns', 'soda', 'whole milk'}): 522, frozenset({'rolls/buns', 'whole milk', 'sausage'}): 552, frozenset({'rolls/buns', 'whole milk', 'pastry'}): 504, frozenset({'rolls/buns', 'other vegetables', 'sausage'}): 522, frozenset({'rolls/buns', 'bottled water', 'whole milk'}): 516, frozenset({'domestic eggs', 'whole milk', 'other vegetables'}): 726, frozenset({'whole milk', 'other vegetables', 'pip fruit'}): 798, frozenset({'shopping bags', 'whole milk', 'other vegetables'}): 450, frozenset({'yogurt', 'whole milk', 'other vegetables'}): 1314, frozenset({'whole milk', 'other vegetables', 'fruit/vegetable juice'}): 618, frozenset({'yogurt', 'other vegetables', 'root vegetables'}): 762, frozenset({'soda', 'bottled water', 'whole milk'}): 444, frozenset({'whole milk', 'other vegetables', 'tropical fruit'}): 1008, frozenset({'yogurt', 'other vegetables', 'tropical fruit'}): 726, frozenset({'yogurt', 'whole milk', 'whipped/sour cream'}): 642, frozenset({'other vegetables', 'tropical fruit', 'pip fruit'}): 558, frozenset({'yogurt', 'other vegetables', 'whipped/sour cream'}): 600, frozenset({'soda', 'other vegetables', 'sausage'}): 426, frozenset({'soda', 'other vegetables', 'yogurt'}): 492, frozenset({'citrus fruit', 'whole milk', 'other vegetables'}): 768, frozenset({'whole milk', 'other vegetables', 'sausage'}): 600, frozenset({'rolls/buns', 'yogurt', 'whole milk'}): 918, frozenset({'bottled water', 'whole milk', 'other vegetables'}): 636, frozenset({'rolls/buns', 'soda', 'other vegetables'}): 582, frozenset({'rolls/buns', 'yogurt', 'tropical fruit'}): 516, frozenset({'rolls/buns', 'yogurt', 'other vegetables'}): 678, frozenset({'soda', 'other vegetables', 'tropical fruit'}): 426, frozenset({'yogurt', 'bottled water', 'other vegetables'}): 480, frozenset({'yogurt', 'citrus fruit', 'other vegetables'}): 450, frozenset({'whole milk', 'other vegetables', 'pastry'}): 624, frozenset({'shopping bags', 'soda', 'whole milk'}): 402}
#
# 18
# {frozenset({'whole milk', 'root vegetables', 'yogurt', 'tropical fruit'}): 672, frozenset({'whole milk', 'other vegetables', 'root vegetables', 'yogurt'}): 924, frozenset({'whole milk', 'other vegetables', 'yogurt', 'tropical fruit'}): 900, frozenset({'whole milk', 'other vegetables', 'root vegetables', 'tropical fruit'}): 828, frozenset({'other vegetables', 'root vegetables', 'yogurt', 'tropical fruit'}): 588, frozenset({'whole milk', 'other vegetables', 'whipped/sour cream', 'yogurt'}): 660, frozenset({'whole milk', 'other vegetables', 'tropical fruit', 'pip fruit'}): 564, frozenset({'whole milk', 'other vegetables', 'root vegetables', 'rolls/buns'}): 732, frozenset({'whole milk', 'rolls/buns', 'yogurt', 'tropical fruit'}): 576, frozenset({'whole milk', 'other vegetables', 'yogurt', 'citrus fruit'}): 564, frozenset({'bottled water', 'whole milk', 'other vegetables', 'yogurt'}): 468, frozenset({'whole milk', 'other vegetables', 'rolls/buns', 'tropical fruit'}): 480, frozenset({'other vegetables', 'rolls/buns', 'yogurt', 'tropical fruit'}): 444, frozenset({'soda', 'whole milk', 'other vegetables', 'yogurt'}): 516, frozenset({'soda', 'whole milk', 'other vegetables', 'rolls/buns'}): 516, frozenset({'whole milk', 'other vegetables', 'rolls/buns', 'yogurt'}): 708, frozenset({'whole milk', 'root vegetables', 'rolls/buns', 'yogurt'}): 552, frozenset({'other vegetables', 'root vegetables', 'rolls/buns', 'yogurt'}): 492}
#
# 3
# {frozenset({'whole milk', 'tropical fruit', 'other vegetables', 'root vegetables', 'yogurt'}): 700, frozenset({'whole milk', 'tropical fruit', 'other vegetables', 'rolls/buns', 'yogurt'}): 500, frozenset({'whole milk', 'other vegetables', 'root vegetables', 'rolls/buns', 'yogurt'}): 480}

# %%
final_itemset
# Out:
# [{frozenset({'margarine'}): 576,
#   frozenset({'citrus fruit'}): 814,
#   frozenset({'coffee'}): 571,
#   frozenset({'yogurt'}): 1372,
#   frozenset({'tropical fruit'}): 1032,
#   frozenset({'whole milk'}): 2513,
#   frozenset({'pip fruit'}): 744,
#   frozenset({'other vegetables'}): 1903,
#   frozenset({'butter'}): 545,
#   frozenset({'rolls/buns'}): 1809,
#   frozenset({'bottled beer'}): 792,
#   frozenset({'white bread'}): 414,
#   frozenset({'chocolate'}): 488,
#   frozenset({'bottled water'}): 1087,
#   frozenset({'curd'}): 524,
#   frozenset({'beef'}): 516,
#   frozenset({'soda'}): 1715,
#   frozenset({'frankfurter'}): 580,
#   frozenset({'chicken'}): 422,
#   frozenset({'newspapers'}): 785,
#   frozenset({'fruit/vegetable juice'}): 711,
#   frozenset({'pastry'}): 875,
#   frozenset({'root vegetables'}): 1072,
#   frozenset({'canned beer'}): 764,
#   frozenset({'sausage'}): 924,
#   frozenset({'brown bread'}): 638,
#   frozenset({'shopping bags'}): 969,
#   frozenset({'napkins'}): 515,
#   frozenset({'pork'}): 567,
#   frozenset({'whipped/sour cream'}): 705,
#   frozenset({'domestic eggs'}): 624,
#   frozenset({'frozen vegetables'}): 473},
#  {frozenset({'tropical fruit', 'yogurt'}): 576,
#   frozenset({'other vegetables', 'whole milk'}): 1472,
#   frozenset({'whole milk', 'yogurt'}): 1102,
#   frozenset({'butter', 'whole milk'}): 542,
#   frozenset({'other vegetables', 'rolls/buns'}): 838,
#   frozenset({'other vegetables', 'tropical fruit'}): 706,
#   frozenset({'bottled water', 'other vegetables'}): 488,
#   frozenset({'citrus fruit', 'yogurt'}): 426,
#   frozenset({'citrus fruit', 'whole milk'}): 600,
#   frozenset({'bottled water', 'yogurt'}): 452,
#   frozenset({'tropical fruit', 'whole milk'}): 832,
#   frozenset({'bottled water', 'whole milk'}): 676,
#   frozenset({'curd', 'whole milk'}): 514,
#   frozenset({'rolls/buns', 'soda'}): 754,
#   frozenset({'rolls/buns', 'tropical fruit'}): 484,
#   frozenset({'root vegetables', 'tropical fruit'}): 414,
#   frozenset({'other vegetables', 'root vegetables'}): 932,
#   frozenset({'rolls/buns', 'root vegetables'}): 478,
#   frozenset({'rolls/buns', 'sausage'}): 602,
#   frozenset({'sausage', 'soda'}): 478,
#   frozenset({'shopping bags', 'soda'}): 484,
#   frozenset({'bottled water', 'rolls/buns'}): 476,
#   frozenset({'root vegetables', 'whole milk'}): 962,
#   frozenset({'soda', 'whole milk'}): 788,
#   frozenset({'pork', 'whole milk'}): 436,
#   frozenset({'whipped/sour cream', 'whole milk'}): 634,
#   frozenset({'other vegetables', 'soda'}): 644,
#   frozenset({'other vegetables', 'pork'}): 426,
#   frozenset({'other vegetables', 'whipped/sour cream'}): 568,
#   frozenset({'pastry', 'soda'}): 414,
#   frozenset({'soda', 'yogurt'}): 538,
#   frozenset({'root vegetables', 'yogurt'}): 508,
#   frozenset({'soda', 'tropical fruit'}): 410,
#   frozenset({'pastry', 'whole milk'}): 654,
#   frozenset({'brown bread', 'whole milk'}): 496,
#   frozenset({'domestic eggs', 'whole milk'}): 590,
#   frozenset({'rolls/buns', 'yogurt'}): 676,
#   frozenset({'bottled water', 'soda'}): 570,
#   frozenset({'fruit/vegetable juice', 'other vegetables'}): 414,
#   frozenset({'domestic eggs', 'other vegetables'}): 438,
#   frozenset({'pastry', 'rolls/buns'}): 412,
#   frozenset({'frozen vegetables', 'whole milk'}): 402,
#   frozenset({'beef', 'whole milk'}): 418,
#   frozenset({'sausage', 'whole milk'}): 588,
#   frozenset({'pip fruit', 'tropical fruit'}): 402,
#   frozenset({'pip fruit', 'whole milk'}): 592,
#   frozenset({'rolls/buns', 'whole milk'}): 1114,
#   frozenset({'margarine', 'whole milk'}): 476,
#   frozenset({'frankfurter', 'whole milk'}): 404,
#   frozenset({'newspapers', 'whole milk'}): 538,
#   frozenset({'fruit/vegetable juice', 'whole milk'}): 524,
#   frozenset({'citrus fruit', 'other vegetables'}): 568,
#   frozenset({'bottled beer', 'whole milk'}): 402,
#   frozenset({'shopping bags', 'whole milk'}): 482,
#   frozenset({'other vegetables', 'sausage'}): 530,
#   frozenset({'other vegetables', 'pastry'}): 444,
#   frozenset({'other vegetables', 'shopping bags'}): 456,
#   frozenset({'other vegetables', 'pip fruit'}): 514,
#   frozenset({'other vegetables', 'yogurt'}): 854,
#   frozenset({'whipped/sour cream', 'yogurt'}): 408},
#  {frozenset({'tropical fruit', 'whole milk', 'yogurt'}): 894,
#   frozenset({'citrus fruit', 'whole milk', 'yogurt'}): 606,
#   frozenset({'bottled water', 'whole milk', 'yogurt'}): 570,
#   frozenset({'other vegetables', 'rolls/buns', 'tropical fruit'}): 462,
#   frozenset({'other vegetables', 'rolls/buns', 'root vegetables'}): 720,
#   frozenset({'other vegetables', 'root vegetables', 'tropical fruit'}): 726,
#   frozenset({'rolls/buns', 'sausage', 'soda'}): 570,
#   frozenset({'bottled water', 'other vegetables', 'rolls/buns'}): 432,
#   frozenset({'other vegetables', 'root vegetables', 'whole milk'}): 1368,
#   frozenset({'other vegetables', 'soda', 'whole milk'}): 822,
#   frozenset({'other vegetables', 'pork', 'whole milk'}): 600,
#   frozenset({'other vegetables', 'whipped/sour cream', 'whole milk'}): 864,
#   frozenset({'root vegetables', 'tropical fruit', 'yogurt'}): 480,
#   frozenset({'root vegetables', 'whole milk', 'yogurt'}): 858,
#   frozenset({'soda', 'whole milk', 'yogurt'}): 618,
#   frozenset({'root vegetables', 'tropical fruit', 'whole milk'}): 708,
#   frozenset({'soda', 'tropical fruit', 'whole milk'}): 462,
#   frozenset({'pastry', 'soda', 'whole milk'}): 486,
#   frozenset({'bottled water', 'rolls/buns', 'yogurt'}): 420,
#   frozenset({'bottled water', 'soda', 'yogurt'}): 438,
#   frozenset({'bottled water', 'rolls/buns', 'soda'}): 402,
#   frozenset({'rolls/buns', 'soda', 'yogurt'}): 510,
#   frozenset({'rolls/buns', 'tropical fruit', 'whole milk'}): 648,
#   frozenset({'pip fruit', 'tropical fruit', 'whole milk'}): 498,
#   frozenset({'other vegetables', 'rolls/buns', 'whole milk'}): 1056,
#   frozenset({'rolls/buns', 'root vegetables', 'whole milk'}): 750,
#   frozenset({'rolls/buns', 'root vegetables', 'yogurt'}): 426,
#   frozenset({'rolls/buns', 'soda', 'whole milk'}): 522,
#   frozenset({'rolls/buns', 'sausage', 'whole milk'}): 552,
#   frozenset({'pastry', 'rolls/buns', 'whole milk'}): 504,
#   frozenset({'other vegetables', 'rolls/buns', 'sausage'}): 522,
#   frozenset({'bottled water', 'rolls/buns', 'whole milk'}): 516,
#   frozenset({'domestic eggs', 'other vegetables', 'whole milk'}): 726,
#   frozenset({'other vegetables', 'pip fruit', 'whole milk'}): 798,
#   frozenset({'other vegetables', 'shopping bags', 'whole milk'}): 450,
#   frozenset({'other vegetables', 'whole milk', 'yogurt'}): 1314,
#   frozenset({'fruit/vegetable juice', 'other vegetables', 'whole milk'}): 618,
#   frozenset({'other vegetables', 'root vegetables', 'yogurt'}): 762,
#   frozenset({'bottled water', 'soda', 'whole milk'}): 444,
#   frozenset({'other vegetables', 'tropical fruit', 'whole milk'}): 1008,
#   frozenset({'other vegetables', 'tropical fruit', 'yogurt'}): 726,
#   frozenset({'whipped/sour cream', 'whole milk', 'yogurt'}): 642,
#   frozenset({'other vegetables', 'pip fruit', 'tropical fruit'}): 558,
#   frozenset({'other vegetables', 'whipped/sour cream', 'yogurt'}): 600,
#   frozenset({'other vegetables', 'sausage', 'soda'}): 426,
#   frozenset({'other vegetables', 'soda', 'yogurt'}): 492,
#   frozenset({'citrus fruit', 'other vegetables', 'whole milk'}): 768,
#   frozenset({'other vegetables', 'sausage', 'whole milk'}): 600,
#   frozenset({'rolls/buns', 'whole milk', 'yogurt'}): 918,
#   frozenset({'bottled water', 'other vegetables', 'whole milk'}): 636,
#   frozenset({'other vegetables', 'rolls/buns', 'soda'}): 582,
#   frozenset({'rolls/buns', 'tropical fruit', 'yogurt'}): 516,
#   frozenset({'other vegetables', 'rolls/buns', 'yogurt'}): 678,
#   frozenset({'other vegetables', 'soda', 'tropical fruit'}): 426,
#   frozenset({'bottled water', 'other vegetables', 'yogurt'}): 480,
#   frozenset({'citrus fruit', 'other vegetables', 'yogurt'}): 450,
#   frozenset({'other vegetables', 'pastry', 'whole milk'}): 624,
#   frozenset({'shopping bags', 'soda', 'whole milk'}): 402},
#  {frozenset({'root vegetables',
#              'tropical fruit',
#              'whole milk',
#              'yogurt'}): 672,
#   frozenset({'other vegetables',
#              'root vegetables',
#              'whole milk',
#              'yogurt'}): 924,
#   frozenset({'other vegetables',
#              'tropical fruit',
#              'whole milk',
#              'yogurt'}): 900,
#   frozenset({'other vegetables',
#              'root vegetables',
#              'tropical fruit',
#              'whole milk'}): 828,
#   frozenset({'other vegetables',
#              'root vegetables',
#              'tropical fruit',
#              'yogurt'}): 588,
#   frozenset({'other vegetables',
#              'whipped/sour cream',
#              'whole milk',
#              'yogurt'}): 660,
#   frozenset({'other vegetables',
#              'pip fruit',
#              'tropical fruit',
#              'whole milk'}): 564,
#   frozenset({'other vegetables',
#              'rolls/buns',
#              'root vegetables',
#              'whole milk'}): 732,
#   frozenset({'rolls/buns', 'tropical fruit', 'whole milk', 'yogurt'}): 576,
#   frozenset({'citrus fruit', 'other vegetables', 'whole milk', 'yogurt'}): 564,
#   frozenset({'bottled water',
#              'other vegetables',
#              'whole milk',
#              'yogurt'}): 468,
#   frozenset({'other vegetables',
#              'rolls/buns',
#              'tropical fruit',
#              'whole milk'}): 480,
#   frozenset({'other vegetables',
#              'rolls/buns',
#              'tropical fruit',
#              'yogurt'}): 444,
#   frozenset({'other vegetables', 'soda', 'whole milk', 'yogurt'}): 516,
#   frozenset({'other vegetables', 'rolls/buns', 'soda', 'whole milk'}): 516,
#   frozenset({'other vegetables', 'rolls/buns', 'whole milk', 'yogurt'}): 708,
#   frozenset({'rolls/buns', 'root vegetables', 'whole milk', 'yogurt'}): 552,
#   frozenset({'other vegetables',
#              'rolls/buns',
#              'root vegetables',
#              'yogurt'}): 492},
#  {frozenset({'other vegetables',
#              'root vegetables',
#              'tropical fruit',
#              'whole milk',
#              'yogurt'}): 700,
#   frozenset({'other vegetables',
#              'rolls/buns',
#              'tropical fruit',
#              'whole milk',
#              'yogurt'}): 500,
#   frozenset({'other vegetables',
#              'rolls/buns',
#              'root vegetables',
#              'whole milk',
#              'yogurt'}): 480},
#  {}]

# %%
association_rules=[]
for itemset in final_itemsets:# iter list
    for value in itemset:
        for condition in getAllSubsets(value):
            conclusion_items=[x for x in value if x not in condition]
            if len(conclusion_items)>0:
                confidence=float(final_itemsets[len(value)-1][value])/float(final_itemsets[len(condition)-1][condition])
                if confidence>min_conf:
                    association_rules.append([[condition,conclusion_items],[confidence]])

# %%
len(association_rules)
# Out:
# 410

# %%
association_rules
# Out:
# [[[frozenset({'other vegetables'}), ['whole milk']], [0.7735155018392013]],
#  [[frozenset({'yogurt'}), ['whole milk']], [0.8032069970845481]],
#  [[frozenset({'butter'}), ['whole milk']], [0.9944954128440368]],
#  [[frozenset({'tropical fruit'}), ['other vegetables']], [0.6841085271317829]],
#  [[frozenset({'citrus fruit'}), ['whole milk']], [0.7371007371007371]],
#  [[frozenset({'tropical fruit'}), ['whole milk']], [0.8062015503875969]],
#  [[frozenset({'bottled water'}), ['whole milk']], [0.6218951241950322]],
#  [[frozenset({'curd'}), ['whole milk']], [0.9809160305343512]],
#  [[frozenset({'root vegetables'}), ['other vegetables']],
#   [0.8694029850746269]],
#  [[frozenset({'sausage'}), ['rolls/buns']], [0.6515151515151515]],
#  [[frozenset({'root vegetables'}), ['whole milk']], [0.8973880597014925]],
#  [[frozenset({'pork'}), ['whole milk']], [0.7689594356261023]],
#  [[frozenset({'whipped/sour cream'}), ['whole milk']], [0.8992907801418439]],
#  [[frozenset({'pork'}), ['other vegetables']], [0.7513227513227513]],
#  [[frozenset({'whipped/sour cream'}), ['other vegetables']],
#   [0.8056737588652483]],
#  [[frozenset({'pastry'}), ['whole milk']], [0.7474285714285714]],
#  [[frozenset({'brown bread'}), ['whole milk']], [0.7774294670846394]],
#  [[frozenset({'domestic eggs'}), ['whole milk']], [0.9455128205128205]],
#  [[frozenset({'domestic eggs'}), ['other vegetables']], [0.7019230769230769]],
#  [[frozenset({'frozen vegetables'}), ['whole milk']], [0.8498942917547568]],
#  [[frozenset({'beef'}), ['whole milk']], [0.810077519379845]],
#  [[frozenset({'sausage'}), ['whole milk']], [0.6363636363636364]],
#  [[frozenset({'pip fruit'}), ['whole milk']], [0.7956989247311828]],
#  [[frozenset({'rolls/buns'}), ['whole milk']], [0.6158098396904367]],
#  [[frozenset({'margarine'}), ['whole milk']], [0.8263888888888888]],
#  [[frozenset({'frankfurter'}), ['whole milk']], [0.696551724137931]],
#  [[frozenset({'newspapers'}), ['whole milk']], [0.6853503184713375]],
#  [[frozenset({'fruit/vegetable juice'}), ['whole milk']],
#   [0.7369901547116737]],
#  [[frozenset({'citrus fruit'}), ['other vegetables']], [0.6977886977886978]],
#  [[frozenset({'pip fruit'}), ['other vegetables']], [0.6908602150537635]],
#  [[frozenset({'yogurt'}), ['other vegetables']], [0.6224489795918368]],
#  [[frozenset({'yogurt'}), ['whole milk', 'tropical fruit']],
#   [0.6516034985422741]],
#  [[frozenset({'tropical fruit'}), ['yogurt', 'whole milk']],
#   [0.8662790697674418]],
#  [[frozenset({'whole milk', 'yogurt'}), ['tropical fruit']],
#   [0.8112522686025408]],
#  [[frozenset({'tropical fruit', 'yogurt'}), ['whole milk']],
#   [1.5520833333333333]],
#  [[frozenset({'tropical fruit', 'whole milk'}), ['yogurt']],
#   [1.0745192307692308]],
#  [[frozenset({'citrus fruit'}), ['yogurt', 'whole milk']],
#   [0.7444717444717445]],
#  [[frozenset({'citrus fruit', 'yogurt'}), ['whole milk']],
#   [1.4225352112676057]],
#  [[frozenset({'citrus fruit', 'whole milk'}), ['yogurt']], [1.01]],
#  [[frozenset({'bottled water', 'yogurt'}), ['whole milk']],
#   [1.261061946902655]],
#  [[frozenset({'bottled water', 'whole milk'}), ['yogurt']],
#   [0.8431952662721893]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}), ['other vegetables']],
#   [0.9545454545454546]],
#  [[frozenset({'other vegetables', 'tropical fruit'}), ['rolls/buns']],
#   [0.6543909348441926]],
#  [[frozenset({'root vegetables'}), ['rolls/buns', 'other vegetables']],
#   [0.6716417910447762]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['root vegetables']],
#   [0.8591885441527446]],
#  [[frozenset({'rolls/buns', 'root vegetables'}), ['other vegetables']],
#   [1.506276150627615]],
#  [[frozenset({'other vegetables', 'root vegetables'}), ['rolls/buns']],
#   [0.7725321888412017]],
#  [[frozenset({'root vegetables'}), ['other vegetables', 'tropical fruit']],
#   [0.6772388059701493]],
#  [[frozenset({'tropical fruit'}), ['root vegetables', 'other vegetables']],
#   [0.7034883720930233]],
#  [[frozenset({'other vegetables', 'root vegetables'}), ['tropical fruit']],
#   [0.778969957081545]],
#  [[frozenset({'root vegetables', 'tropical fruit'}), ['other vegetables']],
#   [1.7536231884057971]],
#  [[frozenset({'other vegetables', 'tropical fruit'}), ['root vegetables']],
#   [1.028328611898017]],
#  [[frozenset({'sausage'}), ['rolls/buns', 'soda']], [0.6168831168831169]],
#  [[frozenset({'rolls/buns', 'soda'}), ['sausage']], [0.7559681697612732]],
#  [[frozenset({'rolls/buns', 'sausage'}), ['soda']], [0.946843853820598]],
#  [[frozenset({'sausage', 'soda'}), ['rolls/buns']], [1.1924686192468619]],
#  [[frozenset({'bottled water', 'rolls/buns'}), ['other vegetables']],
#   [0.907563025210084]],
#  [[frozenset({'bottled water', 'other vegetables'}), ['rolls/buns']],
#   [0.8852459016393442]],
#  [[frozenset({'other vegetables'}), ['whole milk', 'root vegetables']],
#   [0.7188649500788229]],
#  [[frozenset({'root vegetables'}), ['whole milk', 'other vegetables']],
#   [1.2761194029850746]],
#  [[frozenset({'other vegetables', 'whole milk'}), ['root vegetables']],
#   [0.9293478260869565]],
#  [[frozenset({'root vegetables', 'whole milk'}), ['other vegetables']],
#   [1.4220374220374221]],
#  [[frozenset({'other vegetables', 'root vegetables'}), ['whole milk']],
#   [1.4678111587982832]],
#  [[frozenset({'soda', 'whole milk'}), ['other vegetables']],
#   [1.0431472081218274]],
#  [[frozenset({'other vegetables', 'soda'}), ['whole milk']],
#   [1.2763975155279503]],
#  [[frozenset({'pork'}), ['whole milk', 'other vegetables']],
#   [1.0582010582010581]],
#  [[frozenset({'pork', 'whole milk'}), ['other vegetables']],
#   [1.3761467889908257]],
#  [[frozenset({'other vegetables', 'pork'}), ['whole milk']],
#   [1.408450704225352]],
#  [[frozenset({'whipped/sour cream'}), ['whole milk', 'other vegetables']],
#   [1.225531914893617]],
#  [[frozenset({'whipped/sour cream', 'whole milk'}), ['other vegetables']],
#   [1.362776025236593]],
#  [[frozenset({'other vegetables', 'whipped/sour cream'}), ['whole milk']],
#   [1.5211267605633803]],
#  [[frozenset({'root vegetables', 'yogurt'}), ['tropical fruit']],
#   [0.9448818897637795]],
#  [[frozenset({'tropical fruit', 'yogurt'}), ['root vegetables']],
#   [0.8333333333333334]],
#  [[frozenset({'root vegetables', 'tropical fruit'}), ['yogurt']],
#   [1.1594202898550725]],
#  [[frozenset({'yogurt'}), ['whole milk', 'root vegetables']],
#   [0.6253644314868805]],
#  [[frozenset({'root vegetables'}), ['yogurt', 'whole milk']],
#   [0.8003731343283582]],
#  [[frozenset({'whole milk', 'yogurt'}), ['root vegetables']],
#   [0.778584392014519]],
#  [[frozenset({'root vegetables', 'yogurt'}), ['whole milk']],
#   [1.688976377952756]],
#  [[frozenset({'root vegetables', 'whole milk'}), ['yogurt']],
#   [0.8918918918918919]],
#  [[frozenset({'soda', 'yogurt'}), ['whole milk']], [1.1486988847583643]],
#  [[frozenset({'soda', 'whole milk'}), ['yogurt']], [0.7842639593908629]],
#  [[frozenset({'tropical fruit'}), ['whole milk', 'root vegetables']],
#   [0.686046511627907]],
#  [[frozenset({'root vegetables'}), ['whole milk', 'tropical fruit']],
#   [0.6604477611940298]],
#  [[frozenset({'tropical fruit', 'whole milk'}), ['root vegetables']],
#   [0.8509615384615384]],
#  [[frozenset({'root vegetables', 'whole milk'}), ['tropical fruit']],
#   [0.735966735966736]],
#  [[frozenset({'root vegetables', 'tropical fruit'}), ['whole milk']],
#   [1.710144927536232]],
#  [[frozenset({'soda', 'tropical fruit'}), ['whole milk']],
#   [1.1268292682926828]],
#  [[frozenset({'soda', 'whole milk'}), ['pastry']], [0.616751269035533]],
#  [[frozenset({'pastry', 'soda'}), ['whole milk']], [1.173913043478261]],
#  [[frozenset({'pastry', 'whole milk'}), ['soda']], [0.7431192660550459]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['bottled water']],
#   [0.621301775147929]],
#  [[frozenset({'bottled water', 'rolls/buns'}), ['yogurt']],
#   [0.8823529411764706]],
#  [[frozenset({'bottled water', 'yogurt'}), ['rolls/buns']],
#   [0.9292035398230089]],
#  [[frozenset({'bottled water', 'yogurt'}), ['soda']], [0.9690265486725663]],
#  [[frozenset({'soda', 'yogurt'}), ['bottled water']], [0.8141263940520446]],
#  [[frozenset({'bottled water', 'soda'}), ['yogurt']], [0.7684210526315789]],
#  [[frozenset({'bottled water', 'rolls/buns'}), ['soda']],
#   [0.8445378151260504]],
#  [[frozenset({'bottled water', 'soda'}), ['rolls/buns']],
#   [0.7052631578947368]],
#  [[frozenset({'rolls/buns', 'soda'}), ['yogurt']], [0.6763925729442971]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['soda']], [0.7544378698224852]],
#  [[frozenset({'soda', 'yogurt'}), ['rolls/buns']], [0.9479553903345725]],
#  [[frozenset({'tropical fruit'}), ['rolls/buns', 'whole milk']],
#   [0.627906976744186]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}), ['whole milk']],
#   [1.3388429752066116]],
#  [[frozenset({'tropical fruit', 'whole milk'}), ['rolls/buns']],
#   [0.7788461538461539]],
#  [[frozenset({'pip fruit'}), ['whole milk', 'tropical fruit']],
#   [0.6693548387096774]],
#  [[frozenset({'pip fruit', 'whole milk'}), ['tropical fruit']],
#   [0.8412162162162162]],
#  [[frozenset({'pip fruit', 'tropical fruit'}), ['whole milk']],
#   [1.2388059701492538]],
#  [[frozenset({'rolls/buns', 'whole milk'}), ['other vegetables']],
#   [0.947935368043088]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['whole milk']],
#   [1.260143198090692]],
#  [[frozenset({'other vegetables', 'whole milk'}), ['rolls/buns']],
#   [0.717391304347826]],
#  [[frozenset({'root vegetables'}), ['rolls/buns', 'whole milk']],
#   [0.6996268656716418]],
#  [[frozenset({'rolls/buns', 'whole milk'}), ['root vegetables']],
#   [0.6732495511669659]],
#  [[frozenset({'rolls/buns', 'root vegetables'}), ['whole milk']],
#   [1.5690376569037656]],
#  [[frozenset({'root vegetables', 'whole milk'}), ['rolls/buns']],
#   [0.7796257796257796]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['root vegetables']],
#   [0.6301775147928994]],
#  [[frozenset({'rolls/buns', 'root vegetables'}), ['yogurt']],
#   [0.891213389121339]],
#  [[frozenset({'root vegetables', 'yogurt'}), ['rolls/buns']],
#   [0.8385826771653543]],
#  [[frozenset({'rolls/buns', 'soda'}), ['whole milk']], [0.6923076923076923]],
#  [[frozenset({'soda', 'whole milk'}), ['rolls/buns']], [0.6624365482233503]],
#  [[frozenset({'rolls/buns', 'sausage'}), ['whole milk']],
#   [0.9169435215946844]],
#  [[frozenset({'sausage', 'whole milk'}), ['rolls/buns']],
#   [0.9387755102040817]],
#  [[frozenset({'pastry', 'rolls/buns'}), ['whole milk']], [1.2233009708737863]],
#  [[frozenset({'pastry', 'whole milk'}), ['rolls/buns']], [0.7706422018348624]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['sausage']],
#   [0.6229116945107399]],
#  [[frozenset({'rolls/buns', 'sausage'}), ['other vegetables']],
#   [0.867109634551495]],
#  [[frozenset({'other vegetables', 'sausage'}), ['rolls/buns']],
#   [0.9849056603773585]],
#  [[frozenset({'bottled water', 'rolls/buns'}), ['whole milk']],
#   [1.084033613445378]],
#  [[frozenset({'bottled water', 'whole milk'}), ['rolls/buns']],
#   [0.7633136094674556]],
#  [[frozenset({'domestic eggs'}), ['whole milk', 'other vegetables']],
#   [1.1634615384615385]],
#  [[frozenset({'domestic eggs', 'whole milk'}), ['other vegetables']],
#   [1.230508474576271]],
#  [[frozenset({'domestic eggs', 'other vegetables'}), ['whole milk']],
#   [1.6575342465753424]],
#  [[frozenset({'pip fruit'}), ['whole milk', 'other vegetables']],
#   [1.0725806451612903]],
#  [[frozenset({'pip fruit', 'whole milk'}), ['other vegetables']],
#   [1.347972972972973]],
#  [[frozenset({'other vegetables', 'pip fruit'}), ['whole milk']],
#   [1.5525291828793775]],
#  [[frozenset({'shopping bags', 'whole milk'}), ['other vegetables']],
#   [0.9336099585062241]],
#  [[frozenset({'other vegetables', 'shopping bags'}), ['whole milk']],
#   [0.9868421052631579]],
#  [[frozenset({'yogurt'}), ['whole milk', 'other vegetables']],
#   [0.9577259475218659]],
#  [[frozenset({'other vegetables'}), ['yogurt', 'whole milk']],
#   [0.6904887020493957]],
#  [[frozenset({'whole milk', 'yogurt'}), ['other vegetables']],
#   [1.1923774954627948]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['whole milk']],
#   [1.5386416861826697]],
#  [[frozenset({'other vegetables', 'whole milk'}), ['yogurt']],
#   [0.8926630434782609]],
#  [[frozenset({'fruit/vegetable juice'}), ['whole milk', 'other vegetables']],
#   [0.869198312236287]],
#  [[frozenset({'fruit/vegetable juice', 'whole milk'}), ['other vegetables']],
#   [1.1793893129770991]],
#  [[frozenset({'fruit/vegetable juice', 'other vegetables'}), ['whole milk']],
#   [1.4927536231884058]],
#  [[frozenset({'root vegetables'}), ['yogurt', 'other vegetables']],
#   [0.710820895522388]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['root vegetables']],
#   [0.892271662763466]],
#  [[frozenset({'root vegetables', 'yogurt'}), ['other vegetables']], [1.5]],
#  [[frozenset({'other vegetables', 'root vegetables'}), ['yogurt']],
#   [0.8175965665236051]],
#  [[frozenset({'bottled water', 'soda'}), ['whole milk']],
#   [0.7789473684210526]],
#  [[frozenset({'bottled water', 'whole milk'}), ['soda']],
#   [0.6568047337278107]],
#  [[frozenset({'tropical fruit'}), ['whole milk', 'other vegetables']],
#   [0.9767441860465116]],
#  [[frozenset({'other vegetables', 'whole milk'}), ['tropical fruit']],
#   [0.6847826086956522]],
#  [[frozenset({'tropical fruit', 'whole milk'}), ['other vegetables']],
#   [1.2115384615384615]],
#  [[frozenset({'other vegetables', 'tropical fruit'}), ['whole milk']],
#   [1.4277620396600565]],
#  [[frozenset({'tropical fruit'}), ['yogurt', 'other vegetables']],
#   [0.7034883720930233]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['tropical fruit']],
#   [0.8501170960187353]],
#  [[frozenset({'tropical fruit', 'yogurt'}), ['other vegetables']],
#   [1.2604166666666667]],
#  [[frozenset({'other vegetables', 'tropical fruit'}), ['yogurt']],
#   [1.028328611898017]],
#  [[frozenset({'whipped/sour cream'}), ['yogurt', 'whole milk']],
#   [0.9106382978723404]],
#  [[frozenset({'whipped/sour cream', 'yogurt'}), ['whole milk']],
#   [1.5735294117647058]],
#  [[frozenset({'whipped/sour cream', 'whole milk'}), ['yogurt']],
#   [1.0126182965299684]],
#  [[frozenset({'pip fruit'}), ['other vegetables', 'tropical fruit']], [0.75]],
#  [[frozenset({'other vegetables', 'tropical fruit'}), ['pip fruit']],
#   [0.7903682719546742]],
#  [[frozenset({'other vegetables', 'pip fruit'}), ['tropical fruit']],
#   [1.0856031128404668]],
#  [[frozenset({'pip fruit', 'tropical fruit'}), ['other vegetables']],
#   [1.3880597014925373]],
#  [[frozenset({'whipped/sour cream'}), ['yogurt', 'other vegetables']],
#   [0.851063829787234]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['whipped/sour cream']],
#   [0.702576112412178]],
#  [[frozenset({'whipped/sour cream', 'yogurt'}), ['other vegetables']],
#   [1.4705882352941178]],
#  [[frozenset({'other vegetables', 'whipped/sour cream'}), ['yogurt']],
#   [1.056338028169014]],
#  [[frozenset({'other vegetables', 'soda'}), ['sausage']],
#   [0.6614906832298136]],
#  [[frozenset({'sausage', 'soda'}), ['other vegetables']], [0.891213389121339]],
#  [[frozenset({'other vegetables', 'sausage'}), ['soda']],
#   [0.8037735849056604]],
#  [[frozenset({'other vegetables', 'soda'}), ['yogurt']], [0.7639751552795031]],
#  [[frozenset({'soda', 'yogurt'}), ['other vegetables']], [0.9144981412639405]],
#  [[frozenset({'citrus fruit'}), ['whole milk', 'other vegetables']],
#   [0.9434889434889435]],
#  [[frozenset({'citrus fruit', 'whole milk'}), ['other vegetables']], [1.28]],
#  [[frozenset({'citrus fruit', 'other vegetables'}), ['whole milk']],
#   [1.352112676056338]],
#  [[frozenset({'sausage'}), ['whole milk', 'other vegetables']],
#   [0.6493506493506493]],
#  [[frozenset({'sausage', 'whole milk'}), ['other vegetables']],
#   [1.0204081632653061]],
#  [[frozenset({'other vegetables', 'sausage'}), ['whole milk']],
#   [1.1320754716981132]],
#  [[frozenset({'yogurt'}), ['rolls/buns', 'whole milk']], [0.6690962099125365]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['whole milk']], [1.3579881656804733]],
#  [[frozenset({'rolls/buns', 'whole milk'}), ['yogurt']], [0.8240574506283662]],
#  [[frozenset({'whole milk', 'yogurt'}), ['rolls/buns']], [0.8330308529945554]],
#  [[frozenset({'bottled water', 'whole milk'}), ['other vegetables']],
#   [0.9408284023668639]],
#  [[frozenset({'bottled water', 'other vegetables'}), ['whole milk']],
#   [1.3032786885245902]],
#  [[frozenset({'rolls/buns', 'soda'}), ['other vegetables']],
#   [0.7718832891246684]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['soda']],
#   [0.6945107398568019]],
#  [[frozenset({'other vegetables', 'soda'}), ['rolls/buns']],
#   [0.9037267080745341]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['tropical fruit']],
#   [0.7633136094674556]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}), ['yogurt']],
#   [1.0661157024793388]],
#  [[frozenset({'tropical fruit', 'yogurt'}), ['rolls/buns']],
#   [0.8958333333333334]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['other vegetables']],
#   [1.0029585798816567]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['yogurt']],
#   [0.8090692124105012]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['rolls/buns']],
#   [0.7939110070257611]],
#  [[frozenset({'other vegetables', 'soda'}), ['tropical fruit']],
#   [0.6614906832298136]],
#  [[frozenset({'soda', 'tropical fruit'}), ['other vegetables']],
#   [1.0390243902439025]],
#  [[frozenset({'other vegetables', 'tropical fruit'}), ['soda']],
#   [0.603399433427762]],
#  [[frozenset({'bottled water', 'yogurt'}), ['other vegetables']],
#   [1.0619469026548674]],
#  [[frozenset({'bottled water', 'other vegetables'}), ['yogurt']],
#   [0.9836065573770492]],
#  [[frozenset({'citrus fruit', 'yogurt'}), ['other vegetables']],
#   [1.056338028169014]],
#  [[frozenset({'citrus fruit', 'other vegetables'}), ['yogurt']],
#   [0.7922535211267606]],
#  [[frozenset({'pastry'}), ['whole milk', 'other vegetables']],
#   [0.7131428571428572]],
#  [[frozenset({'pastry', 'whole milk'}), ['other vegetables']],
#   [0.9541284403669725]],
#  [[frozenset({'other vegetables', 'pastry'}), ['whole milk']],
#   [1.4054054054054055]],
#  [[frozenset({'shopping bags', 'soda'}), ['whole milk']],
#   [0.8305785123966942]],
#  [[frozenset({'shopping bags', 'whole milk'}), ['soda']],
#   [0.8340248962655602]],
#  [[frozenset({'root vegetables'}), ['whole milk', 'yogurt', 'tropical fruit']],
#   [0.6268656716417911]],
#  [[frozenset({'tropical fruit'}), ['whole milk', 'root vegetables', 'yogurt']],
#   [0.6511627906976745]],
#  [[frozenset({'root vegetables', 'whole milk'}), ['yogurt', 'tropical fruit']],
#   [0.6985446985446986]],
#  [[frozenset({'whole milk', 'yogurt'}), ['root vegetables', 'tropical fruit']],
#   [0.6098003629764065]],
#  [[frozenset({'tropical fruit', 'whole milk'}), ['root vegetables', 'yogurt']],
#   [0.8076923076923077]],
#  [[frozenset({'root vegetables', 'yogurt'}), ['whole milk', 'tropical fruit']],
#   [1.3228346456692914]],
#  [[frozenset({'root vegetables', 'tropical fruit'}), ['whole milk', 'yogurt']],
#   [1.6231884057971016]],
#  [[frozenset({'tropical fruit', 'yogurt'}), ['whole milk', 'root vegetables']],
#   [1.1666666666666667]],
#  [[frozenset({'root vegetables', 'whole milk', 'yogurt'}), ['tropical fruit']],
#   [0.7832167832167832]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'whole milk'}), ['yogurt']],
#   [0.9491525423728814]],
#  [[frozenset({'tropical fruit', 'whole milk', 'yogurt'}), ['root vegetables']],
#   [0.7516778523489933]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'yogurt'}), ['whole milk']],
#   [1.4]],
#  [[frozenset({'root vegetables'}),
#    ['whole milk', 'other vegetables', 'yogurt']],
#   [0.8619402985074627]],
#  [[frozenset({'yogurt'}),
#    ['whole milk', 'other vegetables', 'root vegetables']],
#   [0.673469387755102]],
#  [[frozenset({'other vegetables', 'whole milk'}),
#    ['root vegetables', 'yogurt']],
#   [0.6277173913043478]],
#  [[frozenset({'root vegetables', 'whole milk'}),
#    ['other vegetables', 'yogurt']],
#   [0.9604989604989606]],
#  [[frozenset({'whole milk', 'yogurt'}),
#    ['other vegetables', 'root vegetables']],
#   [0.838475499092559]],
#  [[frozenset({'other vegetables', 'root vegetables'}),
#    ['whole milk', 'yogurt']],
#   [0.9914163090128756]],
#  [[frozenset({'other vegetables', 'yogurt'}),
#    ['whole milk', 'root vegetables']],
#   [1.0819672131147542]],
#  [[frozenset({'root vegetables', 'yogurt'}),
#    ['whole milk', 'other vegetables']],
#   [1.8188976377952757]],
#  [[frozenset({'other vegetables', 'root vegetables', 'whole milk'}),
#    ['yogurt']],
#   [0.6754385964912281]],
#  [[frozenset({'other vegetables', 'whole milk', 'yogurt'}),
#    ['root vegetables']],
#   [0.7031963470319634]],
#  [[frozenset({'root vegetables', 'whole milk', 'yogurt'}),
#    ['other vegetables']],
#   [1.0769230769230769]],
#  [[frozenset({'other vegetables', 'root vegetables', 'yogurt'}),
#    ['whole milk']],
#   [1.2125984251968505]],
#  [[frozenset({'yogurt'}),
#    ['whole milk', 'other vegetables', 'tropical fruit']],
#   [0.6559766763848397]],
#  [[frozenset({'tropical fruit'}),
#    ['whole milk', 'other vegetables', 'yogurt']],
#   [0.872093023255814]],
#  [[frozenset({'other vegetables', 'whole milk'}),
#    ['yogurt', 'tropical fruit']],
#   [0.6114130434782609]],
#  [[frozenset({'whole milk', 'yogurt'}),
#    ['other vegetables', 'tropical fruit']],
#   [0.8166969147005445]],
#  [[frozenset({'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'yogurt']],
#   [1.0817307692307692]],
#  [[frozenset({'other vegetables', 'yogurt'}),
#    ['whole milk', 'tropical fruit']],
#   [1.053864168618267]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['whole milk', 'yogurt']],
#   [1.274787535410765]],
#  [[frozenset({'tropical fruit', 'yogurt'}),
#    ['whole milk', 'other vegetables']],
#   [1.5625]],
#  [[frozenset({'other vegetables', 'whole milk', 'yogurt'}),
#    ['tropical fruit']],
#   [0.684931506849315]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'whole milk'}),
#    ['yogurt']],
#   [0.8928571428571429]],
#  [[frozenset({'tropical fruit', 'whole milk', 'yogurt'}),
#    ['other vegetables']],
#   [1.0067114093959733]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'yogurt'}),
#    ['whole milk']],
#   [1.2396694214876034]],
#  [[frozenset({'root vegetables'}),
#    ['whole milk', 'other vegetables', 'tropical fruit']],
#   [0.7723880597014925]],
#  [[frozenset({'tropical fruit'}),
#    ['whole milk', 'other vegetables', 'root vegetables']],
#   [0.8023255813953488]],
#  [[frozenset({'root vegetables', 'whole milk'}),
#    ['other vegetables', 'tropical fruit']],
#   [0.8607068607068608]],
#  [[frozenset({'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'root vegetables']],
#   [0.9951923076923077]],
#  [[frozenset({'other vegetables', 'root vegetables'}),
#    ['whole milk', 'tropical fruit']],
#   [0.8884120171673819]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['whole milk', 'root vegetables']],
#   [1.1728045325779037]],
#  [[frozenset({'root vegetables', 'tropical fruit'}),
#    ['whole milk', 'other vegetables']],
#   [2.0]],
#  [[frozenset({'other vegetables', 'root vegetables', 'whole milk'}),
#    ['tropical fruit']],
#   [0.6052631578947368]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'whole milk'}),
#    ['root vegetables']],
#   [0.8214285714285714]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'whole milk'}),
#    ['other vegetables']],
#   [1.1694915254237288]],
#  [[frozenset({'other vegetables', 'root vegetables', 'tropical fruit'}),
#    ['whole milk']],
#   [1.140495867768595]],
#  [[frozenset({'other vegetables', 'root vegetables'}),
#    ['yogurt', 'tropical fruit']],
#   [0.630901287553648]],
#  [[frozenset({'other vegetables', 'yogurt'}),
#    ['root vegetables', 'tropical fruit']],
#   [0.6885245901639344]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['root vegetables', 'yogurt']],
#   [0.8328611898016998]],
#  [[frozenset({'root vegetables', 'yogurt'}),
#    ['other vegetables', 'tropical fruit']],
#   [1.1574803149606299]],
#  [[frozenset({'root vegetables', 'tropical fruit'}),
#    ['other vegetables', 'yogurt']],
#   [1.4202898550724639]],
#  [[frozenset({'tropical fruit', 'yogurt'}),
#    ['other vegetables', 'root vegetables']],
#   [1.0208333333333333]],
#  [[frozenset({'other vegetables', 'root vegetables', 'yogurt'}),
#    ['tropical fruit']],
#   [0.7716535433070866]],
#  [[frozenset({'other vegetables', 'root vegetables', 'tropical fruit'}),
#    ['yogurt']],
#   [0.8099173553719008]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'yogurt'}),
#    ['root vegetables']],
#   [0.8099173553719008]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'yogurt'}),
#    ['other vegetables']],
#   [1.225]],
#  [[frozenset({'whipped/sour cream'}),
#    ['whole milk', 'other vegetables', 'yogurt']],
#   [0.9361702127659575]],
#  [[frozenset({'whipped/sour cream', 'whole milk'}),
#    ['other vegetables', 'yogurt']],
#   [1.0410094637223974]],
#  [[frozenset({'other vegetables', 'whipped/sour cream'}),
#    ['whole milk', 'yogurt']],
#   [1.1619718309859155]],
#  [[frozenset({'other vegetables', 'yogurt'}),
#    ['whole milk', 'whipped/sour cream']],
#   [0.7728337236533958]],
#  [[frozenset({'whipped/sour cream', 'yogurt'}),
#    ['whole milk', 'other vegetables']],
#   [1.6176470588235294]],
#  [[frozenset({'other vegetables', 'whipped/sour cream', 'whole milk'}),
#    ['yogurt']],
#   [0.7638888888888888]],
#  [[frozenset({'whipped/sour cream', 'whole milk', 'yogurt'}),
#    ['other vegetables']],
#   [1.02803738317757]],
#  [[frozenset({'other vegetables', 'whipped/sour cream', 'yogurt'}),
#    ['whole milk']],
#   [1.1]],
#  [[frozenset({'pip fruit'}),
#    ['whole milk', 'other vegetables', 'tropical fruit']],
#   [0.7580645161290323]],
#  [[frozenset({'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'pip fruit']],
#   [0.6778846153846154]],
#  [[frozenset({'pip fruit', 'whole milk'}),
#    ['other vegetables', 'tropical fruit']],
#   [0.9527027027027027]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['whole milk', 'pip fruit']],
#   [0.7988668555240793]],
#  [[frozenset({'other vegetables', 'pip fruit'}),
#    ['whole milk', 'tropical fruit']],
#   [1.0972762645914398]],
#  [[frozenset({'pip fruit', 'tropical fruit'}),
#    ['whole milk', 'other vegetables']],
#   [1.4029850746268657]],
#  [[frozenset({'other vegetables', 'pip fruit', 'whole milk'}),
#    ['tropical fruit']],
#   [0.706766917293233]],
#  [[frozenset({'pip fruit', 'tropical fruit', 'whole milk'}),
#    ['other vegetables']],
#   [1.1325301204819278]],
#  [[frozenset({'other vegetables', 'pip fruit', 'tropical fruit'}),
#    ['whole milk']],
#   [1.010752688172043]],
#  [[frozenset({'root vegetables'}),
#    ['whole milk', 'other vegetables', 'rolls/buns']],
#   [0.6828358208955224]],
#  [[frozenset({'root vegetables', 'whole milk'}),
#    ['other vegetables', 'rolls/buns']],
#   [0.760914760914761]],
#  [[frozenset({'rolls/buns', 'whole milk'}),
#    ['other vegetables', 'root vegetables']],
#   [0.6570915619389587]],
#  [[frozenset({'other vegetables', 'root vegetables'}),
#    ['whole milk', 'rolls/buns']],
#   [0.7854077253218884]],
#  [[frozenset({'other vegetables', 'rolls/buns'}),
#    ['whole milk', 'root vegetables']],
#   [0.8735083532219571]],
#  [[frozenset({'rolls/buns', 'root vegetables'}),
#    ['whole milk', 'other vegetables']],
#   [1.5313807531380754]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'whole milk'}),
#    ['root vegetables']],
#   [0.6931818181818182]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'whole milk'}),
#    ['other vegetables']],
#   [0.976]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'root vegetables'}),
#    ['whole milk']],
#   [1.0166666666666666]],
#  [[frozenset({'tropical fruit', 'whole milk'}), ['rolls/buns', 'yogurt']],
#   [0.6923076923076923]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['whole milk', 'tropical fruit']],
#   [0.8520710059171598]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}), ['whole milk', 'yogurt']],
#   [1.1900826446280992]],
#  [[frozenset({'tropical fruit', 'yogurt'}), ['whole milk', 'rolls/buns']],
#   [1.0]],
#  [[frozenset({'rolls/buns', 'whole milk', 'yogurt'}), ['tropical fruit']],
#   [0.6274509803921569]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'whole milk'}), ['yogurt']],
#   [0.8888888888888888]],
#  [[frozenset({'tropical fruit', 'whole milk', 'yogurt'}), ['rolls/buns']],
#   [0.6442953020134228]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'yogurt'}), ['whole milk']],
#   [1.1162790697674418]],
#  [[frozenset({'citrus fruit'}), ['whole milk', 'other vegetables', 'yogurt']],
#   [0.6928746928746928]],
#  [[frozenset({'citrus fruit', 'whole milk'}), ['other vegetables', 'yogurt']],
#   [0.94]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['whole milk', 'citrus fruit']],
#   [0.6604215456674473]],
#  [[frozenset({'citrus fruit', 'other vegetables'}), ['whole milk', 'yogurt']],
#   [0.9929577464788732]],
#  [[frozenset({'citrus fruit', 'yogurt'}), ['whole milk', 'other vegetables']],
#   [1.323943661971831]],
#  [[frozenset({'citrus fruit', 'other vegetables', 'whole milk'}), ['yogurt']],
#   [0.734375]],
#  [[frozenset({'citrus fruit', 'whole milk', 'yogurt'}), ['other vegetables']],
#   [0.9306930693069307]],
#  [[frozenset({'citrus fruit', 'other vegetables', 'yogurt'}), ['whole milk']],
#   [1.2533333333333334]],
#  [[frozenset({'bottled water', 'whole milk'}), ['other vegetables', 'yogurt']],
#   [0.6923076923076923]],
#  [[frozenset({'bottled water', 'other vegetables'}), ['whole milk', 'yogurt']],
#   [0.9590163934426229]],
#  [[frozenset({'bottled water', 'yogurt'}), ['whole milk', 'other vegetables']],
#   [1.0353982300884956]],
#  [[frozenset({'bottled water', 'other vegetables', 'whole milk'}), ['yogurt']],
#   [0.7358490566037735]],
#  [[frozenset({'bottled water', 'whole milk', 'yogurt'}), ['other vegetables']],
#   [0.8210526315789474]],
#  [[frozenset({'bottled water', 'other vegetables', 'yogurt'}), ['whole milk']],
#   [0.975]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['whole milk', 'rolls/buns']],
#   [0.6798866855524079]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}),
#    ['whole milk', 'other vegetables']],
#   [0.9917355371900827]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'whole milk'}),
#    ['other vegetables']],
#   [0.7407407407407407]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'tropical fruit'}),
#    ['whole milk']],
#   [1.0389610389610389]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['rolls/buns', 'yogurt']],
#   [0.6288951841359773]],
#  [[frozenset({'rolls/buns', 'yogurt'}),
#    ['other vegetables', 'tropical fruit']],
#   [0.6568047337278107]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}),
#    ['other vegetables', 'yogurt']],
#   [0.9173553719008265]],
#  [[frozenset({'tropical fruit', 'yogurt'}),
#    ['other vegetables', 'rolls/buns']],
#   [0.7708333333333334]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'yogurt'}),
#    ['tropical fruit']],
#   [0.6548672566371682]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'tropical fruit'}),
#    ['yogurt']],
#   [0.961038961038961]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'yogurt'}),
#    ['rolls/buns']],
#   [0.6115702479338843]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'yogurt'}),
#    ['other vegetables']],
#   [0.8604651162790697]],
#  [[frozenset({'soda', 'whole milk'}), ['other vegetables', 'yogurt']],
#   [0.6548223350253807]],
#  [[frozenset({'other vegetables', 'soda'}), ['whole milk', 'yogurt']],
#   [0.8012422360248447]],
#  [[frozenset({'soda', 'yogurt'}), ['whole milk', 'other vegetables']],
#   [0.9591078066914498]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['soda', 'whole milk']],
#   [0.6042154566744731]],
#  [[frozenset({'other vegetables', 'soda', 'whole milk'}), ['yogurt']],
#   [0.6277372262773723]],
#  [[frozenset({'soda', 'whole milk', 'yogurt'}), ['other vegetables']],
#   [0.8349514563106796]],
#  [[frozenset({'other vegetables', 'soda', 'yogurt'}), ['whole milk']],
#   [1.048780487804878]],
#  [[frozenset({'soda', 'whole milk'}), ['other vegetables', 'rolls/buns']],
#   [0.6548223350253807]],
#  [[frozenset({'other vegetables', 'soda'}), ['whole milk', 'rolls/buns']],
#   [0.8012422360248447]],
#  [[frozenset({'rolls/buns', 'soda'}), ['whole milk', 'other vegetables']],
#   [0.6843501326259946]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['soda', 'whole milk']],
#   [0.6157517899761337]],
#  [[frozenset({'other vegetables', 'soda', 'whole milk'}), ['rolls/buns']],
#   [0.6277372262773723]],
#  [[frozenset({'rolls/buns', 'soda', 'whole milk'}), ['other vegetables']],
#   [0.9885057471264368]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'soda'}), ['whole milk']],
#   [0.8865979381443299]],
#  [[frozenset({'rolls/buns', 'whole milk'}), ['other vegetables', 'yogurt']],
#   [0.6355475763016158]],
#  [[frozenset({'whole milk', 'yogurt'}), ['other vegetables', 'rolls/buns']],
#   [0.6424682395644283]],
#  [[frozenset({'other vegetables', 'rolls/buns'}), ['whole milk', 'yogurt']],
#   [0.8448687350835322]],
#  [[frozenset({'other vegetables', 'yogurt'}), ['whole milk', 'rolls/buns']],
#   [0.8290398126463701]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['whole milk', 'other vegetables']],
#   [1.047337278106509]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'whole milk'}), ['yogurt']],
#   [0.6704545454545454]],
#  [[frozenset({'rolls/buns', 'whole milk', 'yogurt'}), ['other vegetables']],
#   [0.7712418300653595]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'yogurt'}), ['whole milk']],
#   [1.0442477876106195]],
#  [[frozenset({'rolls/buns', 'root vegetables'}), ['whole milk', 'yogurt']],
#   [1.1548117154811715]],
#  [[frozenset({'root vegetables', 'yogurt'}), ['whole milk', 'rolls/buns']],
#   [1.0866141732283465]],
#  [[frozenset({'rolls/buns', 'yogurt'}), ['whole milk', 'root vegetables']],
#   [0.8165680473372781]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'whole milk'}), ['yogurt']],
#   [0.736]],
#  [[frozenset({'root vegetables', 'whole milk', 'yogurt'}), ['rolls/buns']],
#   [0.6433566433566433]],
#  [[frozenset({'rolls/buns', 'whole milk', 'yogurt'}), ['root vegetables']],
#   [0.6013071895424836]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'yogurt'}), ['whole milk']],
#   [1.295774647887324]],
#  [[frozenset({'rolls/buns', 'root vegetables'}),
#    ['other vegetables', 'yogurt']],
#   [1.0292887029288702]],
#  [[frozenset({'root vegetables', 'yogurt'}),
#    ['other vegetables', 'rolls/buns']],
#   [0.968503937007874]],
#  [[frozenset({'rolls/buns', 'yogurt'}),
#    ['other vegetables', 'root vegetables']],
#   [0.727810650887574]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'root vegetables'}),
#    ['yogurt']],
#   [0.6833333333333333]],
#  [[frozenset({'other vegetables', 'root vegetables', 'yogurt'}),
#    ['rolls/buns']],
#   [0.6456692913385826]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'yogurt'}),
#    ['root vegetables']],
#   [0.7256637168141593]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'yogurt'}),
#    ['other vegetables']],
#   [1.1549295774647887]],
#  [[frozenset({'tropical fruit'}),
#    ['whole milk', 'other vegetables', 'root vegetables', 'yogurt']],
#   [0.6782945736434108]],
#  [[frozenset({'root vegetables'}),
#    ['whole milk', 'tropical fruit', 'other vegetables', 'yogurt']],
#   [0.6529850746268657]],
#  [[frozenset({'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'root vegetables', 'yogurt']],
#   [0.8413461538461539]],
#  [[frozenset({'root vegetables', 'whole milk'}),
#    ['tropical fruit', 'other vegetables', 'yogurt']],
#   [0.7276507276507277]],
#  [[frozenset({'whole milk', 'yogurt'}),
#    ['tropical fruit', 'other vegetables', 'root vegetables']],
#   [0.6352087114337568]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['whole milk', 'root vegetables', 'yogurt']],
#   [0.9915014164305949]],
#  [[frozenset({'root vegetables', 'tropical fruit'}),
#    ['whole milk', 'other vegetables', 'yogurt']],
#   [1.6908212560386473]],
#  [[frozenset({'tropical fruit', 'yogurt'}),
#    ['whole milk', 'other vegetables', 'root vegetables']],
#   [1.2152777777777777]],
#  [[frozenset({'other vegetables', 'root vegetables'}),
#    ['whole milk', 'tropical fruit', 'yogurt']],
#   [0.7510729613733905]],
#  [[frozenset({'other vegetables', 'yogurt'}),
#    ['whole milk', 'tropical fruit', 'root vegetables']],
#   [0.819672131147541]],
#  [[frozenset({'root vegetables', 'yogurt'}),
#    ['whole milk', 'tropical fruit', 'other vegetables']],
#   [1.3779527559055118]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'whole milk'}),
#    ['root vegetables', 'yogurt']],
#   [0.6944444444444444]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'yogurt']],
#   [0.9887005649717514]],
#  [[frozenset({'tropical fruit', 'whole milk', 'yogurt'}),
#    ['other vegetables', 'root vegetables']],
#   [0.7829977628635347]],
#  [[frozenset({'root vegetables', 'whole milk', 'yogurt'}),
#    ['tropical fruit', 'other vegetables']],
#   [0.8158508158508159]],
#  [[frozenset({'other vegetables', 'root vegetables', 'tropical fruit'}),
#    ['whole milk', 'yogurt']],
#   [0.9641873278236914]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'yogurt'}),
#    ['whole milk', 'root vegetables']],
#   [0.9641873278236914]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'yogurt'}),
#    ['whole milk', 'other vegetables']],
#   [1.4583333333333333]],
#  [[frozenset({'other vegetables', 'root vegetables', 'yogurt'}),
#    ['whole milk', 'tropical fruit']],
#   [0.9186351706036745]],
#  [[frozenset({'other vegetables',
#               'root vegetables',
#               'tropical fruit',
#               'whole milk'}),
#    ['yogurt']],
#   [0.8454106280193237]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'whole milk', 'yogurt'}),
#    ['root vegetables']],
#   [0.7777777777777778]],
#  [[frozenset({'root vegetables', 'tropical fruit', 'whole milk', 'yogurt'}),
#    ['other vegetables']],
#   [1.0416666666666667]],
#  [[frozenset({'other vegetables', 'root vegetables', 'whole milk', 'yogurt'}),
#    ['tropical fruit']],
#   [0.7575757575757576]],
#  [[frozenset({'other vegetables',
#               'root vegetables',
#               'tropical fruit',
#               'yogurt'}),
#    ['whole milk']],
#   [1.1904761904761905]],
#  [[frozenset({'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'rolls/buns', 'yogurt']],
#   [0.6009615384615384]],
#  [[frozenset({'other vegetables', 'tropical fruit'}),
#    ['whole milk', 'rolls/buns', 'yogurt']],
#   [0.7082152974504249]],
#  [[frozenset({'rolls/buns', 'tropical fruit'}),
#    ['whole milk', 'other vegetables', 'yogurt']],
#   [1.0330578512396693]],
#  [[frozenset({'tropical fruit', 'yogurt'}),
#    ['whole milk', 'other vegetables', 'rolls/buns']],
#   [0.8680555555555556]],
#  [[frozenset({'rolls/buns', 'yogurt'}),
#    ['whole milk', 'tropical fruit', 'other vegetables']],
#   [0.7396449704142012]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'whole milk'}),
#    ['other vegetables', 'yogurt']],
#   [0.7716049382716049]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'tropical fruit'}),
#    ['whole milk', 'yogurt']],
#   [1.0822510822510822]],
#  [[frozenset({'other vegetables', 'tropical fruit', 'yogurt'}),
#    ['whole milk', 'rolls/buns']],
#   [0.6887052341597796]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'yogurt'}),
#    ['whole milk', 'other vegetables']],
#   [0.9689922480620154]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'yogurt'}),
#    ['whole milk', 'tropical fruit']],
#   [0.7374631268436578]],
#  [[frozenset({'other vegetables',
#               'rolls/buns',
#               'tropical fruit',
#               'whole milk'}),
#    ['yogurt']],
#   [1.0416666666666667]],
#  [[frozenset({'rolls/buns', 'tropical fruit', 'whole milk', 'yogurt'}),
#    ['other vegetables']],
#   [0.8680555555555556]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'whole milk', 'yogurt'}),
#    ['tropical fruit']],
#   [0.7062146892655368]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'tropical fruit', 'yogurt'}),
#    ['whole milk']],
#   [1.1261261261261262]],
#  [[frozenset({'rolls/buns', 'root vegetables'}),
#    ['whole milk', 'other vegetables', 'yogurt']],
#   [1.00418410041841]],
#  [[frozenset({'root vegetables', 'yogurt'}),
#    ['whole milk', 'other vegetables', 'rolls/buns']],
#   [0.9448818897637795]],
#  [[frozenset({'rolls/buns', 'yogurt'}),
#    ['whole milk', 'other vegetables', 'root vegetables']],
#   [0.7100591715976331]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'whole milk'}),
#    ['other vegetables', 'yogurt']],
#   [0.64]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'root vegetables'}),
#    ['whole milk', 'yogurt']],
#   [0.6666666666666666]],
#  [[frozenset({'other vegetables', 'root vegetables', 'yogurt'}),
#    ['whole milk', 'rolls/buns']],
#   [0.6299212598425197]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'yogurt'}),
#    ['whole milk', 'root vegetables']],
#   [0.7079646017699115]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'yogurt'}),
#    ['whole milk', 'other vegetables']],
#   [1.1267605633802817]],
#  [[frozenset({'other vegetables',
#               'rolls/buns',
#               'root vegetables',
#               'whole milk'}),
#    ['yogurt']],
#   [0.6557377049180327]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'whole milk', 'yogurt'}),
#    ['root vegetables']],
#   [0.6779661016949152]],
#  [[frozenset({'rolls/buns', 'root vegetables', 'whole milk', 'yogurt'}),
#    ['other vegetables']],
#   [0.8695652173913043]],
#  [[frozenset({'other vegetables', 'rolls/buns', 'root vegetables', 'yogurt'}),
#    ['whole milk']],
#   [0.975609756097561]]]
