# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['FangSong'] 
sns.set(font='FangSong') 
# %matplotlib inline
warnings.filterwarnings('ignore')
pd.options.display.width = 900

# %%
df1 = pd.read_csv('datas2.csv')
df1.head()
# Out:
#           省市      地区  大专以上学历人数(万人)  万人大专以上学历人数(人/万人)  高等学校在校学生人数(万人)  十万人高等学校在校学生数(人/十万人)  科技企业孵化器管理机构从业人员人数(人)
# 0    BeiJing  HuaBei        781.02           3815.07          116.81              5428.83                  2586
# 1    TianJin  HuaBei        331.75           2284.88           64.96              4282.65                  1663
# 2      HeBei  HuaBei        541.00            794.23          154.93              2098.22                   871
# 3     shanXi  HuaBei        340.51            984.73           91.89              2518.81                   249
# 4  NeiMengGu  HuaBei        258.64           1089.36           54.00              2155.70                   271

# %%
df3=df1[df1['地区']=='HuaNan']
plt.figure(dpi=120)
sns.barplot(x='省市',y='大专以上学历人数(万人)',data=df3)
df3=df1[df1['地区']=='XiBei']
plt.figure(dpi=120)
sns.barplot(x='省市',y='大专以上学历人数(万人)',data=df3)

# %%
f, ax = plt.subplots(figsize = (6,6),dpi=120)
ax = sns.swarmplot(y="地区", x="大专以上学历人数(万人)", data=df1)
ax = sns.boxplot(y="地区", x="大专以上学历人数(万人)", data=df1)

# %%
df1[df1["地区"]=="HuaDong"]
# Out:
#           省市       地区  大专以上学历人数(万人)  万人大专以上学历人数(人/万人)  高等学校在校学生人数(万人)  十万人高等学校在校学生数(人/十万人)  科技企业孵化器管理机构从业人员人数(人)
# 8   ShangHai  HuaDong        627.25           2712.54           81.21              3347.93                  1404
# 9    JiangSu  HuaDong       1070.07           1427.90          227.52              2858.23                  7330
# 10  ZheJiang  HuaDong        791.97           1510.09          132.65              2408.27                   769
# 11     AnHui  HuaDong        591.48           1048.61          136.54              2244.62                   844
# 14  ShanDong  HuaDong        902.07            982.12          236.98              2420.79                  1775

# %%
# fig, axes = plt.subplots(nrows=5, ncols=1,figsize=(10,30),dpi=120)
# df2=df1.drop(["省市","地区"],axis=1)
# for col, ax in zip(df2.columns,axes.flatten()):
# #     f, axx = plt.subplots(figsize = (6,6),dpi=120)
#     sns.swarmplot(x=col, y='地区', data=df1, ax=ax)
#     sns.boxplot(x=col, y='地区', data=df1, ax=ax)
f, ax = plt.subplots(figsize = (6,6),dpi=120)
ax = sns.swarmplot(y="地区", x="科技企业孵化器管理机构从业人员人数(人)", data=df1)
ax = sns.boxplot(y="地区", x="科技企业孵化器管理机构从业人员人数(人)", data=df1)

# %%
corrmat=df2.corr()

plt.figure(figsize=(6,6), dpi= 120)
sns.heatmap(corrmat, xticklabels=df2.corr().columns, yticklabels=df2.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
# plt.title('Correlogram of mtcars', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# 建立散点图矩阵。对角线是单个变量的分布情况，非对角线是变量之间的相关性

# %%
# Plot
plt.figure(figsize=(8,8), dpi= 120)
sns.pairplot(df2, kind="scatter",  plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
# Plot
plt.figure(figsize=(10,8), dpi= 120)
sns.pairplot(df2, kind="reg")
plt.show()
